# %% [markdown]
# Connected to Python 3.10.12

# %%
"""
Problema de ruteo de vehiculos con multiples compartimento, flota heterogenea y ventanas de tiempo.

0. Contexto:
    PetroAndes Logistics S.A.C. es una empresa dedicada a la distribución de combustibles líquidos, principalmente gasohol 90 y diésel B5, hacia estaciones de servicio y clientes industriales en el sur del país. 
    
    Cada día la empresa alquila cisternas a transportistas con los que mantiene contratos que establecen tarifas diferenciadas según el tamaño del vehículo y el costo por kilómetro recorrido. 
    
    Al inicio de cada jornada se reciben los pedidos de los clientes, se consolida la demanda total y se debe decidir qué cisternas alquilar, cuánto producto cargará cada una y en qué orden se realizarán las entregas.

    Las cisternas utilizadas son vehículos con dos compartimentos, diseñados para transportar simultáneamente gasohol y diésel sin riesgo de mezcla entre productos. 
    
    La flota está compuesta por dos tipos de unidades, y cada tipo cuenta con un volumen específico asignado a cada producto. 

    Cada unidad realiza una única ruta por jornada, la cual comienza y termina en la almacen de despacho. 
    
    Una vez que un vehículo completa su recorrido y retorna al almacen, no puede volver a salir durante el mismo día.

    Un aspecto operativo crítico son los horarios de atención de los clientes. 
    Las estaciones no pueden recibir combustible en cualquier momento del día, estas ventanas de tiempo son propias de cada cliente y responden a regulaciones de seguridad o políticas internas de cada negocio. 
    Si una cisterna arriba antes del inicio de la ventana a un cliente, puede esperar hasta el horario permitido para iniciar la descarga, sin embargo, si llega después del límite establecido, no puede iniciar ese proceso.

    Cada cliente demanda cantidades específicas de gasohol y diésel, que deben entregarse en una sola visita por producto. 
    
    Un cliente puede ser atendido una única vez si una cisterna entrega ambos combustibles en la misma parada, o con dos cisternas distintas si cada producto se despacha por separado. No está permitido que más de una cisterna atienda el mismo tipo de producto en un mismo cliente. 
    
    Cada entrega tiene un tiempo de descarga definido, y cuando ambos productos se entregan en la misma visita, el tiempo total corresponde a la suma de los tiempos de descarga de cada combustible. 
    
    Los compartimentos de las cisternas son exclusivos para un solo tipo de producto.

    El crecimiento del número de clientes y la variabilidad diaria de la demanda han hecho que la planificación manual resulte insuficiente. Cada error en la asignación de cisternas puede traducirse en retrasos, sobrecostos o incluso en la pérdida de clientes por falta de abastecimiento oportuno. Contar con un programa que asista al gerente de operaciones en la toma de decisiones diarias se ha vuelto crucial para evitar pérdidas y garantizar la continuidad del servicio. 

    INSTANCIAS:

        La flota disponible es fija en todas las instancias y está compuesta por dos tipos de cisternas, con 20 unidades de cada tipo. 
        Los parámetros asociados a cada tipo se detallan a continuación:

        Tipo | Cap. Gasohol | Cap. Diésel | Costo fijo | Costo por km
        -----|--------------|------------|-----------|-------------
        1    | 5800         | 5200       | 450       | 2
        2    | 4000         | 4000       | 370       | 2

        Se asume una velocidad promedio constante de 60 km/h para todos los desplazamientos, sin variaciones horarias. 
        Las capacidades de los compartimentos están expresadas en galones y todos los costos se encuentran en dólares estadounidenses (US$). 
        Además, se considera que el tiempo de servicio en cada cliente es fijo e igual a 5 minutos, independientemente de la cantidad entregada. Si ambos combustibles se entregan en la misma visita, el tiempo total será de 10 minutos.

    EJEMPLO DE FORMATO DE ARCHIVO DE INSTANCIA (.csv):

            id, x,    y,    Gasohol,  Diésel,   Inicio,  Fin
            0,  35.0, 35.0, 0,        0,        04:00,   09:00
            36, 2.0,  60.0, 810,      790,      04:40,   06:00
            68, 56.0, 39.0, 760,      780,      05:50,   07:00
            22, 45.0, 10.0, 810,      850,      05:10,   06:10
            3,  55.0, 45.0, 800,      810,      04:50,   07:10
            31, 31.0, 52.0, 710,      840,      04:10,   07:20
            42, 24.0, 12.0, 810,      800,      04:20,   05:40
            8,  10.0, 10.0, 770,      790,      05:20,   06:00
            24, 65.0, 35.0, 840,      800,      04:50,   07:10
            53, 37.0, 31.0, 810,      850,      05:20,   06:00
            63, 27.0, 69.0, 860,      810,      04:30,   07:00

        Las distancias entre el almacén y los clientes, así como entre clientes, se calculan utilizando la distancia euclidiana a partir de sus coordenadas (x, y) expresadas en kilómetros. 
        Además, se establece que las cisternas pueden iniciar sus rutas a partir de las 04:00 horas y deben retornar al almacén antes de las 09:00 horas del mismo día.

Funcion Objetivo: Minimizar el costo diario de operacion, considerando el alquiler de cisternas y la distancia recorrida por los vehiculos, garantizando la atención completa de todos los clientes dentro de sus ventanas de tiempo.
"""

import os, sys
os.chdir(os.path.dirname(os.path.abspath(__file__)))

import pandas as pd
import numpy as np
from IPython.display import display
from typing import List, Dict
import random

from models import ProblemInstance, Ruta, SolutionVisualizer
from solvers import SweepAlgorithm, SolverTabuSearchMCVRPTW

pd.set_option('display.float_format', lambda x: '%.2f' % x)
np.set_printoptions(precision=2, suppress=True)

SEED = 42
np.random.seed(SEED)
random.seed(SEED)


# -----------------------------------------------------------------------------
# Utility Functions for Data Preprocessing
# -----------------------------------------------------------------------------

def time_to_minutes(time_str):
    """Convertir ventanas de tiempo a minutos desde 04:00"""
    h, m = map(int, time_str.split(':'))
    return (h - 4) * 60 + m


def polar_coordinate_angle(x, y, depot_x, depot_y):
    """Calculate the angle of a point (x, y) with respect to a depot in polar coordinates."""
    delta_x = x - depot_x
    delta_y = y - depot_y
    angle = np.arctan2(delta_y, delta_x)
    return angle if angle >= 0 else angle + 2 * np.pi


def clockwise_angle(angle_ccw):
    """Convierte un ángulo CCW a su equivalente horario en [0, 2π)."""
    return (-angle_ccw) % (2 * np.pi)


def radius(x, y, depot_x, depot_y):
    """
    Calculate the radius of a point (x, y) with respect to a depot (depot_x, depot_y)
    in polar coordinates.
    """
    return np.sqrt((x - depot_x) ** 2 + (y - depot_y) ** 2)


def split_client_demands(df: pd.DataFrame) -> pd.DataFrame:
    """Split demands into two rows: one for gasohol and another for diesel."""
    gasohol_df = df.copy()
    gasohol_df["tipo_combustible"] = "gasohol"
    gasohol_df["demanda_diesel"] = 0

    diesel_df = df.copy()
    diesel_df["tipo_combustible"] = "diesel"
    diesel_df["demanda_gasohol"] = 0

    df_split_demands = (
        pd.concat([gasohol_df, diesel_df], ignore_index=True)
        .sort_values(by=['AN', 'R'])
        .drop_duplicates(subset=['index', 'demanda_gasohol', 'demanda_diesel'], keep='first')
        .assign(old_index=lambda x: x.index)
        .drop(columns=['index'])
        .reset_index(drop=True).reset_index(drop=False)
    )
    
    return df_split_demands


# -----------------------------------------------------------------------------
# Load and Preprocess Data
# -----------------------------------------------------------------------------

df = (
    pd.read_csv('./instancias/50_clientes.csv')
    .reset_index(drop=False)
)

df['E'] = df['ventana_inicio'].apply(time_to_minutes)
df['L'] = df['ventana_fin'].apply(time_to_minutes)

df['AN'] = df.apply(
    lambda row: polar_coordinate_angle(row['x'], row['y'], df.loc[0, 'x'], df.loc[0, 'y']), axis=1
)

df['R'] = df.apply(
    lambda row: radius(row['x'], row['y'], df.loc[0, 'x'], df.loc[0, 'y']), axis=1
)

# Reorder according to polar-coordinate angle and distance
df = (
    df.sort_values(by=['AN', 'R'])
    .rename(columns={'index': 'old_index'})
    .reset_index(drop=True).reset_index(drop=False)
)
# display(df)


# -----------------------------------------------------------------------------
# Problem Parameters
# -----------------------------------------------------------------------------

tipos_cisternas = {
    1: {'cap_gasohol': 5800, 'cap_diesel': 5200, 'costo_fijo': 450, 'costo_km': 2},
    2: {'cap_gasohol': 4000, 'cap_diesel': 4000, 'costo_fijo': 370, 'costo_km': 2}
}

# -----------------------------------------------------------------------------
# Main Algorithm
# -----------------------------------------------------------------------------

def tabu_search_mcvrptw(data: pd.DataFrame, tipos_cisternas: Dict, 
                       clockwise: bool = False, I: int = 1000, 
                       split_demands: bool = False,
                       num_vehiculos_por_tipo: int = 20,
                       velocidad: float = 60, 
                       tiempo_descarga: float = 5):
    """
    Iterated Tabu Search para MCVRPTW.
    
    Basado en Silvestrin (2017) - 'An Iterated Tabu Search for Multi-Compartment Vehicle Routing Problem'
    
    Pseudo-código:
        function ITS()
            s <- SweepConstruction()
            s <- TabuSearch(s)
            for i = 1, ..., I iterations do
                s' <- Perturb(s)
                s <- TabuSearch(s')
                with probability (i / I)^2: s <- s'
            end for
            return the best solution s' found during search
        end function
    """
    df_input = data.copy()
    if clockwise:
        df_input['AN'] = df_input['AN'].apply(clockwise_angle)
    if split_demands:
        df_input = split_client_demands(df_input)

    instance = ProblemInstance(
        df_input, tipos_cisternas, num_vehiculos_por_tipo, 
        velocidad, tiempo_descarga
    )
    visualizer = SolutionVisualizer(instance)
    
    sweep_solver = SweepAlgorithm(instance)
    
    # Construcción inicial con Angular Sweep
    rutas = sweep_solver.forward_sweep()
    visualizer.imprimir_solucion(rutas, 1)
    # visualizer.visualizar_rutas(rutas, "Forward Sweep")

    # Mejora con "2-opt" bidireccional
    rutas = sweep_solver.iterative_improving_sweep(rutas)
    visualizer.imprimir_solucion(rutas, 1)
    visualizer.visualizar_rutas(rutas, "Forward Sweep + 2-opt bidirectional")

    # Iterated Tabu Search
    tabu_solver = SolverTabuSearchMCVRPTW(sweep_solver)
    best_solution = rutas
    best_cost = sum(r.costo_total for r in best_solution)

    for iteration in range(1, I + 1):
        rutas_perturbadas = tabu_solver.perturbation(rutas)
        rutas = tabu_solver.tabu_search(rutas_perturbadas, iteration)

        prob = (iteration / I) ** 2
        if random.random() < prob:
            rutas = rutas_perturbadas
        
        current_cost = sum(r.costo_total for r in rutas)
        if current_cost < best_cost:
            best_solution = rutas
            best_cost = current_cost
            print(f"  [Iteración {iteration}] Nueva mejor solución: ${best_cost:,.2f}")
    
    visualizer.imprimir_solucion(best_solution, 2)
    visualizer.visualizar_rutas(best_solution, "Iterated Tabu Search - Final Solution")
    return best_solution, best_cost


# -----------------------------------------------------------------------------
# Execute
# -----------------------------------------------------------------------------

best_cost_solution = float('inf')
best_config = {}
for cc in [False, True]:
    for sd in [False, True]:
        try:
            print(f"\n--- Clockwise: {cc} | Split Demands: {sd} ---")
            rutas_solucion, costo = tabu_search_mcvrptw(df, tipos_cisternas, clockwise=cc, split_demands=sd, I=50)
            print(f"Solución final con costo total: ${costo:,.2f}")
            if costo < best_cost_solution:
                best_cost_solution = costo
                best_config = {'clockwise': cc, 'split_demands': sd}
        except Exception as e:
            print(f"Error con configuración Clockwise={cc}, Split Demands={sd}: {e}")
            import traceback
            traceback.print_exc()
            raise e
    #     break
    # break

print(f"\n=== Mejor configuración encontrada: Clockwise={best_config['clockwise']}, Split Demands={best_config['split_demands']} con costo total: ${best_cost_solution:,.2f} ===")
# Out:
# --- Clockwise: False | Split Demands: False ---
#
# >>> Vehículos utilizados en Forward Sweep:
#   * Tipo 1: 0/20
#   * Tipo 2: 13/20
#
# ================================================================================
# SOLUCIÓN
# ================================================================================
#
# >>> RESUMEN GENERAL:
#   * Número de rutas: 13
#   * Costo total: $7,282.18
#   * Distancia total: 1236.09 km
#   * Cisternas Tipo 1: 0/20
#   * Cisternas Tipo 2: 13/20
#
# ================================================================================
#
# ================================================================================
# INICIANDO MEJORA ITERATIVA (CLOCKWISE Y COUNTERCLOCKWISE)
# ================================================================================
#
# >>> Iteración global 1
#
#   >>> Intentando mejora en sentido ANTIHORARIO...
#   [Iteración 1 - antihorario] Mejora rutas 0-1: $1117.44 → $1076.14 (ahorro: $41.31)
#   [Iteración 1 - antihorario] Mejora rutas 1-2: $1130.67 → $1050.20 (ahorro: $80.47)
#   [Iteración 1 - antihorario] Mejora rutas 2-3: $1115.61 → $1036.27 (ahorro: $79.34)
#   [Iteración 1 - antihorario] Mejora rutas 2-3: $1036.27 → $998.18 (ahorro: $38.09)
#   [Iteración 1 - antihorario] Mejora rutas 2-3: $998.18 → $955.50 (ahorro: $42.68)
#   [Iteración 1 - antihorario] Mejora rutas 4-5: $1132.78 → $1121.03 (ahorro: $11.75)
#   [Iteración 1 - antihorario] Mejora rutas 7-8: $1021.48 → $989.20 (ahorro: $32.28)
#   [Iteración 1 - antihorario] Mejora rutas 7-8: $989.20 → $979.41 (ahorro: $9.79)
#   [Iteración 1 - antihorario] Mejora rutas 7-8: $979.41 → $979.19 (ahorro: $0.22)
#   [Iteración 1 - antihorario] Mejora rutas 7-8: $979.19 → $956.52 (ahorro: $22.66)
#   [Iteración 1 - antihorario] Mejora rutas 8-9: $968.60 → $959.98 (ahorro: $8.62)
#   [Iteración 1 - antihorario] Mejora rutas 9-10: $919.39 → $909.84 (ahorro: $9.55)
#   [Iteración 1 - antihorario] Mejora rutas 10-11: $1080.65 → $1039.54 (ahorro: $41.12)
#   [Iteración 1 - antihorario] Mejora rutas 11-12: $1153.37 → $1077.63 (ahorro: $75.74)
#   [Iteración 1 - antihorario] Mejora rutas 11-12: $1077.63 → $1006.40 (ahorro: $71.23)
#
# >>> Proceso de mejora (antihorario) completado en 2 iteraciones.
# >>> Vehículos utilizados:
#   * Tipo 1: 0/20
#   * Tipo 2: 13/20
#   >>> Mejora encontrada. Costo actual: $6,717.32
#
#   >>> Intentando mejora en sentido HORARIO...
#   [Iteración 1 - horario] Mejora rutas 1-2: $1143.41 → $1105.47 (ahorro: $37.94)
#   [Iteración 1 - horario] Mejora rutas 4-5: $1080.17 → $1079.61 (ahorro: $0.56)
#   [Iteración 1 - horario] Mejora rutas 4-5: $1079.61 → $1078.90 (ahorro: $0.71)
#   [Iteración 1 - horario] Mejora rutas 4-5: $1078.90 → $1078.36 (ahorro: $0.54)
#   [Iteración 1 - horario] Mejora rutas 9-10: $955.50 → $947.15 (ahorro: $8.35)
#
# >>> Proceso de mejora (horario) completado en 2 iteraciones.
# >>> Vehículos utilizados:
#   * Tipo 1: 0/20
#   * Tipo 2: 13/20
#   >>> Mejora encontrada. Costo actual: $6,669.22
#
# >>> Iteración global 2
#
#   >>> Intentando mejora en sentido ANTIHORARIO...
#
# >>> Proceso de mejora (antihorario) completado en 1 iteraciones.
# >>> Vehículos utilizados:
#   * Tipo 1: 0/20
#   * Tipo 2: 13/20
#   >>> Sin mejoras
#
#   >>> Intentando mejora en sentido HORARIO...
#
# >>> Proceso de mejora (horario) completado en 1 iteraciones.
# >>> Vehículos utilizados:
#   * Tipo 1: 0/20
#   * Tipo 2: 13/20
#   >>> Sin mejoras
#
# >>> No se encontraron más mejoras en ninguna dirección.
#
# ================================================================================
# MEJORA ITERATIVA COMPLETADA EN 2 ITERACIONES GLOBALES
# ================================================================================
#
# ================================================================================
# SOLUCIÓN
# ================================================================================
#
# >>> RESUMEN GENERAL:
#   * Número de rutas: 13
#   * Costo total: $6,669.22
#   * Distancia total: 929.61 km
#   * Cisternas Tipo 1: 0/20
#   * Cisternas Tipo 2: 13/20
#
# ================================================================================
#   [Iteración 1] Nueva mejor solución: $6,447.27
#   [Iteración 2] Nueva mejor solución: $6,414.44
#   [Iteración 3] Nueva mejor solución: $6,055.52
#   [Iteración 4] Nueva mejor solución: $5,976.68
#   [Iteración 15] Nueva mejor solución: $5,596.88
#   [Iteración 16] Nueva mejor solución: $5,594.75
#   [Iteración 29] Nueva mejor solución: $5,571.83
#   [Iteración 30] Nueva mejor solución: $5,120.65
#   [Iteración 31] Nueva mejor solución: $5,115.07
#
# ================================================================================
# SOLUCIÓN
# ================================================================================
#
# >>> RESUMEN GENERAL:
#   * Número de rutas: 9
#   * Costo total: $5,115.07
#   * Distancia total: 892.53 km
#   * Cisternas Tipo 1: 0/20
#   * Cisternas Tipo 2: 9/20
#
# >>> DETALLE DE RUTAS:
#
#   Ruta #1:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 2 → 7 → 10 → 5 → 4 → Depot
#     Carga: Gasohol=2350gal (58.8%), Diésel=2120gal (53.0%)
#     Distancia: 127.49 km
#     Tiempo: 197.5 min
#     Costo: $624.97
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 2 (65.0, 35.0): 50.0 min (04:50) | Ventana: [04:50 - 07:10]
#       - Cliente 7 (65.0, 55.0): 80.0 min (05:20) | Ventana: [04:30 - 07:10]
#       - Cliente 10 (62.0, 77.0): 112.2 min (05:52) | Ventana: [04:40 - 06:00]
#       - Cliente 5 (55.0, 45.0): 155.0 min (06:35) | Ventana: [04:50 - 07:10]
#       - Cliente 4 (53.0, 43.0): 167.8 min (06:48) | Ventana: [06:40 - 07:20]
#     Entregas por cliente:
#       - Cliente 2: G, D
#       - Cliente 7: G, D
#       - Cliente 10: G, D
#       - Cliente 5: G, D
#       - Cliente 4: G, D
#
#   Ruta #2:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 12 → 14 → 17 → 18 → 15 → Depot
#     Carga: Gasohol=2440gal (61.0%), Diésel=2770gal (69.2%)
#     Distancia: 103.96 km
#     Tiempo: 168.5 min
#     Costo: $577.92
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 12 (40.0, 60.0): 40.0 min (04:40) | Ventana: [04:40 - 05:50]
#       - Cliente 14 (31.0, 67.0): 61.4 min (05:01) | Ventana: [04:40 - 06:40]
#       - Cliente 17 (27.0, 69.0): 75.9 min (05:16) | Ventana: [04:30 - 07:00]
#       - Cliente 18 (15.0, 77.0): 100.3 min (05:40) | Ventana: [04:40 - 05:50]
#       - Cliente 15 (30.0, 60.0): 133.0 min (06:13) | Ventana: [05:40 - 06:30]
#     Entregas por cliente:
#       - Cliente 12: G, D
#       - Cliente 14: G, D
#       - Cliente 17: G, D
#       - Cliente 18: G, D
#       - Cliente 15: G, D
#
#   Ruta #3:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 20 → 21 → 22 → 23 → 24 → Depot
#     Carga: Gasohol=2200gal (55.0%), Diésel=2690gal (67.2%)
#     Distancia: 103.35 km
#     Tiempo: 169.8 min
#     Costo: $576.71
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 20 (20.0, 65.0): 50.0 min (04:50) | Ventana: [04:50 - 05:30]
#       - Cliente 21 (15.0, 60.0): 67.1 min (05:07) | Ventana: [04:30 - 06:30]
#       - Cliente 22 (8.0, 56.0): 85.1 min (05:25) | Ventana: [04:30 - 07:00]
#       - Cliente 23 (2.0, 60.0): 102.3 min (05:42) | Ventana: [04:40 - 06:00]
#       - Cliente 24 (2.0, 48.0): 124.3 min (06:04) | Ventana: [05:00 - 07:00]
#     Entregas por cliente:
#       - Cliente 20: G, D
#       - Cliente 21: G, D
#       - Cliente 22: G, D
#       - Cliente 23: G, D
#       - Cliente 24: G, D
#
#   Ruta #4:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 13 → 16 → 19 → 25 → 26 → 27 → 28 → Depot
#     Carga: Gasohol=3000gal (75.0%), Diésel=3710gal (92.8%)
#     Distancia: 96.57 km
#     Tiempo: 174.7 min
#     Costo: $563.13
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 13 (35.0, 40.0): 5.0 min (04:05) | Ventana: [04:00 - 05:20]
#       - Cliente 16 (31.0, 52.0): 27.6 min (04:28) | Ventana: [04:10 - 07:20]
#       - Cliente 19 (24.0, 58.0): 46.9 min (04:47) | Ventana: [04:40 - 05:20]
#       - Cliente 25 (10.0, 43.0): 80.0 min (05:20) | Ventana: [05:20 - 06:00]
#       - Cliente 26 (6.0, 38.0): 96.4 min (05:36) | Ventana: [04:20 - 05:40]
#       - Cliente 27 (5.0, 30.0): 120.0 min (06:00) | Ventana: [06:00 - 07:10]
#       - Cliente 28 (12.0, 24.0): 139.2 min (06:19) | Ventana: [04:20 - 06:20]
#     Entregas por cliente:
#       - Cliente 13: G, D
#       - Cliente 16: G, D
#       - Cliente 19: G, D
#       - Cliente 25: G, D
#       - Cliente 26: G, D
#       - Cliente 27: G, D
#       - Cliente 28: G, D
#
#   Ruta #5:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 45 → 43 → 46 → 50 → 3 → 8 → Depot
#     Carga: Gasohol=2540gal (63.5%), Diésel=3100gal (77.5%)
#     Distancia: 92.80 km
#     Tiempo: 196.5 min
#     Costo: $555.60
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 45 (45.0, 20.0): 18.0 min (04:18) | Ventana: [04:10 - 07:20]
#       - Cliente 43 (45.0, 10.0): 70.0 min (05:10) | Ventana: [05:10 - 06:10]
#       - Cliente 46 (53.0, 12.0): 100.0 min (05:40) | Ventana: [05:40 - 06:50]
#       - Cliente 50 (57.0, 29.0): 127.5 min (06:07) | Ventana: [05:30 - 07:20]
#       - Cliente 3 (56.0, 39.0): 147.5 min (06:28) | Ventana: [05:50 - 07:00]
#       - Cliente 8 (47.0, 47.0): 169.6 min (06:50) | Ventana: [04:40 - 07:30]
#     Entregas por cliente:
#       - Cliente 45: G, D
#       - Cliente 43: G, D
#       - Cliente 46: G, D
#       - Cliente 50: G, D
#       - Cliente 3: G, D
#       - Cliente 8: G, D
#
#   Ruta #6:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 41 → 40 → 34 → 30 → 31 → 32 → 38 → 42 → Depot
#     Carga: Gasohol=3960gal (99.0%), Diésel=3450gal (86.2%)
#     Distancia: 85.09 km
#     Tiempo: 189.1 min
#     Costo: $540.18
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 41 (30.0, 5.0): 50.0 min (04:50) | Ventana: [04:50 - 05:30]
#       - Cliente 40 (24.0, 12.0): 69.2 min (05:09) | Ventana: [04:20 - 05:40]
#       - Cliente 34 (19.0, 21.0): 89.5 min (05:30) | Ventana: [04:20 - 07:20]
#       - Cliente 30 (20.0, 26.0): 104.6 min (05:45) | Ventana: [05:10 - 05:50]
#       - Cliente 31 (18.0, 24.0): 120.0 min (06:00) | Ventana: [06:00 - 07:20]
#       - Cliente 32 (21.0, 24.0): 133.0 min (06:13) | Ventana: [04:10 - 07:30]
#       - Cliente 38 (25.0, 24.0): 147.0 min (06:27) | Ventana: [04:10 - 07:30]
#       - Cliente 42 (36.0, 26.0): 170.0 min (06:50) | Ventana: [06:50 - 07:30]
#     Entregas por cliente:
#       - Cliente 41: G, D
#       - Cliente 40: G, D
#       - Cliente 34: G, D
#       - Cliente 30: G, D
#       - Cliente 31: G, D
#       - Cliente 32: G, D
#       - Cliente 38: G, D
#       - Cliente 42: G, D
#
#   Ruta #7:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 35 → 37 → 29 → 33 → 36 → 39 → Depot
#     Carga: Gasohol=3010gal (75.2%), Diésel=2910gal (72.8%)
#     Distancia: 94.52 km
#     Tiempo: 194.8 min
#     Costo: $559.04
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 35 (26.0, 27.0): 30.0 min (04:30) | Ventana: [04:30 - 07:00]
#       - Cliente 37 (5.0, 5.0): 70.4 min (05:10) | Ventana: [05:10 - 05:50]
#       - Cliente 29 (4.0, 18.0): 93.5 min (05:33) | Ventana: [04:40 - 06:30]
#       - Cliente 33 (15.0, 19.0): 114.5 min (05:54) | Ventana: [04:20 - 07:20]
#       - Cliente 36 (18.0, 18.0): 150.0 min (06:30) | Ventana: [06:30 - 07:20]
#       - Cliente 39 (25.0, 21.0): 167.6 min (06:48) | Ventana: [05:30 - 07:10]
#     Entregas por cliente:
#       - Cliente 35: G, D
#       - Cliente 37: G, D
#       - Cliente 29: G, D
#       - Cliente 33: G, D
#       - Cliente 36: G, D
#       - Cliente 39: G, D
#
#   Ruta #8:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 48 → 47 → 49 → 1 → Depot
#     Carga: Gasohol=1990gal (49.8%), Diésel=2120gal (53.0%)
#     Distancia: 95.83 km
#     Tiempo: 206.2 min
#     Costo: $561.66
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 48 (45.0, 30.0): 50.0 min (04:50) | Ventana: [04:50 - 07:30]
#       - Cliente 47 (67.0, 5.0): 93.3 min (05:33) | Ventana: [05:10 - 05:50]
#       - Cliente 49 (65.0, 20.0): 150.0 min (06:30) | Ventana: [06:30 - 07:10]
#       - Cliente 1 (50.0, 35.0): 181.2 min (07:01) | Ventana: [04:10 - 07:20]
#     Entregas por cliente:
#       - Cliente 48: G, D
#       - Cliente 47: G, D
#       - Cliente 49: G, D
#       - Cliente 1: G, D
#
#   Ruta #9:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 11 → 9 → 6 → 44 → Depot
#     Carga: Gasohol=2140gal (53.5%), Diésel=1950gal (48.8%)
#     Distancia: 92.93 km
#     Tiempo: 132.9 min
#     Costo: $555.85
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 11 (41.0, 49.0): 15.2 min (04:15) | Ventana: [04:10 - 07:30]
#       - Cliente 9 (57.0, 68.0): 50.1 min (04:50) | Ventana: [04:30 - 06:30]
#       - Cliente 6 (61.0, 52.0): 76.6 min (05:17) | Ventana: [05:10 - 06:10]
#       - Cliente 44 (37.0, 31.0): 118.5 min (05:58) | Ventana: [05:20 - 06:00]
#     Entregas por cliente:
#       - Cliente 11: G, D
#       - Cliente 9: G, D
#       - Cliente 6: G, D
#       - Cliente 44: G, D
#
# ================================================================================
# Solución final con costo total: $5,115.07
#
# --- Clockwise: False | Split Demands: True ---
#
# >>> Vehículos utilizados en Forward Sweep:
#   * Tipo 1: 0/20
#   * Tipo 2: 14/20
#
# ================================================================================
# SOLUCIÓN
# ================================================================================
#
# >>> RESUMEN GENERAL:
#   * Número de rutas: 14
#   * Costo total: $7,769.17
#   * Distancia total: 1294.58 km
#   * Cisternas Tipo 1: 0/20
#   * Cisternas Tipo 2: 14/20
#
# ================================================================================
#
# ================================================================================
# INICIANDO MEJORA ITERATIVA (CLOCKWISE Y COUNTERCLOCKWISE)
# ================================================================================
#
# >>> Iteración global 1
#
#   >>> Intentando mejora en sentido ANTIHORARIO...
#   [Iteración 1 - antihorario] Mejora rutas 0-1: $1117.44 → $1076.14 (ahorro: $41.31)
#   [Iteración 1 - antihorario] Mejora rutas 2-3: $1222.24 → $1208.39 (ahorro: $13.85)
#   [Iteración 1 - antihorario] Mejora rutas 2-3: $1208.39 → $1135.74 (ahorro: $72.65)
#   [Iteración 1 - antihorario] Mejora rutas 2-3: $1135.74 → $1132.63 (ahorro: $3.11)
#   [Iteración 1 - antihorario] Mejora rutas 3-4: $1100.69 → $1034.67 (ahorro: $66.02)
#   [Iteración 1 - antihorario] Mejora rutas 6-7: $1007.48 → $995.85 (ahorro: $11.62)
#   [Iteración 1 - antihorario] Mejora rutas 7-8: $1030.50 → $1023.72 (ahorro: $6.78)
#   [Iteración 1 - antihorario] Mejora rutas 8-9: $1013.72 → $1009.81 (ahorro: $3.92)
#   [Iteración 1 - antihorario] Mejora rutas 9-10: $1042.27 → $1024.82 (ahorro: $17.45)
#   [Iteración 1 - antihorario] Mejora rutas 10-11: $1085.23 → $1057.42 (ahorro: $27.80)
#   [Iteración 2 - antihorario] Mejora rutas 7-8: $994.22 → $990.33 (ahorro: $3.89)
#   [Iteración 2 - antihorario] Mejora rutas 9-10: $1023.24 → $1009.69 (ahorro: $13.55)
#
# >>> Proceso de mejora (antihorario) completado en 3 iteraciones.
# >>> Vehículos utilizados:
#   * Tipo 1: 0/20
#   * Tipo 2: 14/20
#   >>> Mejora encontrada. Costo actual: $7,487.21
#
#   >>> Intentando mejora en sentido HORARIO...
#   [Iteración 1 - horario] Mejora rutas 0-1: $1215.78 → $1130.67 (ahorro: $85.11)
#   [Iteración 1 - horario] Mejora rutas 0-1: $1130.67 → $1124.37 (ahorro: $6.31)
#   [Iteración 1 - horario] Mejora rutas 5-6: $990.33 → $983.83 (ahorro: $6.50)
#   [Iteración 1 - horario] Mejora rutas 5-6: $983.83 → $983.55 (ahorro: $0.28)
#   [Iteración 1 - horario] Mejora rutas 5-6: $983.55 → $977.74 (ahorro: $5.81)
#   [Iteración 1 - horario] Mejora rutas 9-10: $1034.67 → $996.88 (ahorro: $37.79)
#   [Iteración 1 - horario] Mejora rutas 10-11: $1018.94 → $1016.65 (ahorro: $2.29)
#   [Iteración 1 - horario] Mejora rutas 11-12: $991.27 → $982.80 (ahorro: $8.47)
#   [Iteración 1 - horario] Mejora rutas 12-13: $1068.59 → $1058.23 (ahorro: $10.36)
#
# >>> Proceso de mejora (horario) completado en 2 iteraciones.
# >>> Vehículos utilizados:
#   * Tipo 1: 0/20
#   * Tipo 2: 14/20
#   >>> Mejora encontrada. Costo actual: $7,324.30
#
# >>> Iteración global 2
#
#   >>> Intentando mejora en sentido ANTIHORARIO...
#   [Iteración 1 - antihorario] Mejora rutas 2-3: $1015.72 → $1008.54 (ahorro: $7.18)
#
# >>> Proceso de mejora (antihorario) completado en 2 iteraciones.
# >>> Vehículos utilizados:
#   * Tipo 1: 0/20
#   * Tipo 2: 14/20
#   >>> Mejora encontrada. Costo actual: $7,317.12
#
#   >>> Intentando mejora en sentido HORARIO...
#
# >>> Proceso de mejora (horario) completado en 1 iteraciones.
# >>> Vehículos utilizados:
#   * Tipo 1: 0/20
#   * Tipo 2: 14/20
#   >>> Sin mejoras
#
# >>> Iteración global 3
#
#   >>> Intentando mejora en sentido ANTIHORARIO...
#
# >>> Proceso de mejora (antihorario) completado en 1 iteraciones.
# >>> Vehículos utilizados:
#   * Tipo 1: 0/20
#   * Tipo 2: 14/20
#   >>> Sin mejoras
#
#   >>> Intentando mejora en sentido HORARIO...
#
# >>> Proceso de mejora (horario) completado en 1 iteraciones.
# >>> Vehículos utilizados:
#   * Tipo 1: 0/20
#   * Tipo 2: 14/20
#   >>> Sin mejoras
#
# >>> No se encontraron más mejoras en ninguna dirección.
#
# ================================================================================
# MEJORA ITERATIVA COMPLETADA EN 3 ITERACIONES GLOBALES
# ================================================================================
#
# ================================================================================
# SOLUCIÓN
# ================================================================================
#
# >>> RESUMEN GENERAL:
#   * Número de rutas: 14
#   * Costo total: $7,317.12
#   * Distancia total: 1068.56 km
#   * Cisternas Tipo 1: 0/20
#   * Cisternas Tipo 2: 14/20
#
# ================================================================================
#   [Iteración 1] Nueva mejor solución: $7,034.37
#   [Iteración 29] Nueva mejor solución: $6,667.39
#   [Iteración 46] Nueva mejor solución: $6,660.20
#   [Iteración 48] Nueva mejor solución: $6,659.86
#   [Iteración 49] Nueva mejor solución: $6,659.79
#
# ================================================================================
# SOLUCIÓN
# ================================================================================
#
# >>> RESUMEN GENERAL:
#   * Número de rutas: 12
#   * Costo total: $6,659.79
#   * Distancia total: 1109.90 km
#   * Cisternas Tipo 1: 0/20
#   * Cisternas Tipo 2: 12/20
#
# >>> DETALLE DE RUTAS:
#
#   Ruta #1:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 42 → 41 → 39 → 37 → 38 → 23 → 24 → 29 → Depot
#     Carga: Gasohol=1860gal (46.5%), Diésel=1600gal (40.0%)
#     Distancia: 98.77 km
#     Tiempo: 139.7 min
#     Costo: $567.54
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 42 (15.0, 60.0): 32.0 min (04:32) | Ventana: [04:30 - 06:30]
#       - Cliente 41 (15.0, 60.0): 37.0 min (04:37) | Ventana: [04:30 - 06:30]
#       - Cliente 39 (20.0, 65.0): 50.0 min (04:50) | Ventana: [04:50 - 05:30]
#       - Cliente 37 (24.0, 58.0): 63.1 min (05:03) | Ventana: [04:40 - 05:20]
#       - Cliente 38 (24.0, 58.0): 68.1 min (05:08) | Ventana: [04:40 - 05:20]
#       - Cliente 23 (40.0, 60.0): 89.2 min (05:29) | Ventana: [04:40 - 05:50]
#       - Cliente 24 (40.0, 60.0): 94.2 min (05:34) | Ventana: [04:40 - 05:50]
#       - Cliente 29 (30.0, 60.0): 109.2 min (05:49) | Ventana: [05:40 - 06:30]
#     Entregas por cliente:
#       - Cliente 42: D
#       - Cliente 41: G
#       - Cliente 39: G
#       - Cliente 37: G
#       - Cliente 38: D
#       - Cliente 23: G
#       - Cliente 24: D
#       - Cliente 29: G
#
#   Ruta #2:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 17 → 18 → 20 → 19 → 14 → 13 → 12 → 11 → 7 → 8 → 15 → 16 → Depot
#     Carga: Gasohol=2840gal (71.0%), Diésel=2560gal (64.0%)
#     Distancia: 113.38 km
#     Tiempo: 204.2 min
#     Costo: $596.77
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 17 (57.0, 68.0): 39.7 min (04:40) | Ventana: [04:30 - 06:30]
#       - Cliente 18 (57.0, 68.0): 44.7 min (04:45) | Ventana: [04:30 - 06:30]
#       - Cliente 20 (62.0, 77.0): 60.0 min (04:60) | Ventana: [04:40 - 06:00]
#       - Cliente 19 (62.0, 77.0): 65.0 min (05:05) | Ventana: [04:40 - 06:00]
#       - Cliente 14 (65.0, 55.0): 92.2 min (05:32) | Ventana: [04:30 - 07:10]
#       - Cliente 13 (65.0, 55.0): 97.2 min (05:37) | Ventana: [04:30 - 07:10]
#       - Cliente 12 (61.0, 52.0): 107.2 min (05:47) | Ventana: [05:10 - 06:10]
#       - Cliente 11 (61.0, 52.0): 112.2 min (05:52) | Ventana: [05:10 - 06:10]
#       - Cliente 7 (53.0, 43.0): 160.0 min (06:40) | Ventana: [06:40 - 07:20]
#       - Cliente 8 (53.0, 43.0): 165.0 min (06:45) | Ventana: [06:40 - 07:20]
#       - Cliente 15 (47.0, 47.0): 177.2 min (06:57) | Ventana: [04:40 - 07:30]
#       - Cliente 16 (47.0, 47.0): 182.2 min (07:02) | Ventana: [04:40 - 07:30]
#     Entregas por cliente:
#       - Cliente 17: G
#       - Cliente 18: D
#       - Cliente 20: D
#       - Cliente 19: G
#       - Cliente 14: D
#       - Cliente 13: G
#       - Cliente 12: D
#       - Cliente 11: G
#       - Cliente 7: G
#       - Cliente 8: D
#       - Cliente 15: G
#       - Cliente 16: D
#
#   Ruta #3:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 10 → 9 → 6 → 4 → 3 → 100 → 99 → 98 → 97 → Depot
#     Carga: Gasohol=2080gal (52.0%), Diésel=2320gal (58.0%)
#     Distancia: 93.87 km
#     Tiempo: 210.4 min
#     Costo: $557.75
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 10 (55.0, 45.0): 50.0 min (04:50) | Ventana: [04:50 - 07:10]
#       - Cliente 9 (55.0, 45.0): 55.0 min (04:55) | Ventana: [04:50 - 07:10]
#       - Cliente 6 (56.0, 39.0): 110.0 min (05:50) | Ventana: [05:50 - 07:00]
#       - Cliente 4 (65.0, 35.0): 124.8 min (06:05) | Ventana: [04:50 - 07:10]
#       - Cliente 3 (65.0, 35.0): 129.8 min (06:10) | Ventana: [04:50 - 07:10]
#       - Cliente 100 (57.0, 29.0): 144.8 min (06:25) | Ventana: [05:30 - 07:20]
#       - Cliente 99 (57.0, 29.0): 149.8 min (06:30) | Ventana: [05:30 - 07:20]
#       - Cliente 98 (65.0, 20.0): 166.9 min (06:47) | Ventana: [06:30 - 07:10]
#       - Cliente 97 (65.0, 20.0): 171.9 min (06:52) | Ventana: [06:30 - 07:10]
#     Entregas por cliente:
#       - Cliente 10: D
#       - Cliente 9: G
#       - Cliente 6: D
#       - Cliente 4: D
#       - Cliente 3: G
#       - Cliente 100: D
#       - Cliente 99: G
#       - Cliente 98: D
#       - Cliente 97: G
#
#   Ruta #4:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 40 → 35 → 36 → 34 → 33 → 28 → 27 → 30 → 22 → 21 → Depot
#     Carga: Gasohol=2110gal (52.8%), Diésel=3320gal (83.0%)
#     Distancia: 103.29 km
#     Tiempo: 169.8 min
#     Costo: $576.59
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 40 (20.0, 65.0): 50.0 min (04:50) | Ventana: [04:50 - 05:30]
#       - Cliente 35 (15.0, 77.0): 68.0 min (05:08) | Ventana: [04:40 - 05:50]
#       - Cliente 36 (15.0, 77.0): 73.0 min (05:13) | Ventana: [04:40 - 05:50]
#       - Cliente 34 (27.0, 69.0): 92.4 min (05:32) | Ventana: [04:30 - 07:00]
#       - Cliente 33 (27.0, 69.0): 97.4 min (05:37) | Ventana: [04:30 - 07:00]
#       - Cliente 28 (31.0, 67.0): 106.9 min (05:47) | Ventana: [04:40 - 06:40]
#       - Cliente 27 (31.0, 67.0): 111.9 min (05:52) | Ventana: [04:40 - 06:40]
#       - Cliente 30 (30.0, 60.0): 124.0 min (06:04) | Ventana: [05:40 - 06:30]
#       - Cliente 22 (41.0, 49.0): 144.5 min (06:25) | Ventana: [04:10 - 07:30]
#       - Cliente 21 (41.0, 49.0): 149.5 min (06:30) | Ventana: [04:10 - 07:30]
#     Entregas por cliente:
#       - Cliente 40: D
#       - Cliente 35: G
#       - Cliente 36: D
#       - Cliente 34: D
#       - Cliente 33: G
#       - Cliente 28: D
#       - Cliente 27: G
#       - Cliente 30: D
#       - Cliente 22: D
#       - Cliente 21: G
#
#   Ruta #5:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 43 → 44 → 45 → 46 → 47 → 48 → Depot
#     Carga: Gasohol=1420gal (35.5%), Diésel=1370gal (34.2%)
#     Distancia: 88.88 km
#     Tiempo: 118.9 min
#     Costo: $547.77
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 43 (8.0, 56.0): 34.2 min (04:34) | Ventana: [04:30 - 07:00]
#       - Cliente 44 (8.0, 56.0): 39.2 min (04:39) | Ventana: [04:30 - 07:00]
#       - Cliente 45 (2.0, 60.0): 51.4 min (04:51) | Ventana: [04:40 - 06:00]
#       - Cliente 46 (2.0, 60.0): 56.4 min (04:56) | Ventana: [04:40 - 06:00]
#       - Cliente 47 (2.0, 48.0): 73.4 min (05:13) | Ventana: [05:00 - 07:00]
#       - Cliente 48 (2.0, 48.0): 78.4 min (05:18) | Ventana: [05:00 - 07:00]
#     Entregas por cliente:
#       - Cliente 43: G
#       - Cliente 44: D
#       - Cliente 45: G
#       - Cliente 46: D
#       - Cliente 47: G
#       - Cliente 48: D
#
#   Ruta #6:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 76 → 59 → 52 → 51 → 50 → 49 → 32 → 31 → Depot
#     Carga: Gasohol=2040gal (51.0%), Diésel=1980gal (49.5%)
#     Distancia: 85.41 km
#     Tiempo: 170.2 min
#     Costo: $540.81
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 76 (25.0, 24.0): 14.9 min (04:15) | Ventana: [04:10 - 07:30]
#       - Cliente 59 (20.0, 26.0): 70.0 min (05:10) | Ventana: [05:10 - 05:50]
#       - Cliente 52 (6.0, 38.0): 93.4 min (05:33) | Ventana: [04:20 - 05:40]
#       - Cliente 51 (6.0, 38.0): 98.4 min (05:38) | Ventana: [04:20 - 05:40]
#       - Cliente 50 (10.0, 43.0): 109.8 min (05:50) | Ventana: [05:20 - 06:00]
#       - Cliente 49 (10.0, 43.0): 114.8 min (05:55) | Ventana: [05:20 - 06:00]
#       - Cliente 32 (31.0, 52.0): 142.7 min (06:23) | Ventana: [04:10 - 07:20]
#       - Cliente 31 (31.0, 52.0): 147.7 min (06:28) | Ventana: [04:10 - 07:20]
#     Entregas por cliente:
#       - Cliente 76: D
#       - Cliente 59: G
#       - Cliente 52: D
#       - Cliente 51: G
#       - Cliente 50: D
#       - Cliente 49: G
#       - Cliente 32: D
#       - Cliente 31: G
#
#   Ruta #7:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 25 → 26 → 60 → 57 → 58 → 71 → 72 → 62 → 61 → Depot
#     Carga: Gasohol=1890gal (47.2%), Diésel=3040gal (76.0%)
#     Distancia: 83.66 km
#     Tiempo: 196.2 min
#     Costo: $537.31
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 25 (35.0, 40.0): 5.0 min (04:05) | Ventana: [04:00 - 05:20]
#       - Cliente 26 (35.0, 40.0): 10.0 min (04:10) | Ventana: [04:00 - 05:20]
#       - Cliente 60 (20.0, 26.0): 70.0 min (05:10) | Ventana: [05:10 - 05:50]
#       - Cliente 57 (4.0, 18.0): 92.9 min (05:33) | Ventana: [04:40 - 06:30]
#       - Cliente 58 (4.0, 18.0): 97.9 min (05:38) | Ventana: [04:40 - 06:30]
#       - Cliente 71 (18.0, 18.0): 150.0 min (06:30) | Ventana: [06:30 - 07:20]
#       - Cliente 72 (18.0, 18.0): 155.0 min (06:35) | Ventana: [06:30 - 07:20]
#       - Cliente 62 (18.0, 24.0): 166.0 min (06:46) | Ventana: [06:00 - 07:20]
#       - Cliente 61 (18.0, 24.0): 171.0 min (06:51) | Ventana: [06:00 - 07:20]
#     Entregas por cliente:
#       - Cliente 25: G
#       - Cliente 26: D
#       - Cliente 60: D
#       - Cliente 57: G
#       - Cliente 58: D
#       - Cliente 71: G
#       - Cliente 72: D
#       - Cliente 62: D
#       - Cliente 61: G
#
#   Ruta #8:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 80 → 79 → 74 → 73 → Depot
#     Carga: Gasohol=1040gal (26.0%), Diésel=700gal (17.5%)
#     Distancia: 88.17 km
#     Tiempo: 122.4 min
#     Costo: $546.34
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 80 (24.0, 12.0): 25.5 min (04:25) | Ventana: [04:20 - 05:40]
#       - Cliente 79 (24.0, 12.0): 30.5 min (04:30) | Ventana: [04:20 - 05:40]
#       - Cliente 74 (5.0, 5.0): 70.0 min (05:10) | Ventana: [05:10 - 05:50]
#       - Cliente 73 (5.0, 5.0): 75.0 min (05:15) | Ventana: [05:10 - 05:50]
#     Entregas por cliente:
#       - Cliente 80: D
#       - Cliente 79: G
#       - Cliente 74: D
#       - Cliente 73: G
#
#   Ruta #9:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 56 → 55 → 66 → 65 → 68 → 67 → 64 → 63 → 78 → 77 → 87 → 83 → 84 → Depot
#     Carga: Gasohol=3370gal (84.2%), Diésel=2570gal (64.2%)
#     Distancia: 74.18 km
#     Tiempo: 189.1 min
#     Costo: $518.36
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 56 (12.0, 24.0): 25.5 min (04:25) | Ventana: [04:20 - 06:20]
#       - Cliente 55 (12.0, 24.0): 30.5 min (04:30) | Ventana: [04:20 - 06:20]
#       - Cliente 66 (15.0, 19.0): 41.3 min (04:41) | Ventana: [04:20 - 07:20]
#       - Cliente 65 (15.0, 19.0): 46.3 min (04:46) | Ventana: [04:20 - 07:20]
#       - Cliente 68 (19.0, 21.0): 55.8 min (04:56) | Ventana: [04:20 - 07:20]
#       - Cliente 67 (19.0, 21.0): 60.8 min (05:01) | Ventana: [04:20 - 07:20]
#       - Cliente 64 (21.0, 24.0): 69.4 min (05:09) | Ventana: [04:10 - 07:30]
#       - Cliente 63 (21.0, 24.0): 74.4 min (05:14) | Ventana: [04:10 - 07:30]
#       - Cliente 78 (25.0, 21.0): 90.0 min (05:30) | Ventana: [05:30 - 07:10]
#       - Cliente 77 (25.0, 21.0): 95.0 min (05:35) | Ventana: [05:30 - 07:10]
#       - Cliente 87 (37.0, 31.0): 115.6 min (05:56) | Ventana: [05:20 - 06:00]
#       - Cliente 83 (36.0, 26.0): 170.0 min (06:50) | Ventana: [06:50 - 07:30]
#       - Cliente 84 (36.0, 26.0): 175.0 min (06:55) | Ventana: [06:50 - 07:30]
#     Entregas por cliente:
#       - Cliente 56: D
#       - Cliente 55: G
#       - Cliente 66: D
#       - Cliente 65: G
#       - Cliente 68: D
#       - Cliente 67: G
#       - Cliente 64: D
#       - Cliente 63: G
#       - Cliente 78: D
#       - Cliente 77: G
#       - Cliente 87: G
#       - Cliente 83: G
#       - Cliente 84: D
#
#   Ruta #10:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 82 → 81 → 54 → 53 → Depot
#     Carga: Gasohol=790gal (19.8%), Diésel=1000gal (25.0%)
#     Distancia: 96.18 km
#     Tiempo: 160.4 min
#     Costo: $562.37
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 82 (30.0, 5.0): 50.0 min (04:50) | Ventana: [04:50 - 05:30]
#       - Cliente 81 (30.0, 5.0): 55.0 min (04:55) | Ventana: [04:50 - 05:30]
#       - Cliente 54 (5.0, 30.0): 120.0 min (06:00) | Ventana: [06:00 - 07:10]
#       - Cliente 53 (5.0, 30.0): 125.0 min (06:05) | Ventana: [06:00 - 07:10]
#     Entregas por cliente:
#       - Cliente 82: D
#       - Cliente 81: G
#       - Cliente 54: D
#       - Cliente 53: G
#
#   Ruta #11:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 88 → 69 → 70 → 75 → 90 → 89 → 96 → 5 → 1 → 2 → 95 → Depot
#     Carga: Gasohol=2740gal (68.5%), Diésel=2710gal (67.8%)
#     Distancia: 89.41 km
#     Tiempo: 219.9 min
#     Costo: $548.82
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 88 (37.0, 31.0): 80.0 min (05:20) | Ventana: [05:20 - 06:00]
#       - Cliente 69 (26.0, 27.0): 96.7 min (05:37) | Ventana: [04:30 - 07:00]
#       - Cliente 70 (26.0, 27.0): 101.7 min (05:42) | Ventana: [04:30 - 07:00]
#       - Cliente 75 (25.0, 24.0): 109.9 min (05:50) | Ventana: [04:10 - 07:30]
#       - Cliente 90 (45.0, 20.0): 135.3 min (06:15) | Ventana: [04:10 - 07:20]
#       - Cliente 89 (45.0, 20.0): 140.3 min (06:20) | Ventana: [04:10 - 07:20]
#       - Cliente 96 (45.0, 30.0): 155.3 min (06:35) | Ventana: [04:50 - 07:30]
#       - Cliente 5 (56.0, 39.0): 174.5 min (06:54) | Ventana: [05:50 - 07:00]
#       - Cliente 1 (50.0, 35.0): 186.7 min (07:07) | Ventana: [04:10 - 07:20]
#       - Cliente 2 (50.0, 35.0): 191.7 min (07:12) | Ventana: [04:10 - 07:20]
#       - Cliente 95 (45.0, 30.0): 203.8 min (07:24) | Ventana: [04:50 - 07:30]
#     Entregas por cliente:
#       - Cliente 88: D
#       - Cliente 69: G
#       - Cliente 70: D
#       - Cliente 75: G
#       - Cliente 90: D
#       - Cliente 89: G
#       - Cliente 96: D
#       - Cliente 5: G
#       - Cliente 1: G
#       - Cliente 2: D
#       - Cliente 95: G
#
#   Ruta #12:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 94 → 93 → 92 → 91 → 86 → 85 → Depot
#     Carga: Gasohol=1450gal (36.2%), Diésel=1650gal (41.2%)
#     Distancia: 94.69 km
#     Tiempo: 155.2 min
#     Costo: $559.38
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 94 (67.0, 5.0): 70.0 min (05:10) | Ventana: [05:10 - 05:50]
#       - Cliente 93 (67.0, 5.0): 75.0 min (05:15) | Ventana: [05:10 - 05:50]
#       - Cliente 92 (53.0, 12.0): 100.0 min (05:40) | Ventana: [05:40 - 06:50]
#       - Cliente 91 (53.0, 12.0): 105.0 min (05:45) | Ventana: [05:40 - 06:50]
#       - Cliente 86 (45.0, 10.0): 118.2 min (05:58) | Ventana: [05:10 - 06:10]
#       - Cliente 85 (45.0, 10.0): 123.2 min (06:03) | Ventana: [05:10 - 06:10]
#     Entregas por cliente:
#       - Cliente 94: D
#       - Cliente 93: G
#       - Cliente 92: D
#       - Cliente 91: G
#       - Cliente 86: D
#       - Cliente 85: G
#
# ================================================================================
# Solución final con costo total: $6,659.79
#
# --- Clockwise: True | Split Demands: False ---
#
# >>> Vehículos utilizados en Forward Sweep:
#   * Tipo 1: 0/20
#   * Tipo 2: 12/20
#
# ================================================================================
# SOLUCIÓN
# ================================================================================
#
# >>> RESUMEN GENERAL:
#   * Número de rutas: 12
#   * Costo total: $6,678.09
#   * Distancia total: 1119.05 km
#   * Cisternas Tipo 1: 0/20
#   * Cisternas Tipo 2: 12/20
#
# ================================================================================
#
# ================================================================================
# INICIANDO MEJORA ITERATIVA (CLOCKWISE Y COUNTERCLOCKWISE)
# ================================================================================
#
# >>> Iteración global 1
#
#   >>> Intentando mejora en sentido ANTIHORARIO...
#   [Iteración 1 - antihorario] Mejora rutas 1-2: $1026.43 → $1004.58 (ahorro: $21.85)
#   [Iteración 1 - antihorario] Mejora rutas 3-4: $1145.08 → $1125.98 (ahorro: $19.10)
#   [Iteración 1 - antihorario] Mejora rutas 3-4: $1125.98 → $1093.89 (ahorro: $32.09)
#   [Iteración 1 - antihorario] Mejora rutas 3-4: $1093.89 → $1085.91 (ahorro: $7.99)
#   [Iteración 1 - antihorario] Mejora rutas 3-4: $1085.91 → $1060.14 (ahorro: $25.77)
#   [Iteración 1 - antihorario] Mejora rutas 5-6: $1070.95 → $1059.38 (ahorro: $11.57)
#   [Iteración 1 - antihorario] Mejora rutas 6-7: $987.35 → $982.84 (ahorro: $4.51)
#   [Iteración 1 - antihorario] Mejora rutas 7-8: $1099.37 → $1001.79 (ahorro: $97.59)
#
# >>> Proceso de mejora (antihorario) completado en 2 iteraciones.
# >>> Vehículos utilizados:
#   * Tipo 1: 0/20
#   * Tipo 2: 12/20
#   >>> Mejora encontrada. Costo actual: $6,457.63
#
#   >>> Intentando mejora en sentido HORARIO...
#   [Iteración 1 - horario] Mejora rutas 0-1: $1143.34 → $1123.33 (ahorro: $20.01)
#   [Iteración 1 - horario] Mejora rutas 0-1: $1123.33 → $1107.76 (ahorro: $15.57)
#   [Iteración 1 - horario] Mejora rutas 1-2: $1077.20 → $1029.30 (ahorro: $47.91)
#   [Iteración 1 - horario] Mejora rutas 7-8: $1060.14 → $1059.25 (ahorro: $0.89)
#   [Iteración 1 - horario] Mejora rutas 9-10: $1004.58 → $949.82 (ahorro: $54.76)
#   [Iteración 1 - horario] Mejora rutas 10-11: $973.78 → $962.03 (ahorro: $11.74)
#   [Iteración 1 - horario] Mejora rutas 10-11: $962.03 → $947.95 (ahorro: $14.09)
#
# >>> Proceso de mejora (horario) completado en 2 iteraciones.
# >>> Vehículos utilizados:
#   * Tipo 1: 0/20
#   * Tipo 2: 12/20
#   >>> Mejora encontrada. Costo actual: $6,292.67
#
# >>> Iteración global 2
#
#   >>> Intentando mejora en sentido ANTIHORARIO...
#   [Iteración 1 - antihorario] Mejora rutas 3-4: $1059.25 → $1058.18 (ahorro: $1.07)
#   [Iteración 1 - antihorario] Mejora rutas 3-4: $1058.18 → $1057.91 (ahorro: $0.27)
#   [Iteración 1 - antihorario] Mejora rutas 9-10: $1029.30 → $1014.04 (ahorro: $15.25)
#
# >>> Proceso de mejora (antihorario) completado en 2 iteraciones.
# >>> Vehículos utilizados:
#   * Tipo 1: 0/20
#   * Tipo 2: 12/20
#   >>> Mejora encontrada. Costo actual: $6,276.07
#
#   >>> Intentando mejora en sentido HORARIO...
#
# >>> Proceso de mejora (horario) completado en 1 iteraciones.
# >>> Vehículos utilizados:
#   * Tipo 1: 0/20
#   * Tipo 2: 12/20
#   >>> Sin mejoras
#
# >>> Iteración global 3
#
#   >>> Intentando mejora en sentido ANTIHORARIO...
#
# >>> Proceso de mejora (antihorario) completado en 1 iteraciones.
# >>> Vehículos utilizados:
#   * Tipo 1: 0/20
#   * Tipo 2: 12/20
#   >>> Sin mejoras
#
#   >>> Intentando mejora en sentido HORARIO...
#
# >>> Proceso de mejora (horario) completado en 1 iteraciones.
# >>> Vehículos utilizados:
#   * Tipo 1: 0/20
#   * Tipo 2: 12/20
#   >>> Sin mejoras
#
# >>> No se encontraron más mejoras en ninguna dirección.
#
# ================================================================================
# MEJORA ITERATIVA COMPLETADA EN 3 ITERACIONES GLOBALES
# ================================================================================
#
# ================================================================================
# SOLUCIÓN
# ================================================================================
#
# >>> RESUMEN GENERAL:
#   * Número de rutas: 12
#   * Costo total: $6,276.07
#   * Distancia total: 918.04 km
#   * Cisternas Tipo 1: 0/20
#   * Cisternas Tipo 2: 12/20
#
# ================================================================================
#   [Iteración 1] Nueva mejor solución: $6,034.58
#   [Iteración 2] Nueva mejor solución: $6,018.50
#   [Iteración 4] Nueva mejor solución: $5,607.65
#   [Iteración 5] Nueva mejor solución: $5,555.19
#   [Iteración 6] Nueva mejor solución: $5,551.84
#   [Iteración 22] Nueva mejor solución: $5,537.14
#   [Iteración 29] Nueva mejor solución: $5,527.37
#   [Iteración 30] Nueva mejor solución: $5,521.42
#
# ================================================================================
# SOLUCIÓN
# ================================================================================
#
# >>> RESUMEN GENERAL:
#   * Número de rutas: 10
#   * Costo total: $5,521.42
#   * Distancia total: 910.71 km
#   * Cisternas Tipo 1: 0/20
#   * Cisternas Tipo 2: 10/20
#
# >>> DETALLE DE RUTAS:
#
#   Ruta #1:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 13 → 50 → 49 → 2 → Depot
#     Carga: Gasohol=2140gal (53.5%), Diésel=2090gal (52.2%)
#     Distancia: 86.64 km
#     Tiempo: 215.0 min
#     Costo: $543.28
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 13 (35.0, 40.0): 5.0 min (04:05) | Ventana: [04:00 - 05:20]
#       - Cliente 50 (57.0, 29.0): 90.0 min (05:30) | Ventana: [05:30 - 07:20]
#       - Cliente 49 (65.0, 20.0): 150.0 min (06:30) | Ventana: [06:30 - 07:10]
#       - Cliente 2 (65.0, 35.0): 175.0 min (06:55) | Ventana: [04:50 - 07:10]
#     Entregas por cliente:
#       - Cliente 13: G, D
#       - Cliente 50: G, D
#       - Cliente 49: G, D
#       - Cliente 2: G, D
#
#   Ruta #2:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 47 → 44 → Depot
#     Carga: Gasohol=920gal (23.0%), Diésel=1290gal (32.2%)
#     Distancia: 88.03 km
#     Tiempo: 134.2 min
#     Costo: $546.07
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 47 (67.0, 5.0): 70.0 min (05:10) | Ventana: [05:10 - 05:50]
#       - Cliente 44 (37.0, 31.0): 119.7 min (05:60) | Ventana: [05:20 - 06:00]
#     Entregas por cliente:
#       - Cliente 47: G, D
#       - Cliente 44: G, D
#
#   Ruta #3:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 35 → 38 → 32 → 28 → 29 → 34 → 39 → 42 → Depot
#     Carga: Gasohol=3800gal (95.0%), Diésel=3770gal (94.2%)
#     Distancia: 80.64 km
#     Tiempo: 189.1 min
#     Costo: $531.28
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 35 (26.0, 27.0): 30.0 min (04:30) | Ventana: [04:30 - 07:00]
#       - Cliente 38 (25.0, 24.0): 43.2 min (04:43) | Ventana: [04:10 - 07:30]
#       - Cliente 32 (21.0, 24.0): 57.2 min (04:57) | Ventana: [04:10 - 07:30]
#       - Cliente 28 (12.0, 24.0): 76.2 min (05:16) | Ventana: [04:20 - 06:20]
#       - Cliente 29 (4.0, 18.0): 96.2 min (05:36) | Ventana: [04:40 - 06:30]
#       - Cliente 34 (19.0, 21.0): 121.5 min (06:01) | Ventana: [04:20 - 07:20]
#       - Cliente 39 (25.0, 21.0): 137.5 min (06:17) | Ventana: [05:30 - 07:10]
#       - Cliente 42 (36.0, 26.0): 170.0 min (06:50) | Ventana: [06:50 - 07:30]
#     Entregas por cliente:
#       - Cliente 35: G, D
#       - Cliente 38: G, D
#       - Cliente 32: G, D
#       - Cliente 28: G, D
#       - Cliente 29: G, D
#       - Cliente 34: G, D
#       - Cliente 39: G, D
#       - Cliente 42: G, D
#
#   Ruta #4:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 30 → 37 → 33 → 36 → 31 → Depot
#     Carga: Gasohol=2710gal (67.8%), Diésel=2390gal (59.8%)
#     Distancia: 89.92 km
#     Tiempo: 196.2 min
#     Costo: $549.83
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 30 (20.0, 26.0): 70.0 min (05:10) | Ventana: [05:10 - 05:50]
#       - Cliente 37 (5.0, 5.0): 105.8 min (05:46) | Ventana: [05:10 - 05:50]
#       - Cliente 33 (15.0, 19.0): 133.0 min (06:13) | Ventana: [04:20 - 07:20]
#       - Cliente 36 (18.0, 18.0): 150.0 min (06:30) | Ventana: [06:30 - 07:20]
#       - Cliente 31 (18.0, 24.0): 166.0 min (06:46) | Ventana: [06:00 - 07:20]
#     Entregas por cliente:
#       - Cliente 30: G, D
#       - Cliente 37: G, D
#       - Cliente 33: G, D
#       - Cliente 36: G, D
#       - Cliente 31: G, D
#
#   Ruta #5:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 22 → 24 → 25 → 26 → 27 → Depot
#     Carga: Gasohol=2260gal (56.5%), Diésel=2550gal (63.7%)
#     Distancia: 98.52 km
#     Tiempo: 160.4 min
#     Costo: $567.04
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 22 (8.0, 56.0): 34.2 min (04:34) | Ventana: [04:30 - 07:00]
#       - Cliente 24 (2.0, 48.0): 60.0 min (05:00) | Ventana: [05:00 - 07:00]
#       - Cliente 25 (10.0, 43.0): 80.0 min (05:20) | Ventana: [05:20 - 06:00]
#       - Cliente 26 (6.0, 38.0): 96.4 min (05:36) | Ventana: [04:20 - 05:40]
#       - Cliente 27 (5.0, 30.0): 120.0 min (06:00) | Ventana: [06:00 - 07:10]
#     Entregas por cliente:
#       - Cliente 22: G, D
#       - Cliente 24: G, D
#       - Cliente 25: G, D
#       - Cliente 26: G, D
#       - Cliente 27: G, D
#
#   Ruta #6:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 23 → 21 → 12 → Depot
#     Carga: Gasohol=1280gal (32.0%), Diésel=1710gal (42.8%)
#     Distancia: 104.90 km
#     Tiempo: 134.9 min
#     Costo: $579.79
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 23 (2.0, 60.0): 41.4 min (04:41) | Ventana: [04:40 - 06:00]
#       - Cliente 21 (15.0, 60.0): 64.4 min (05:04) | Ventana: [04:30 - 06:30]
#       - Cliente 12 (40.0, 60.0): 99.4 min (05:39) | Ventana: [04:40 - 05:50]
#     Entregas por cliente:
#       - Cliente 23: G, D
#       - Cliente 21: G, D
#       - Cliente 12: G, D
#
#   Ruta #7:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 19 → 20 → 18 → 17 → 14 → 15 → 16 → Depot
#     Carga: Gasohol=3100gal (77.5%), Diésel=3720gal (93.0%)
#     Distancia: 98.05 km
#     Tiempo: 182.6 min
#     Costo: $566.10
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 19 (24.0, 58.0): 40.0 min (04:40) | Ventana: [04:40 - 05:20]
#       - Cliente 20 (20.0, 65.0): 58.1 min (04:58) | Ventana: [04:50 - 05:30]
#       - Cliente 18 (15.0, 77.0): 81.1 min (05:21) | Ventana: [04:40 - 05:50]
#       - Cliente 17 (27.0, 69.0): 105.5 min (05:45) | Ventana: [04:30 - 07:00]
#       - Cliente 14 (31.0, 67.0): 120.0 min (05:60) | Ventana: [04:40 - 06:40]
#       - Cliente 15 (30.0, 60.0): 137.0 min (06:17) | Ventana: [05:40 - 06:30]
#       - Cliente 16 (31.0, 52.0): 155.1 min (06:35) | Ventana: [04:10 - 07:20]
#     Entregas por cliente:
#       - Cliente 19: G, D
#       - Cliente 20: G, D
#       - Cliente 18: G, D
#       - Cliente 17: G, D
#       - Cliente 14: G, D
#       - Cliente 15: G, D
#       - Cliente 16: G, D
#
#   Ruta #8:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 40 → 41 → 43 → 46 → 45 → Depot
#     Carga: Gasohol=2180gal (54.5%), Diésel=2380gal (59.5%)
#     Distancia: 88.11 km
#     Tiempo: 149.3 min
#     Costo: $546.23
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 40 (24.0, 12.0): 25.5 min (04:25) | Ventana: [04:20 - 05:40]
#       - Cliente 41 (30.0, 5.0): 50.0 min (04:50) | Ventana: [04:50 - 05:30]
#       - Cliente 43 (45.0, 10.0): 75.8 min (05:16) | Ventana: [05:10 - 06:10]
#       - Cliente 46 (53.0, 12.0): 100.0 min (05:40) | Ventana: [05:40 - 06:50]
#       - Cliente 45 (45.0, 20.0): 121.3 min (06:01) | Ventana: [04:10 - 07:20]
#     Entregas por cliente:
#       - Cliente 40: G, D
#       - Cliente 41: G, D
#       - Cliente 43: G, D
#       - Cliente 46: G, D
#       - Cliente 45: G, D
#
#   Ruta #9:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 11 → 8 → 5 → 3 → 4 → 1 → 48 → Depot
#     Carga: Gasohol=3060gal (76.5%), Diésel=3380gal (84.5%)
#     Distancia: 67.68 km
#     Tiempo: 216.8 min
#     Costo: $505.36
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 11 (41.0, 49.0): 15.2 min (04:15) | Ventana: [04:10 - 07:30]
#       - Cliente 8 (47.0, 47.0): 40.0 min (04:40) | Ventana: [04:40 - 07:30]
#       - Cliente 5 (55.0, 45.0): 58.2 min (04:58) | Ventana: [04:50 - 07:10]
#       - Cliente 3 (56.0, 39.0): 110.0 min (05:50) | Ventana: [05:50 - 07:00]
#       - Cliente 4 (53.0, 43.0): 160.0 min (06:40) | Ventana: [06:40 - 07:20]
#       - Cliente 1 (50.0, 35.0): 178.5 min (06:59) | Ventana: [04:10 - 07:20]
#       - Cliente 48 (45.0, 30.0): 195.6 min (07:16) | Ventana: [04:50 - 07:30]
#     Entregas por cliente:
#       - Cliente 11: G, D
#       - Cliente 8: G, D
#       - Cliente 5: G, D
#       - Cliente 3: G, D
#       - Cliente 4: G, D
#       - Cliente 1: G, D
#       - Cliente 48: G, D
#
#   Ruta #10:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 9 → 10 → 7 → 6 → Depot
#     Carga: Gasohol=2180gal (54.5%), Diésel=1540gal (38.5%)
#     Distancia: 108.22 km
#     Tiempo: 148.2 min
#     Costo: $586.45
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 9 (57.0, 68.0): 39.7 min (04:40) | Ventana: [04:30 - 06:30]
#       - Cliente 10 (62.0, 77.0): 60.0 min (04:60) | Ventana: [04:40 - 06:00]
#       - Cliente 7 (65.0, 55.0): 92.2 min (05:32) | Ventana: [04:30 - 07:10]
#       - Cliente 6 (61.0, 52.0): 107.2 min (05:47) | Ventana: [05:10 - 06:10]
#     Entregas por cliente:
#       - Cliente 9: G, D
#       - Cliente 10: G, D
#       - Cliente 7: G, D
#       - Cliente 6: G, D
#
# ================================================================================
# Solución final con costo total: $5,521.42
#
# --- Clockwise: True | Split Demands: True ---
#
# >>> Vehículos utilizados en Forward Sweep:
#   * Tipo 1: 0/20
#   * Tipo 2: 12/20
#
# ================================================================================
# SOLUCIÓN
# ================================================================================
#
# >>> RESUMEN GENERAL:
#   * Número de rutas: 12
#   * Costo total: $6,678.09
#   * Distancia total: 1119.05 km
#   * Cisternas Tipo 1: 0/20
#   * Cisternas Tipo 2: 12/20
#
# ================================================================================
#
# ================================================================================
# INICIANDO MEJORA ITERATIVA (CLOCKWISE Y COUNTERCLOCKWISE)
# ================================================================================
#
# >>> Iteración global 1
#
#   >>> Intentando mejora en sentido ANTIHORARIO...
#   [Iteración 1 - antihorario] Mejora rutas 1-2: $1026.43 → $1004.85 (ahorro: $21.58)
#   [Iteración 1 - antihorario] Mejora rutas 3-4: $1145.08 → $1126.01 (ahorro: $19.07)
#   [Iteración 1 - antihorario] Mejora rutas 3-4: $1126.01 → $1119.39 (ahorro: $6.61)
#   [Iteración 1 - antihorario] Mejora rutas 3-4: $1119.39 → $1100.35 (ahorro: $19.05)
#   [Iteración 1 - antihorario] Mejora rutas 3-4: $1100.35 → $1097.81 (ahorro: $2.54)
#
# >>> Proceso de mejora (antihorario) completado en 2 iteraciones.
# >>> Vehículos utilizados:
#   * Tipo 1: 0/20
#   * Tipo 2: 12/20
#   >>> Mejora encontrada. Costo actual: $6,609.25
#
#   >>> Intentando mejora en sentido HORARIO...
#   [Iteración 1 - horario] Mejora rutas 0-1: $1143.34 → $1126.82 (ahorro: $16.52)
#   [Iteración 1 - horario] Mejora rutas 0-1: $1126.82 → $1116.93 (ahorro: $9.89)
#   [Iteración 1 - horario] Mejora rutas 1-2: $1077.20 → $1029.54 (ahorro: $47.66)
#   [Iteración 1 - horario] Mejora rutas 2-3: $1049.40 → $1035.04 (ahorro: $14.36)
#   [Iteración 1 - horario] Mejora rutas 7-8: $1097.81 → $1093.00 (ahorro: $4.81)
#   [Iteración 1 - horario] Mejora rutas 7-8: $1093.00 → $1087.14 (ahorro: $5.87)
#   [Iteración 1 - horario] Mejora rutas 7-8: $1087.14 → $1081.88 (ahorro: $5.26)
#   [Iteración 1 - horario] Mejora rutas 7-8: $1081.88 → $1081.33 (ahorro: $0.55)
#   [Iteración 1 - horario] Mejora rutas 10-11: $1144.85 → $1112.17 (ahorro: $32.67)
#   [Iteración 2 - horario] Mejora rutas 0-1: $1178.90 → $1174.24 (ahorro: $4.65)
#   [Iteración 2 - horario] Mejora rutas 1-2: $1074.74 → $1074.37 (ahorro: $0.37)
#
# >>> Proceso de mejora (horario) completado en 3 iteraciones.
# >>> Vehículos utilizados:
#   * Tipo 1: 0/20
#   * Tipo 2: 12/20
#   >>> Mejora encontrada. Costo actual: $6,466.63
#
# >>> Iteración global 2
#
#   >>> Intentando mejora en sentido ANTIHORARIO...
#   [Iteración 1 - antihorario] Mejora rutas 8-9: $1035.41 → $983.96 (ahorro: $51.45)
#
# >>> Proceso de mejora (antihorario) completado en 2 iteraciones.
# >>> Vehículos utilizados:
#   * Tipo 1: 0/20
#   * Tipo 2: 12/20
#   >>> Mejora encontrada. Costo actual: $6,415.18
#
#   >>> Intentando mejora en sentido HORARIO...
#
# >>> Proceso de mejora (horario) completado en 1 iteraciones.
# >>> Vehículos utilizados:
#   * Tipo 1: 0/20
#   * Tipo 2: 12/20
#   >>> Sin mejoras
#
# >>> Iteración global 3
#
#   >>> Intentando mejora en sentido ANTIHORARIO...
#
# >>> Proceso de mejora (antihorario) completado en 1 iteraciones.
# >>> Vehículos utilizados:
#   * Tipo 1: 0/20
#   * Tipo 2: 12/20
#   >>> Sin mejoras
#
#   >>> Intentando mejora en sentido HORARIO...
#
# >>> Proceso de mejora (horario) completado en 1 iteraciones.
# >>> Vehículos utilizados:
#   * Tipo 1: 0/20
#   * Tipo 2: 12/20
#   >>> Sin mejoras
#
# >>> No se encontraron más mejoras en ninguna dirección.
#
# ================================================================================
# MEJORA ITERATIVA COMPLETADA EN 3 ITERACIONES GLOBALES
# ================================================================================
#
# ================================================================================
# SOLUCIÓN
# ================================================================================
#
# >>> RESUMEN GENERAL:
#   * Número de rutas: 12
#   * Costo total: $6,415.18
#   * Distancia total: 987.59 km
#   * Cisternas Tipo 1: 0/20
#   * Cisternas Tipo 2: 12/20
#
# ================================================================================
# ================================================================================
# SOLUCIÓN
# ================================================================================
#
# >>> RESUMEN GENERAL:
#   * Número de rutas: 12
#   * Costo total: $6,415.18
#   * Distancia total: 987.59 km
#   * Cisternas Tipo 1: 0/20
#   * Cisternas Tipo 2: 12/20
#
# >>> DETALLE DE RUTAS:
#
#   Ruta #1:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 1 → 2 → 3 → 4 → 5 → 6 → 9 → 10 → 16 → Depot
#     Carga: Gasohol=2170gal (54.2%), Diésel=2430gal (60.8%)
#     Distancia: 90.07 km
#     Tiempo: 203.0 min
#     Costo: $550.14
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 1 (50.0, 35.0): 15.0 min (04:15) | Ventana: [04:10 - 07:20]
#       - Cliente 2 (50.0, 35.0): 20.0 min (04:20) | Ventana: [04:10 - 07:20]
#       - Cliente 3 (65.0, 35.0): 50.0 min (04:50) | Ventana: [04:50 - 07:10]
#       - Cliente 4 (65.0, 35.0): 55.0 min (04:55) | Ventana: [04:50 - 07:10]
#       - Cliente 5 (57.0, 29.0): 90.0 min (05:30) | Ventana: [05:30 - 07:20]
#       - Cliente 6 (57.0, 29.0): 95.0 min (05:35) | Ventana: [05:30 - 07:20]
#       - Cliente 9 (65.0, 20.0): 150.0 min (06:30) | Ventana: [06:30 - 07:10]
#       - Cliente 10 (65.0, 20.0): 155.0 min (06:35) | Ventana: [06:30 - 07:10]
#       - Cliente 16 (45.0, 20.0): 180.0 min (07:00) | Ventana: [04:10 - 07:20]
#     Entregas por cliente:
#       - Cliente 1: G
#       - Cliente 2: D
#       - Cliente 3: G
#       - Cliente 4: D
#       - Cliente 5: G
#       - Cliente 6: D
#       - Cliente 9: G
#       - Cliente 10: D
#       - Cliente 16: D
#
#   Ruta #2:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 20 → 19 → 11 → 12 → 13 → 14 → 8 → 7 → Depot
#     Carga: Gasohol=1940gal (48.5%), Diésel=2300gal (57.5%)
#     Distancia: 96.02 km
#     Tiempo: 179.1 min
#     Costo: $562.03
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 20 (45.0, 10.0): 70.0 min (05:10) | Ventana: [05:10 - 06:10]
#       - Cliente 19 (45.0, 10.0): 75.0 min (05:15) | Ventana: [05:10 - 06:10]
#       - Cliente 11 (67.0, 5.0): 102.6 min (05:43) | Ventana: [05:10 - 05:50]
#       - Cliente 12 (67.0, 5.0): 107.6 min (05:48) | Ventana: [05:10 - 05:50]
#       - Cliente 13 (53.0, 12.0): 128.2 min (06:08) | Ventana: [05:40 - 06:50]
#       - Cliente 14 (53.0, 12.0): 133.2 min (06:13) | Ventana: [05:40 - 06:50]
#       - Cliente 8 (45.0, 30.0): 157.9 min (06:38) | Ventana: [04:50 - 07:30]
#       - Cliente 7 (45.0, 30.0): 162.9 min (06:43) | Ventana: [04:50 - 07:30]
#     Entregas por cliente:
#       - Cliente 20: D
#       - Cliente 19: G
#       - Cliente 11: G
#       - Cliente 12: D
#       - Cliente 13: G
#       - Cliente 14: D
#       - Cliente 8: D
#       - Cliente 7: G
#
#   Ruta #3:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 17 → 18 → 15 → 21 → 22 → Depot
#     Carga: Gasohol=1220gal (30.5%), Diésel=1070gal (26.8%)
#     Distancia: 37.95 km
#     Tiempo: 189.1 min
#     Costo: $445.89
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 17 (37.0, 31.0): 80.0 min (05:20) | Ventana: [05:20 - 06:00]
#       - Cliente 18 (37.0, 31.0): 85.0 min (05:25) | Ventana: [05:20 - 06:00]
#       - Cliente 15 (45.0, 20.0): 103.6 min (05:44) | Ventana: [04:10 - 07:20]
#       - Cliente 21 (36.0, 26.0): 170.0 min (06:50) | Ventana: [06:50 - 07:30]
#       - Cliente 22 (36.0, 26.0): 175.0 min (06:55) | Ventana: [06:50 - 07:30]
#     Entregas por cliente:
#       - Cliente 17: G
#       - Cliente 18: D
#       - Cliente 15: G
#       - Cliente 21: G
#       - Cliente 22: D
#
#   Ruta #4:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 23 → 24 → 25 → 26 → 31 → 32 → 40 → 39 → 27 → Depot
#     Carga: Gasohol=2180gal (54.5%), Diésel=1680gal (42.0%)
#     Distancia: 78.68 km
#     Tiempo: 205.6 min
#     Costo: $527.37
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 23 (30.0, 5.0): 50.0 min (04:50) | Ventana: [04:50 - 05:30]
#       - Cliente 24 (30.0, 5.0): 55.0 min (04:55) | Ventana: [04:50 - 05:30]
#       - Cliente 25 (24.0, 12.0): 69.2 min (05:09) | Ventana: [04:20 - 05:40]
#       - Cliente 26 (24.0, 12.0): 74.2 min (05:14) | Ventana: [04:20 - 05:40]
#       - Cliente 31 (18.0, 18.0): 150.0 min (06:30) | Ventana: [06:30 - 07:20]
#       - Cliente 32 (18.0, 18.0): 155.0 min (06:35) | Ventana: [06:30 - 07:20]
#       - Cliente 40 (15.0, 19.0): 163.2 min (06:43) | Ventana: [04:20 - 07:20]
#       - Cliente 39 (15.0, 19.0): 168.2 min (06:48) | Ventana: [04:20 - 07:20]
#       - Cliente 27 (25.0, 21.0): 183.4 min (07:03) | Ventana: [05:30 - 07:10]
#     Entregas por cliente:
#       - Cliente 23: G
#       - Cliente 24: D
#       - Cliente 25: G
#       - Cliente 26: D
#       - Cliente 31: G
#       - Cliente 32: D
#       - Cliente 40: D
#       - Cliente 39: G
#       - Cliente 27: G
#
#   Ruta #5:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 29 → 30 → 37 → 38 → 33 → 34 → 43 → 44 → 41 → 42 → 28 → 36 → 35 → Depot
#     Carga: Gasohol=3070gal (76.8%), Diésel=2980gal (74.5%)
#     Distancia: 91.98 km
#     Tiempo: 181.1 min
#     Costo: $553.96
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 29 (25.0, 24.0): 14.9 min (04:15) | Ventana: [04:10 - 07:30]
#       - Cliente 30 (25.0, 24.0): 19.9 min (04:20) | Ventana: [04:10 - 07:30]
#       - Cliente 37 (19.0, 21.0): 31.6 min (04:32) | Ventana: [04:20 - 07:20]
#       - Cliente 38 (19.0, 21.0): 36.6 min (04:37) | Ventana: [04:20 - 07:20]
#       - Cliente 33 (5.0, 5.0): 70.0 min (05:10) | Ventana: [05:10 - 05:50]
#       - Cliente 34 (5.0, 5.0): 75.0 min (05:15) | Ventana: [05:10 - 05:50]
#       - Cliente 43 (18.0, 24.0): 120.0 min (06:00) | Ventana: [06:00 - 07:20]
#       - Cliente 44 (18.0, 24.0): 125.0 min (06:05) | Ventana: [06:00 - 07:20]
#       - Cliente 41 (21.0, 24.0): 133.0 min (06:13) | Ventana: [04:10 - 07:30]
#       - Cliente 42 (21.0, 24.0): 138.0 min (06:18) | Ventana: [04:10 - 07:30]
#       - Cliente 28 (25.0, 21.0): 148.0 min (06:28) | Ventana: [05:30 - 07:10]
#       - Cliente 36 (26.0, 27.0): 159.1 min (06:39) | Ventana: [04:30 - 07:00]
#       - Cliente 35 (26.0, 27.0): 164.1 min (06:44) | Ventana: [04:30 - 07:00]
#     Entregas por cliente:
#       - Cliente 29: G
#       - Cliente 30: D
#       - Cliente 37: G
#       - Cliente 38: D
#       - Cliente 33: G
#       - Cliente 34: D
#       - Cliente 43: G
#       - Cliente 44: D
#       - Cliente 41: G
#       - Cliente 42: D
#       - Cliente 28: D
#       - Cliente 36: D
#       - Cliente 35: G
#
#   Ruta #6:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 45 → 46 → 47 → 48 → 49 → 50 → 51 → 52 → Depot
#     Carga: Gasohol=2080gal (52.0%), Diésel=2420gal (60.5%)
#     Distancia: 85.01 km
#     Tiempo: 177.5 min
#     Costo: $540.03
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 45 (20.0, 26.0): 70.0 min (05:10) | Ventana: [05:10 - 05:50]
#       - Cliente 46 (20.0, 26.0): 75.0 min (05:15) | Ventana: [05:10 - 05:50]
#       - Cliente 47 (4.0, 18.0): 97.9 min (05:38) | Ventana: [04:40 - 06:30]
#       - Cliente 48 (4.0, 18.0): 102.9 min (05:43) | Ventana: [04:40 - 06:30]
#       - Cliente 49 (12.0, 24.0): 117.9 min (05:58) | Ventana: [04:20 - 06:20]
#       - Cliente 50 (12.0, 24.0): 122.9 min (06:03) | Ventana: [04:20 - 06:20]
#       - Cliente 51 (5.0, 30.0): 137.1 min (06:17) | Ventana: [06:00 - 07:10]
#       - Cliente 52 (5.0, 30.0): 142.1 min (06:22) | Ventana: [06:00 - 07:10]
#     Entregas por cliente:
#       - Cliente 45: G
#       - Cliente 46: D
#       - Cliente 47: G
#       - Cliente 48: D
#       - Cliente 49: G
#       - Cliente 50: D
#       - Cliente 51: G
#       - Cliente 52: D
#
#   Ruta #7:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 53 → 54 → 55 → 56 → 57 → 58 → Depot
#     Carga: Gasohol=1440gal (36.0%), Diésel=1550gal (38.8%)
#     Distancia: 80.46 km
#     Tiempo: 144.9 min
#     Costo: $530.92
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 53 (6.0, 38.0): 29.2 min (04:29) | Ventana: [04:20 - 05:40]
#       - Cliente 54 (6.0, 38.0): 34.2 min (04:34) | Ventana: [04:20 - 05:40]
#       - Cliente 55 (10.0, 43.0): 80.0 min (05:20) | Ventana: [05:20 - 06:00]
#       - Cliente 56 (10.0, 43.0): 85.0 min (05:25) | Ventana: [05:20 - 06:00]
#       - Cliente 57 (2.0, 48.0): 99.4 min (05:39) | Ventana: [05:00 - 07:00]
#       - Cliente 58 (2.0, 48.0): 104.4 min (05:44) | Ventana: [05:00 - 07:00]
#     Entregas por cliente:
#       - Cliente 53: G
#       - Cliente 54: D
#       - Cliente 55: G
#       - Cliente 56: D
#       - Cliente 57: G
#       - Cliente 58: D
#
#   Ruta #8:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 59 → 60 → 61 → 62 → 63 → 64 → Depot
#     Carga: Gasohol=1310gal (32.8%), Diésel=1470gal (36.8%)
#     Distancia: 88.69 km
#     Tiempo: 118.7 min
#     Costo: $547.38
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 59 (2.0, 60.0): 41.4 min (04:41) | Ventana: [04:40 - 06:00]
#       - Cliente 60 (2.0, 60.0): 46.4 min (04:46) | Ventana: [04:40 - 06:00]
#       - Cliente 61 (8.0, 56.0): 58.6 min (04:59) | Ventana: [04:30 - 07:00]
#       - Cliente 62 (8.0, 56.0): 63.6 min (05:04) | Ventana: [04:30 - 07:00]
#       - Cliente 63 (15.0, 60.0): 76.7 min (05:17) | Ventana: [04:30 - 06:30]
#       - Cliente 64 (15.0, 60.0): 81.7 min (05:22) | Ventana: [04:30 - 06:30]
#     Entregas por cliente:
#       - Cliente 59: G
#       - Cliente 60: D
#       - Cliente 61: G
#       - Cliente 62: D
#       - Cliente 63: G
#       - Cliente 64: D
#
#   Ruta #9:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 65 → 66 → 67 → 68 → 69 → 70 → 73 → 74 → 71 → Depot
#     Carga: Gasohol=2280gal (57.0%), Diésel=2280gal (57.0%)
#     Distancia: 111.98 km
#     Tiempo: 173.4 min
#     Costo: $593.96
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 65 (20.0, 65.0): 50.0 min (04:50) | Ventana: [04:50 - 05:30]
#       - Cliente 66 (20.0, 65.0): 55.0 min (04:55) | Ventana: [04:50 - 05:30]
#       - Cliente 67 (24.0, 58.0): 68.1 min (05:08) | Ventana: [04:40 - 05:20]
#       - Cliente 68 (24.0, 58.0): 73.1 min (05:13) | Ventana: [04:40 - 05:20]
#       - Cliente 69 (15.0, 77.0): 99.1 min (05:39) | Ventana: [04:40 - 05:50]
#       - Cliente 70 (15.0, 77.0): 104.1 min (05:44) | Ventana: [04:40 - 05:50]
#       - Cliente 73 (27.0, 69.0): 123.5 min (06:04) | Ventana: [04:30 - 07:00]
#       - Cliente 74 (27.0, 69.0): 128.5 min (06:09) | Ventana: [04:30 - 07:00]
#       - Cliente 71 (31.0, 52.0): 151.0 min (06:31) | Ventana: [04:10 - 07:20]
#     Entregas por cliente:
#       - Cliente 65: G
#       - Cliente 66: D
#       - Cliente 67: G
#       - Cliente 68: D
#       - Cliente 69: G
#       - Cliente 70: D
#       - Cliente 73: G
#       - Cliente 74: D
#       - Cliente 71: G
#
#   Ruta #10:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 79 → 80 → Depot
#     Carga: Gasohol=550gal (13.8%), Diésel=670gal (16.8%)
#     Distancia: 10.00 km
#     Tiempo: 20.0 min
#     Costo: $390.00
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 79 (35.0, 40.0): 5.0 min (04:05) | Ventana: [04:00 - 05:20]
#       - Cliente 80 (35.0, 40.0): 10.0 min (04:10) | Ventana: [04:00 - 05:20]
#     Entregas por cliente:
#       - Cliente 79: G
#       - Cliente 80: D
#
#   Ruta #11:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 83 → 81 → 82 → 85 → 86 → 87 → 88 → 76 → 75 → 78 → 77 → 72 → Depot
#     Carga: Gasohol=2710gal (67.8%), Diésel=2620gal (65.5%)
#     Distancia: 132.07 km
#     Tiempo: 200.8 min
#     Costo: $634.14
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 83 (41.0, 49.0): 15.2 min (04:15) | Ventana: [04:10 - 07:30]
#       - Cliente 81 (40.0, 60.0): 40.0 min (04:40) | Ventana: [04:40 - 05:50]
#       - Cliente 82 (40.0, 60.0): 45.0 min (04:45) | Ventana: [04:40 - 05:50]
#       - Cliente 85 (62.0, 77.0): 77.8 min (05:18) | Ventana: [04:40 - 06:00]
#       - Cliente 86 (62.0, 77.0): 82.8 min (05:23) | Ventana: [04:40 - 06:00]
#       - Cliente 87 (57.0, 68.0): 98.1 min (05:38) | Ventana: [04:30 - 06:30]
#       - Cliente 88 (57.0, 68.0): 103.1 min (05:43) | Ventana: [04:30 - 06:30]
#       - Cliente 76 (30.0, 60.0): 136.3 min (06:16) | Ventana: [05:40 - 06:30]
#       - Cliente 75 (30.0, 60.0): 141.3 min (06:21) | Ventana: [05:40 - 06:30]
#       - Cliente 78 (31.0, 67.0): 153.3 min (06:33) | Ventana: [04:40 - 06:40]
#       - Cliente 77 (31.0, 67.0): 158.3 min (06:38) | Ventana: [04:40 - 06:40]
#       - Cliente 72 (31.0, 52.0): 178.3 min (06:58) | Ventana: [04:10 - 07:20]
#     Entregas por cliente:
#       - Cliente 83: G
#       - Cliente 81: G
#       - Cliente 82: D
#       - Cliente 85: G
#       - Cliente 86: D
#       - Cliente 87: G
#       - Cliente 88: D
#       - Cliente 76: D
#       - Cliente 75: G
#       - Cliente 78: D
#       - Cliente 77: G
#       - Cliente 72: D
#
#   Ruta #12:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 84 → 90 → 89 → 91 → 92 → 93 → 94 → 95 → 96 → 97 → 98 → 99 → 100 → Depot
#     Carga: Gasohol=2680gal (67.0%), Diésel=3350gal (83.8%)
#     Distancia: 84.68 km
#     Tiempo: 206.4 min
#     Costo: $539.36
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 84 (41.0, 49.0): 15.2 min (04:15) | Ventana: [04:10 - 07:30]
#       - Cliente 90 (47.0, 47.0): 40.0 min (04:40) | Ventana: [04:40 - 07:30]
#       - Cliente 89 (47.0, 47.0): 45.0 min (04:45) | Ventana: [04:40 - 07:30]
#       - Cliente 91 (65.0, 55.0): 69.7 min (05:10) | Ventana: [04:30 - 07:10]
#       - Cliente 92 (65.0, 55.0): 74.7 min (05:15) | Ventana: [04:30 - 07:10]
#       - Cliente 93 (61.0, 52.0): 84.7 min (05:25) | Ventana: [05:10 - 06:10]
#       - Cliente 94 (61.0, 52.0): 89.7 min (05:30) | Ventana: [05:10 - 06:10]
#       - Cliente 95 (55.0, 45.0): 103.9 min (05:44) | Ventana: [04:50 - 07:10]
#       - Cliente 96 (55.0, 45.0): 108.9 min (05:49) | Ventana: [04:50 - 07:10]
#       - Cliente 97 (53.0, 43.0): 160.0 min (06:40) | Ventana: [06:40 - 07:20]
#       - Cliente 98 (53.0, 43.0): 165.0 min (06:45) | Ventana: [06:40 - 07:20]
#       - Cliente 99 (56.0, 39.0): 175.0 min (06:55) | Ventana: [05:50 - 07:00]
#       - Cliente 100 (56.0, 39.0): 180.0 min (07:00) | Ventana: [05:50 - 07:00]
#     Entregas por cliente:
#       - Cliente 84: D
#       - Cliente 90: D
#       - Cliente 89: G
#       - Cliente 91: G
#       - Cliente 92: D
#       - Cliente 93: G
#       - Cliente 94: D
#       - Cliente 95: G
#       - Cliente 96: D
#       - Cliente 97: G
#       - Cliente 98: D
#       - Cliente 99: G
#       - Cliente 100: D
#
# ================================================================================
# Solución final con costo total: $6,415.18
#
# === Mejor configuración encontrada: Clockwise=False, Split Demands=False con costo total: $5,115.07 ===

# %% [markdown]
# No kernel connected

# %% [markdown]
# No kernel connected

# %% [markdown]
# No kernel connected
