# %% [markdown]
# Connected to Python 3.10.12

# %%
"""
Problema de ruteo de vehiculos con multiples compartimento, flota heterogenea y ventanas de tiempo.

0. Contexto:
    PetroAndes Logistics S.A.C. es una empresa dedicada a la distribución de combustibles líquidos, principalmente gasohol 90 y diésel B5, hacia estaciones de servicio y clientes industriales en el sur del país. 
    
    Cada día la empresa alquila cisternas a transportistas con los que mantiene contratos que establecen tarifas diferenciadas según el tamaño del vehículo y el costo por kilómetro recorrido. 
    
    Al inicio de cada jornada se reciben los pedidos de los clientes, se consolida la demanda total y se debe decidir qué cisternas alquilar, cuánto producto cargará cada una y en qué orden se realizarán las entregas.

    Las cisternas utilizadas son vehículos con dos compartimentos, diseñados para transportar simultáneamente gasohol y diésel sin riesgo de mezcla entre productos. 
    
    La flota está compuesta por dos tipos de unidades, y cada tipo cuenta con un volumen específico asignado a cada producto. 

    Cada unidad realiza una única ruta por jornada, la cual comienza y termina en la almacen de despacho. 
    
    Una vez que un vehículo completa su recorrido y retorna al almacen, no puede volver a salir durante el mismo día.

    Un aspecto operativo crítico son los horarios de atención de los clientes. 
    Las estaciones no pueden recibir combustible en cualquier momento del día, estas ventanas de tiempo son propias de cada cliente y responden a regulaciones de seguridad o políticas internas de cada negocio. 
    Si una cisterna arriba antes del inicio de la ventana a un cliente, puede esperar hasta el horario permitido para iniciar la descarga, sin embargo, si llega después del límite establecido, no puede iniciar ese proceso.

    Cada cliente demanda cantidades específicas de gasohol y diésel, que deben entregarse en una sola visita por producto. 
    
    Un cliente puede ser atendido una única vez si una cisterna entrega ambos combustibles en la misma parada, o con dos cisternas distintas si cada producto se despacha por separado. No está permitido que más de una cisterna atienda el mismo tipo de producto en un mismo cliente. 
    
    Cada entrega tiene un tiempo de descarga definido, y cuando ambos productos se entregan en la misma visita, el tiempo total corresponde a la suma de los tiempos de descarga de cada combustible. 
    
    Los compartimentos de las cisternas son exclusivos para un solo tipo de producto.

    El crecimiento del número de clientes y la variabilidad diaria de la demanda han hecho que la planificación manual resulte insuficiente. Cada error en la asignación de cisternas puede traducirse en retrasos, sobrecostos o incluso en la pérdida de clientes por falta de abastecimiento oportuno. Contar con un programa que asista al gerente de operaciones en la toma de decisiones diarias se ha vuelto crucial para evitar pérdidas y garantizar la continuidad del servicio. 

    INSTANCIAS:

        La flota disponible es fija en todas las instancias y está compuesta por dos tipos de cisternas, con 20 unidades de cada tipo. 
        Los parámetros asociados a cada tipo se detallan a continuación:

        Tipo | Cap. Gasohol | Cap. Diésel | Costo fijo | Costo por km
        -----|--------------|------------|-----------|-------------
        1    | 5800         | 5200       | 450       | 2
        2    | 4000         | 4000       | 370       | 2

        Se asume una velocidad promedio constante de 60 km/h para todos los desplazamientos, sin variaciones horarias. 
        Las capacidades de los compartimentos están expresadas en galones y todos los costos se encuentran en dólares estadounidenses (US$). 
        Además, se considera que el tiempo de servicio en cada cliente es fijo e igual a 5 minutos, independientemente de la cantidad entregada. Si ambos combustibles se entregan en la misma visita, el tiempo total será de 10 minutos.

    EJEMPLO DE FORMATO DE ARCHIVO DE INSTANCIA (.csv):

            id, x,    y,    Gasohol,  Diésel,   Inicio,  Fin
            0,  35.0, 35.0, 0,        0,        04:00,   09:00
            36, 2.0,  60.0, 810,      790,      04:40,   06:00
            68, 56.0, 39.0, 760,      780,      05:50,   07:00
            22, 45.0, 10.0, 810,      850,      05:10,   06:10
            3,  55.0, 45.0, 800,      810,      04:50,   07:10
            31, 31.0, 52.0, 710,      840,      04:10,   07:20
            42, 24.0, 12.0, 810,      800,      04:20,   05:40
            8,  10.0, 10.0, 770,      790,      05:20,   06:00
            24, 65.0, 35.0, 840,      800,      04:50,   07:10
            53, 37.0, 31.0, 810,      850,      05:20,   06:00
            63, 27.0, 69.0, 860,      810,      04:30,   07:00

        Las distancias entre el almacén y los clientes, así como entre clientes, se calculan utilizando la distancia euclidiana a partir de sus coordenadas (x, y) expresadas en kilómetros. 
        Además, se establece que las cisternas pueden iniciar sus rutas a partir de las 04:00 horas y deben retornar al almacén antes de las 09:00 horas del mismo día.

Funcion Objetivo: Minimizar el costo diario de operacion, considerando el alquiler de cisternas y la distancia recorrida por los vehiculos, garantizando la atención completa de todos los clientes dentro de sus ventanas de tiempo.
"""

import os, sys
os.chdir(os.path.dirname(os.path.abspath(__file__)))

import pandas as pd
import numpy as np
from IPython.display import display
from typing import List, Dict
import random

from models import ProblemInstance, Ruta, SolutionVisualizer
from solvers import SweepAlgorithm, SolverTabuSearchMCVRPTW

pd.set_option('display.float_format', lambda x: '%.2f' % x)
np.set_printoptions(precision=2, suppress=True)

SEED = 42
np.random.seed(SEED)
random.seed(SEED)


# -----------------------------------------------------------------------------
# Utility Functions for Data Preprocessing
# -----------------------------------------------------------------------------

def time_to_minutes(time_str):
    """Convertir ventanas de tiempo a minutos desde 04:00"""
    h, m = map(int, time_str.split(':'))
    return (h - 4) * 60 + m


def polar_coordinate_angle(x, y, depot_x, depot_y):
    """Calculate the angle of a point (x, y) with respect to a depot in polar coordinates."""
    delta_x = x - depot_x
    delta_y = y - depot_y
    angle = np.arctan2(delta_y, delta_x)
    return angle if angle >= 0 else angle + 2 * np.pi


def clockwise_angle(angle_ccw):
    """Convierte un ángulo CCW a su equivalente horario en [0, 2π)."""
    return (-angle_ccw) % (2 * np.pi)


def radius(x, y, depot_x, depot_y):
    """
    Calculate the radius of a point (x, y) with respect to a depot (depot_x, depot_y)
    in polar coordinates.
    """
    return np.sqrt((x - depot_x) ** 2 + (y - depot_y) ** 2)


def split_client_demands(df: pd.DataFrame) -> pd.DataFrame:
    """Split demands into two rows: one for gasohol and another for diesel."""
    gasohol_df = df.copy()
    gasohol_df["tipo_combustible"] = "gasohol"
    gasohol_df["demanda_diesel"] = 0

    diesel_df = df.copy()
    diesel_df["tipo_combustible"] = "diesel"
    diesel_df["demanda_gasohol"] = 0

    df_split_demands = (
        pd.concat([gasohol_df, diesel_df], ignore_index=True)
        .sort_values(by=['AN', 'R'])
        .drop_duplicates(subset=['index', 'demanda_gasohol', 'demanda_diesel'], keep='first')
        .assign(old_index=lambda x: x.index)
        .drop(columns=['index'])
        .reset_index(drop=True).reset_index(drop=False)
    )
    
    return df_split_demands


# -----------------------------------------------------------------------------
# Load and Preprocess Data
# -----------------------------------------------------------------------------

df = (
    pd.read_csv('./instancias/25_clientes_2.csv')
    .reset_index(drop=False)
)

df['E'] = df['ventana_inicio'].apply(time_to_minutes)
df['L'] = df['ventana_fin'].apply(time_to_minutes)

df['AN'] = df.apply(
    lambda row: polar_coordinate_angle(row['x'], row['y'], df.loc[0, 'x'], df.loc[0, 'y']), axis=1
)

df['R'] = df.apply(
    lambda row: radius(row['x'], row['y'], df.loc[0, 'x'], df.loc[0, 'y']), axis=1
)

# Reorder according to polar-coordinate angle and distance
df = (
    df.sort_values(by=['AN', 'R'])
    .rename(columns={'index': 'old_index'})
    .reset_index(drop=True).reset_index(drop=False)
)
# display(df)


# -----------------------------------------------------------------------------
# Problem Parameters
# -----------------------------------------------------------------------------

tipos_cisternas = {
    1: {'cap_gasohol': 5800, 'cap_diesel': 5200, 'costo_fijo': 450, 'costo_km': 2},
    2: {'cap_gasohol': 4000, 'cap_diesel': 4000, 'costo_fijo': 370, 'costo_km': 2}
}

# -----------------------------------------------------------------------------
# Main Algorithm
# -----------------------------------------------------------------------------

def tabu_search_mcvrptw(data: pd.DataFrame, tipos_cisternas: Dict, 
                       clockwise: bool = False, I: int = 1000, 
                       split_demands: bool = False,
                       num_vehiculos_por_tipo: int = 20,
                       velocidad: float = 60, 
                       tiempo_descarga: float = 5):
    """
    Iterated Tabu Search para MCVRPTW.
    
    Basado en Silvestrin (2017) - 'An Iterated Tabu Search for Multi-Compartment Vehicle Routing Problem'
    
    Pseudo-código:
        function ITS()
            s <- SweepConstruction()
            s <- TabuSearch(s)
            for i = 1, ..., I iterations do
                s' <- Perturb(s)
                s <- TabuSearch(s')
                with probability (i / I)^2: s <- s'
            end for
            return the best solution s' found during search
        end function
    """
    df_input = data.copy()
    if clockwise:
        df_input['AN'] = df_input['AN'].apply(clockwise_angle)
    if split_demands:
        df_input = split_client_demands(df_input)

    instance = ProblemInstance(
        df_input, tipos_cisternas, num_vehiculos_por_tipo, 
        velocidad, tiempo_descarga
    )
    visualizer = SolutionVisualizer(instance)
    
    sweep_solver = SweepAlgorithm(instance)
    
    # Construcción inicial con Angular Sweep
    rutas = sweep_solver.forward_sweep()
    visualizer.imprimir_solucion(rutas, 1)
    # visualizer.visualizar_rutas(rutas, "Forward Sweep")

    # Mejora con "2-opt" bidireccional
    rutas = sweep_solver.iterative_improving_sweep(rutas)
    visualizer.imprimir_solucion(rutas, 1)
    visualizer.visualizar_rutas(rutas, "Forward Sweep + 2-opt bidirectional")

    # Iterated Tabu Search
    tabu_solver = SolverTabuSearchMCVRPTW(sweep_solver)
    best_solution = rutas
    best_cost = sum(r.costo_total for r in best_solution)

    for iteration in range(1, I + 1):
        rutas_perturbadas = tabu_solver.perturbation(rutas)
        rutas = tabu_solver.tabu_search(rutas_perturbadas, iteration)

        prob = (iteration / I) ** 2
        if random.random() < prob:
            rutas = rutas_perturbadas
        
        current_cost = sum(r.costo_total for r in rutas)
        if current_cost < best_cost:
            best_solution = rutas
            best_cost = current_cost
            print(f"  [Iteración {iteration}] Nueva mejor solución: ${best_cost:,.2f}")
    
    visualizer.imprimir_solucion(best_solution, 2)
    visualizer.visualizar_rutas(best_solution, "Iterated Tabu Search - Final Solution")
    return best_solution, best_cost


# -----------------------------------------------------------------------------
# Execute
# -----------------------------------------------------------------------------

best_cost_solution = float('inf')
best_config = {}
for cc in [False, True]:
    for sd in [False, True]:
        try:
            print(f"\n--- Clockwise: {cc} | Split Demands: {sd} ---")
            rutas_solucion, costo = tabu_search_mcvrptw(df, tipos_cisternas, clockwise=cc, split_demands=sd, I=50)
            print(f"Solución final con costo total: ${costo:,.2f}")
            if costo < best_cost_solution:
                best_cost_solution = costo
                best_config = {'clockwise': cc, 'split_demands': sd}
        except Exception as e:
            print(f"Error con configuración Clockwise={cc}, Split Demands={sd}: {e}")
            import traceback
            traceback.print_exc()
            raise e
    #     break
    # break

print(f"\n=== Mejor configuración encontrada: Clockwise={best_config['clockwise']}, Split Demands={best_config['split_demands']} con costo total: ${best_cost_solution:,.2f} ===")
# Out:
# --- Clockwise: False | Split Demands: False ---
#
# >>> Vehículos utilizados en Forward Sweep:
#   * Tipo 1: 3/20
#   * Tipo 2: 6/20
#
# ================================================================================
# SOLUCIÓN
# ================================================================================
#
# >>> RESUMEN GENERAL:
#   * Número de rutas: 9
#   * Costo total: $5,036.15
#   * Distancia total: 733.08 km
#   * Cisternas Tipo 1: 3/20
#   * Cisternas Tipo 2: 6/20
#
# ================================================================================
#
# ================================================================================
# INICIANDO MEJORA ITERATIVA (CLOCKWISE Y COUNTERCLOCKWISE)
# ================================================================================
#
# >>> Iteración global 1
#
#   >>> Intentando mejora en sentido ANTIHORARIO...
#   [Iteración 1 - antihorario] Mejora rutas 2-3: $1189.92 → $1183.54 (ahorro: $6.37)
#   [Iteración 1 - antihorario] Mejora rutas 3-4: $1135.47 → $1107.48 (ahorro: $27.99)
#   [Iteración 1 - antihorario] Mejora rutas 6-7: $1033.28 → $985.82 (ahorro: $47.45)
#   [Iteración 1 - antihorario] Mejora rutas 7-8: $1029.05 → $964.50 (ahorro: $64.54)
#
# >>> Proceso de mejora (antihorario) completado en 2 iteraciones.
# >>> Vehículos utilizados:
#   * Tipo 1: 3/20
#   * Tipo 2: 6/20
#   >>> Mejora encontrada. Costo actual: $4,889.79
#
#   >>> Intentando mejora en sentido HORARIO...
#   [Iteración 1 - horario] Mejora rutas 4-5: $1107.48 → $1090.52 (ahorro: $16.96)
#   [Iteración 1 - horario] Mejora rutas 4-5: $1090.52 → $1090.27 (ahorro: $0.26)
#   [Iteración 1 - horario] Mejora rutas 5-6: $1078.31 → $1078.27 (ahorro: $0.04)
#   [Iteración 2 - horario] Mejora rutas 4-5: $1090.19 → $1086.10 (ahorro: $4.09)
#   [Iteración 2 - horario] Mejora rutas 4-5: $1086.10 → $1084.57 (ahorro: $1.53)
#   [Iteración 2 - horario] Mejora rutas 5-6: $1064.79 → $1041.66 (ahorro: $23.13)
#
# >>> Proceso de mejora (horario) completado en 3 iteraciones.
# >>> Vehículos utilizados:
#   * Tipo 1: 2/20
#   * Tipo 2: 7/20
#   >>> Mejora encontrada. Costo actual: $4,843.77
#
# >>> Iteración global 2
#
#   >>> Intentando mejora en sentido ANTIHORARIO...
#   [Iteración 1 - antihorario] Mejora rutas 2-3: $1041.66 → $1040.76 (ahorro: $0.90)
#   [Iteración 1 - antihorario] Mejora rutas 2-3: $1040.76 → $1037.76 (ahorro: $3.00)
#
# >>> Proceso de mejora (antihorario) completado en 2 iteraciones.
# >>> Vehículos utilizados:
#   * Tipo 1: 2/20
#   * Tipo 2: 7/20
#   >>> Mejora encontrada. Costo actual: $4,839.87
#
#   >>> Intentando mejora en sentido HORARIO...
#
# >>> Proceso de mejora (horario) completado en 1 iteraciones.
# >>> Vehículos utilizados:
#   * Tipo 1: 2/20
#   * Tipo 2: 7/20
#   >>> Sin mejoras
#
# >>> Iteración global 3
#
#   >>> Intentando mejora en sentido ANTIHORARIO...
#
# >>> Proceso de mejora (antihorario) completado en 1 iteraciones.
# >>> Vehículos utilizados:
#   * Tipo 1: 2/20
#   * Tipo 2: 7/20
#   >>> Sin mejoras
#
#   >>> Intentando mejora en sentido HORARIO...
#
# >>> Proceso de mejora (horario) completado en 1 iteraciones.
# >>> Vehículos utilizados:
#   * Tipo 1: 2/20
#   * Tipo 2: 7/20
#   >>> Sin mejoras
#
# >>> No se encontraron más mejoras en ninguna dirección.
#
# ================================================================================
# MEJORA ITERATIVA COMPLETADA EN 3 ITERACIONES GLOBALES
# ================================================================================
#
# ================================================================================
# SOLUCIÓN
# ================================================================================
#
# >>> RESUMEN GENERAL:
#   * Número de rutas: 9
#   * Costo total: $4,839.87
#   * Distancia total: 674.94 km
#   * Cisternas Tipo 1: 2/20
#   * Cisternas Tipo 2: 7/20
#
# ================================================================================
#   [Iteración 1] Nueva mejor solución: $4,804.11
#
# ================================================================================
# SOLUCIÓN
# ================================================================================
#
# >>> RESUMEN GENERAL:
#   * Número de rutas: 9
#   * Costo total: $4,804.11
#   * Distancia total: 697.06 km
#   * Cisternas Tipo 1: 1/20
#   * Cisternas Tipo 2: 8/20
#
# >>> DETALLE DE RUTAS:
#
#   Ruta #1:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 2 → 3 → 4 → Depot
#     Carga: Gasohol=3600gal (90.0%), Diésel=3590gal (89.8%)
#     Distancia: 68.29 km
#     Tiempo: 158.4 min
#     Costo: $506.58
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 2 (65.0, 35.0): 50.0 min (04:50) | Ventana: [04:50 - 07:10]
#       - Cliente 3 (56.0, 39.0): 110.0 min (05:50) | Ventana: [05:50 - 07:00]
#       - Cliente 4 (55.0, 45.0): 126.1 min (06:06) | Ventana: [04:50 - 07:10]
#     Entregas por cliente:
#       - Cliente 2: G, D
#       - Cliente 3: G, D
#       - Cliente 4: G, D
#
#   Ruta #2:
#     Cisterna: Tipo 1
#     Secuencia: Depot → 5 → 6 → 7 → 8 → Depot
#     Carga: Gasohol=4820gal (83.1%), Diésel=4790gal (92.1%)
#     Distancia: 108.08 km
#     Tiempo: 187.0 min
#     Costo: $666.17
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 5 (61.0, 52.0): 70.0 min (05:10) | Ventana: [05:10 - 06:10]
#       - Cliente 6 (57.0, 68.0): 96.5 min (05:36) | Ventana: [04:30 - 06:30]
#       - Cliente 7 (62.0, 77.0): 116.8 min (05:57) | Ventana: [04:40 - 06:00]
#       - Cliente 8 (41.0, 49.0): 161.8 min (06:42) | Ventana: [04:10 - 07:30]
#     Entregas por cliente:
#       - Cliente 5: G, D
#       - Cliente 6: G, D
#       - Cliente 7: G, D
#       - Cliente 8: G, D
#
#   Ruta #3:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 12 → 13 → 14 → Depot
#     Carga: Gasohol=3400gal (85.0%), Diésel=3410gal (85.2%)
#     Distancia: 72.64 km
#     Tiempo: 117.1 min
#     Costo: $515.29
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 12 (24.0, 58.0): 40.0 min (04:40) | Ventana: [04:40 - 05:20]
#       - Cliente 13 (20.0, 65.0): 58.1 min (04:58) | Ventana: [04:50 - 05:30]
#       - Cliente 14 (15.0, 60.0): 75.1 min (05:15) | Ventana: [04:30 - 06:30]
#     Entregas por cliente:
#       - Cliente 12: G, D
#       - Cliente 13: G, D
#       - Cliente 14: G, D
#
#   Ruta #4:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 9 → 11 → 10 → Depot
#     Carga: Gasohol=3520gal (88.0%), Diésel=3650gal (91.2%)
#     Distancia: 76.23 km
#     Tiempo: 120.7 min
#     Costo: $522.47
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 9 (40.0, 60.0): 40.0 min (04:40) | Ventana: [04:40 - 05:50]
#       - Cliente 11 (27.0, 69.0): 65.8 min (05:06) | Ventana: [04:30 - 07:00]
#       - Cliente 10 (31.0, 52.0): 93.3 min (05:33) | Ventana: [04:10 - 07:20]
#     Entregas por cliente:
#       - Cliente 9: G, D
#       - Cliente 11: G, D
#       - Cliente 10: G, D
#
#   Ruta #5:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 16 → 15 → Depot
#     Carga: Gasohol=2380gal (59.5%), Diésel=2380gal (59.5%)
#     Distancia: 86.44 km
#     Tiempo: 160.2 min
#     Costo: $542.88
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 16 (10.0, 43.0): 80.0 min (05:20) | Ventana: [05:20 - 06:00]
#       - Cliente 15 (2.0, 60.0): 108.8 min (05:49) | Ventana: [04:40 - 06:00]
#     Entregas por cliente:
#       - Cliente 16: G, D
#       - Cliente 15: G, D
#
#   Ruta #6:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 17 → 18 → Depot
#     Carga: Gasohol=2310gal (57.8%), Diésel=2420gal (60.5%)
#     Distancia: 84.88 km
#     Tiempo: 132.5 min
#     Costo: $539.76
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 17 (5.0, 5.0): 70.0 min (05:10) | Ventana: [05:10 - 05:50]
#       - Cliente 18 (25.0, 24.0): 107.6 min (05:48) | Ventana: [04:10 - 07:30]
#     Entregas por cliente:
#       - Cliente 17: G, D
#       - Cliente 18: G, D
#
#   Ruta #7:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 19 → 20 → Depot
#     Carga: Gasohol=2360gal (59.0%), Diésel=2440gal (61.0%)
#     Distancia: 65.13 km
#     Tiempo: 90.4 min
#     Costo: $500.26
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 19 (24.0, 12.0): 25.5 min (04:25) | Ventana: [04:20 - 05:40]
#       - Cliente 20 (30.0, 5.0): 50.0 min (04:50) | Ventana: [04:50 - 05:30]
#     Entregas por cliente:
#       - Cliente 19: G, D
#       - Cliente 20: G, D
#
#   Ruta #8:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 22 → 25 → 24 → Depot
#     Carga: Gasohol=3420gal (85.5%), Diésel=3550gal (88.8%)
#     Distancia: 94.14 km
#     Tiempo: 167.2 min
#     Costo: $558.28
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 22 (45.0, 10.0): 70.0 min (05:10) | Ventana: [05:10 - 06:10]
#       - Cliente 25 (67.0, 5.0): 102.6 min (05:43) | Ventana: [05:10 - 05:50]
#       - Cliente 24 (45.0, 20.0): 139.2 min (06:19) | Ventana: [04:10 - 07:20]
#     Entregas por cliente:
#       - Cliente 22: G, D
#       - Cliente 25: G, D
#       - Cliente 24: G, D
#
#   Ruta #9:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 23 → 21 → 1 → Depot
#     Carga: Gasohol=3640gal (91.0%), Diésel=3750gal (93.8%)
#     Distancia: 41.21 km
#     Tiempo: 221.6 min
#     Costo: $452.43
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 23 (37.0, 31.0): 80.0 min (05:20) | Ventana: [05:20 - 06:00]
#       - Cliente 21 (36.0, 26.0): 170.0 min (06:50) | Ventana: [06:50 - 07:30]
#       - Cliente 1 (50.0, 35.0): 196.6 min (07:17) | Ventana: [04:10 - 07:20]
#     Entregas por cliente:
#       - Cliente 23: G, D
#       - Cliente 21: G, D
#       - Cliente 1: G, D
#
# ================================================================================
# Solución final con costo total: $4,804.11
#
# --- Clockwise: False | Split Demands: True ---
#
# >>> Vehículos utilizados en Forward Sweep:
#   * Tipo 1: 2/20
#   * Tipo 2: 8/20
#
# ================================================================================
# SOLUCIÓN
# ================================================================================
#
# >>> RESUMEN GENERAL:
#   * Número de rutas: 10
#   * Costo total: $5,525.87
#   * Distancia total: 832.94 km
#   * Cisternas Tipo 1: 2/20
#   * Cisternas Tipo 2: 8/20
#
# ================================================================================
#
# ================================================================================
# INICIANDO MEJORA ITERATIVA (CLOCKWISE Y COUNTERCLOCKWISE)
# ================================================================================
#
# >>> Iteración global 1
#
#   >>> Intentando mejora en sentido ANTIHORARIO...
#   [Iteración 1 - antihorario] Mejora rutas 1-2: $1155.89 → $1088.60 (ahorro: $67.28)
#   [Iteración 1 - antihorario] Mejora rutas 1-2: $1088.60 → $1085.12 (ahorro: $3.48)
#   [Iteración 1 - antihorario] Mejora rutas 2-3: $1052.90 → $1034.83 (ahorro: $18.07)
#
# >>> Proceso de mejora (antihorario) completado en 2 iteraciones.
# >>> Vehículos utilizados:
#   * Tipo 1: 2/20
#   * Tipo 2: 8/20
#   >>> Mejora encontrada. Costo actual: $5,437.03
#
#   >>> Intentando mejora en sentido HORARIO...
#   [Iteración 1 - horario] Mejora rutas 4-5: $1115.05 → $1114.66 (ahorro: $0.40)
#   [Iteración 1 - horario] Mejora rutas 4-5: $1114.66 → $1065.39 (ahorro: $49.26)
#   [Iteración 1 - horario] Mejora rutas 6-7: $1034.83 → $1025.51 (ahorro: $9.32)
#
# >>> Proceso de mejora (horario) completado en 2 iteraciones.
# >>> Vehículos utilizados:
#   * Tipo 1: 1/20
#   * Tipo 2: 9/20
#   >>> Mejora encontrada. Costo actual: $5,378.06
#
# >>> Iteración global 2
#
#   >>> Intentando mejora en sentido ANTIHORARIO...
#
# >>> Proceso de mejora (antihorario) completado en 1 iteraciones.
# >>> Vehículos utilizados:
#   * Tipo 1: 1/20
#   * Tipo 2: 9/20
#   >>> Sin mejoras
#
#   >>> Intentando mejora en sentido HORARIO...
#
# >>> Proceso de mejora (horario) completado en 1 iteraciones.
# >>> Vehículos utilizados:
#   * Tipo 1: 1/20
#   * Tipo 2: 9/20
#   >>> Sin mejoras
#
# >>> No se encontraron más mejoras en ninguna dirección.
#
# ================================================================================
# MEJORA ITERATIVA COMPLETADA EN 2 ITERACIONES GLOBALES
# ================================================================================
#
# ================================================================================
# SOLUCIÓN
# ================================================================================
#
# >>> RESUMEN GENERAL:
#   * Número de rutas: 10
#   * Costo total: $5,378.06
#   * Distancia total: 799.03 km
#   * Cisternas Tipo 1: 1/20
#   * Cisternas Tipo 2: 9/20
#
# ================================================================================
#   [Iteración 1] Nueva mejor solución: $5,365.75
#   [Iteración 2] Nueva mejor solución: $5,276.04
#   [Iteración 11] Nueva mejor solución: $5,241.56
#   [Iteración 21] Nueva mejor solución: $4,925.71
#
# ================================================================================
# SOLUCIÓN
# ================================================================================
#
# >>> RESUMEN GENERAL:
#   * Número de rutas: 9
#   * Costo total: $4,925.71
#   * Distancia total: 797.85 km
#   * Cisternas Tipo 1: 0/20
#   * Cisternas Tipo 2: 9/20
#
# >>> DETALLE DE RUTAS:
#
#   Ruta #1:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 8 → 7 → 5 → 4 → 2 → 1 → Depot
#     Carga: Gasohol=3600gal (90.0%), Diésel=3680gal (92.0%)
#     Distancia: 68.29 km
#     Tiempo: 169.8 min
#     Costo: $506.58
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 8 (55.0, 45.0): 50.0 min (04:50) | Ventana: [04:50 - 07:10]
#       - Cliente 7 (55.0, 45.0): 55.0 min (04:55) | Ventana: [04:50 - 07:10]
#       - Cliente 5 (56.0, 39.0): 110.0 min (05:50) | Ventana: [05:50 - 07:00]
#       - Cliente 4 (65.0, 35.0): 124.8 min (06:05) | Ventana: [04:50 - 07:10]
#       - Cliente 2 (50.0, 35.0): 144.8 min (06:25) | Ventana: [04:10 - 07:20]
#       - Cliente 1 (50.0, 35.0): 149.8 min (06:30) | Ventana: [04:10 - 07:20]
#     Entregas por cliente:
#       - Cliente 8: D
#       - Cliente 7: G
#       - Cliente 5: G
#       - Cliente 4: D
#       - Cliente 2: D
#       - Cliente 1: G
#
#   Ruta #2:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 12 → 11 → 13 → 14 → Depot
#     Carga: Gasohol=2430gal (60.8%), Diésel=2450gal (61.3%)
#     Distancia: 99.89 km
#     Tiempo: 119.9 min
#     Costo: $569.77
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 12 (57.0, 68.0): 39.7 min (04:40) | Ventana: [04:30 - 06:30]
#       - Cliente 11 (57.0, 68.0): 44.7 min (04:45) | Ventana: [04:30 - 06:30]
#       - Cliente 13 (62.0, 77.0): 60.0 min (04:60) | Ventana: [04:40 - 06:00]
#       - Cliente 14 (62.0, 77.0): 65.0 min (05:05) | Ventana: [04:40 - 06:00]
#     Entregas por cliente:
#       - Cliente 12: D
#       - Cliente 11: G
#       - Cliente 13: G
#       - Cliente 14: D
#
#   Ruta #3:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 9 → 10 → 3 → 6 → 16 → 15 → Depot
#     Carga: Gasohol=3630gal (90.8%), Diésel=3520gal (88.0%)
#     Distancia: 91.64 km
#     Tiempo: 160.6 min
#     Costo: $553.27
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 9 (61.0, 52.0): 70.0 min (05:10) | Ventana: [05:10 - 06:10]
#       - Cliente 10 (61.0, 52.0): 75.0 min (05:15) | Ventana: [05:10 - 06:10]
#       - Cliente 3 (65.0, 35.0): 97.5 min (05:37) | Ventana: [04:50 - 07:10]
#       - Cliente 6 (56.0, 39.0): 112.3 min (05:52) | Ventana: [05:50 - 07:00]
#       - Cliente 16 (41.0, 49.0): 135.3 min (06:15) | Ventana: [04:10 - 07:30]
#       - Cliente 15 (41.0, 49.0): 140.3 min (06:20) | Ventana: [04:10 - 07:30]
#     Entregas por cliente:
#       - Cliente 9: G
#       - Cliente 10: D
#       - Cliente 3: G
#       - Cliente 6: D
#       - Cliente 16: D
#       - Cliente 15: G
#
#   Ruta #4:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 17 → 18 → 21 → 22 → 25 → 20 → Depot
#     Carga: Gasohol=3570gal (89.2%), Diésel=3650gal (91.2%)
#     Distancia: 83.86 km
#     Tiempo: 128.4 min
#     Costo: $537.72
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 17 (40.0, 60.0): 40.0 min (04:40) | Ventana: [04:40 - 05:50]
#       - Cliente 18 (40.0, 60.0): 45.0 min (04:45) | Ventana: [04:40 - 05:50]
#       - Cliente 21 (27.0, 69.0): 65.8 min (05:06) | Ventana: [04:30 - 07:00]
#       - Cliente 22 (27.0, 69.0): 70.8 min (05:11) | Ventana: [04:30 - 07:00]
#       - Cliente 25 (20.0, 65.0): 83.9 min (05:24) | Ventana: [04:50 - 05:30]
#       - Cliente 20 (31.0, 52.0): 105.9 min (05:46) | Ventana: [04:10 - 07:20]
#     Entregas por cliente:
#       - Cliente 17: G
#       - Cliente 18: D
#       - Cliente 21: G
#       - Cliente 22: D
#       - Cliente 25: G
#       - Cliente 20: D
#
#   Ruta #5:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 19 → 23 → 24 → 26 → 27 → 28 → Depot
#     Carga: Gasohol=3350gal (83.8%), Diésel=3410gal (85.2%)
#     Distancia: 73.83 km
#     Tiempo: 112.1 min
#     Costo: $517.67
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 19 (31.0, 52.0): 17.5 min (04:17) | Ventana: [04:10 - 07:20]
#       - Cliente 23 (24.0, 58.0): 40.0 min (04:40) | Ventana: [04:40 - 05:20]
#       - Cliente 24 (24.0, 58.0): 45.0 min (04:45) | Ventana: [04:40 - 05:20]
#       - Cliente 26 (20.0, 65.0): 58.1 min (04:58) | Ventana: [04:50 - 05:30]
#       - Cliente 27 (15.0, 60.0): 70.1 min (05:10) | Ventana: [04:30 - 06:30]
#       - Cliente 28 (15.0, 60.0): 75.1 min (05:15) | Ventana: [04:30 - 06:30]
#     Entregas por cliente:
#       - Cliente 19: G
#       - Cliente 23: G
#       - Cliente 24: D
#       - Cliente 26: D
#       - Cliente 27: G
#       - Cliente 28: D
#
#   Ruta #6:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 30 → 29 → 31 → 32 → 45 → Depot
#     Carga: Gasohol=3590gal (89.8%), Diésel=2380gal (59.5%)
#     Distancia: 94.21 km
#     Tiempo: 129.0 min
#     Costo: $558.41
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 30 (2.0, 60.0): 41.4 min (04:41) | Ventana: [04:40 - 06:00]
#       - Cliente 29 (2.0, 60.0): 46.4 min (04:46) | Ventana: [04:40 - 06:00]
#       - Cliente 31 (10.0, 43.0): 80.0 min (05:20) | Ventana: [05:20 - 06:00]
#       - Cliente 32 (10.0, 43.0): 85.0 min (05:25) | Ventana: [05:20 - 06:00]
#       - Cliente 45 (37.0, 31.0): 119.5 min (05:60) | Ventana: [05:20 - 06:00]
#     Entregas por cliente:
#       - Cliente 30: D
#       - Cliente 29: G
#       - Cliente 31: G
#       - Cliente 32: D
#       - Cliente 45: G
#
#   Ruta #7:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 35 → 36 → 33 → 34 → 44 → Depot
#     Carga: Gasohol=2310gal (57.8%), Diésel=3670gal (91.8%)
#     Distancia: 109.69 km
#     Tiempo: 152.2 min
#     Costo: $589.38
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 35 (25.0, 24.0): 14.9 min (04:15) | Ventana: [04:10 - 07:30]
#       - Cliente 36 (25.0, 24.0): 19.9 min (04:20) | Ventana: [04:10 - 07:30]
#       - Cliente 33 (5.0, 5.0): 70.0 min (05:10) | Ventana: [05:10 - 05:50]
#       - Cliente 34 (5.0, 5.0): 75.0 min (05:15) | Ventana: [05:10 - 05:50]
#       - Cliente 44 (45.0, 10.0): 120.3 min (06:00) | Ventana: [05:10 - 06:10]
#     Entregas por cliente:
#       - Cliente 35: G
#       - Cliente 36: D
#       - Cliente 33: G
#       - Cliente 34: D
#       - Cliente 44: D
#
#   Ruta #8:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 37 → 38 → 40 → 39 → 43 → 42 → Depot
#     Carga: Gasohol=3570gal (89.2%), Diésel=3670gal (91.8%)
#     Distancia: 77.94 km
#     Tiempo: 184.1 min
#     Costo: $525.88
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 37 (24.0, 12.0): 25.5 min (04:25) | Ventana: [04:20 - 05:40]
#       - Cliente 38 (24.0, 12.0): 30.5 min (04:30) | Ventana: [04:20 - 05:40]
#       - Cliente 40 (30.0, 5.0): 50.0 min (04:50) | Ventana: [04:50 - 05:30]
#       - Cliente 39 (30.0, 5.0): 55.0 min (04:55) | Ventana: [04:50 - 05:30]
#       - Cliente 43 (45.0, 10.0): 75.8 min (05:16) | Ventana: [05:10 - 06:10]
#       - Cliente 42 (36.0, 26.0): 170.0 min (06:50) | Ventana: [06:50 - 07:30]
#     Entregas por cliente:
#       - Cliente 37: G
#       - Cliente 38: D
#       - Cliente 40: D
#       - Cliente 39: G
#       - Cliente 43: G
#       - Cliente 42: D
#
#   Ruta #9:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 47 → 48 → 49 → 50 → 46 → 41 → Depot
#     Carga: Gasohol=3400gal (85.0%), Diésel=3550gal (88.8%)
#     Distancia: 98.51 km
#     Tiempo: 184.1 min
#     Costo: $567.02
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 47 (45.0, 20.0): 18.0 min (04:18) | Ventana: [04:10 - 07:20]
#       - Cliente 48 (45.0, 20.0): 23.0 min (04:23) | Ventana: [04:10 - 07:20]
#       - Cliente 49 (67.0, 5.0): 70.0 min (05:10) | Ventana: [05:10 - 05:50]
#       - Cliente 50 (67.0, 5.0): 75.0 min (05:15) | Ventana: [05:10 - 05:50]
#       - Cliente 46 (37.0, 31.0): 119.7 min (05:60) | Ventana: [05:20 - 06:00]
#       - Cliente 41 (36.0, 26.0): 170.0 min (06:50) | Ventana: [06:50 - 07:30]
#     Entregas por cliente:
#       - Cliente 47: G
#       - Cliente 48: D
#       - Cliente 49: G
#       - Cliente 50: D
#       - Cliente 46: D
#       - Cliente 41: G
#
# ================================================================================
# Solución final con costo total: $4,925.71
#
# --- Clockwise: True | Split Demands: False ---
#
# >>> Vehículos utilizados en Forward Sweep:
#   * Tipo 1: 2/20
#   * Tipo 2: 6/20
#
# ================================================================================
# SOLUCIÓN
# ================================================================================
#
# >>> RESUMEN GENERAL:
#   * Número de rutas: 8
#   * Costo total: $4,527.97
#   * Distancia total: 703.98 km
#   * Cisternas Tipo 1: 2/20
#   * Cisternas Tipo 2: 6/20
#
# ================================================================================
#
# ================================================================================
# INICIANDO MEJORA ITERATIVA (CLOCKWISE Y COUNTERCLOCKWISE)
# ================================================================================
#
# >>> Iteración global 1
#
#   >>> Intentando mejora en sentido ANTIHORARIO...
#   [Iteración 1 - antihorario] Mejora rutas 0-1: $1138.16 → $1123.74 (ahorro: $14.42)
#   [Iteración 1 - antihorario] Mejora rutas 5-6: $1237.21 → $1193.45 (ahorro: $43.76)
#
# >>> Proceso de mejora (antihorario) completado en 2 iteraciones.
# >>> Vehículos utilizados:
#   * Tipo 1: 2/20
#   * Tipo 2: 6/20
#   >>> Mejora encontrada. Costo actual: $4,469.79
#
#   >>> Intentando mejora en sentido HORARIO...
#   [Iteración 1 - horario] Mejora rutas 4-5: $1087.09 → $1075.26 (ahorro: $11.83)
#
# >>> Proceso de mejora (horario) completado en 2 iteraciones.
# >>> Vehículos utilizados:
#   * Tipo 1: 2/20
#   * Tipo 2: 6/20
#   >>> Mejora encontrada. Costo actual: $4,457.96
#
# >>> Iteración global 2
#
#   >>> Intentando mejora en sentido ANTIHORARIO...
#
# >>> Proceso de mejora (antihorario) completado en 1 iteraciones.
# >>> Vehículos utilizados:
#   * Tipo 1: 2/20
#   * Tipo 2: 6/20
#   >>> Sin mejoras
#
#   >>> Intentando mejora en sentido HORARIO...
#
# >>> Proceso de mejora (horario) completado en 1 iteraciones.
# >>> Vehículos utilizados:
#   * Tipo 1: 2/20
#   * Tipo 2: 6/20
#   >>> Sin mejoras
#
# >>> No se encontraron más mejoras en ninguna dirección.
#
# ================================================================================
# MEJORA ITERATIVA COMPLETADA EN 2 ITERACIONES GLOBALES
# ================================================================================
#
# ================================================================================
# SOLUCIÓN
# ================================================================================
#
# >>> RESUMEN GENERAL:
#   * Número de rutas: 8
#   * Costo total: $4,457.96
#   * Distancia total: 668.98 km
#   * Cisternas Tipo 1: 2/20
#   * Cisternas Tipo 2: 6/20
#
# ================================================================================
#   [Iteración 41] Nueva mejor solución: $4,371.97
#   [Iteración 42] Nueva mejor solución: $4,364.26
#   [Iteración 44] Nueva mejor solución: $4,334.61
#   [Iteración 48] Nueva mejor solución: $4,274.50
#
# ================================================================================
# SOLUCIÓN
# ================================================================================
#
# >>> RESUMEN GENERAL:
#   * Número de rutas: 8
#   * Costo total: $4,274.50
#   * Distancia total: 657.25 km
#   * Cisternas Tipo 1: 0/20
#   * Cisternas Tipo 2: 8/20
#
# >>> DETALLE DE RUTAS:
#
#   Ruta #1:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 17 → 22 → Depot
#     Carga: Gasohol=2420gal (60.5%), Diésel=2450gal (61.3%)
#     Distancia: 109.66 km
#     Tiempo: 157.2 min
#     Costo: $589.33
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 17 (5.0, 5.0): 70.0 min (05:10) | Ventana: [05:10 - 05:50]
#       - Cliente 22 (45.0, 10.0): 120.3 min (06:00) | Ventana: [05:10 - 06:10]
#     Entregas por cliente:
#       - Cliente 17: G, D
#       - Cliente 22: G, D
#
#   Ruta #2:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 1 → 15 → 16 → Depot
#     Carga: Gasohol=3620gal (90.5%), Diésel=3650gal (91.2%)
#     Distancia: 114.16 km
#     Tiempo: 144.2 min
#     Costo: $598.31
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 1 (50.0, 35.0): 15.0 min (04:15) | Ventana: [04:10 - 07:20]
#       - Cliente 15 (2.0, 60.0): 79.1 min (05:19) | Ventana: [04:40 - 06:00]
#       - Cliente 16 (10.0, 43.0): 107.9 min (05:48) | Ventana: [05:20 - 06:00]
#     Entregas por cliente:
#       - Cliente 1: G, D
#       - Cliente 15: G, D
#       - Cliente 16: G, D
#
#   Ruta #3:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 12 → 11 → 8 → Depot
#     Carga: Gasohol=3530gal (88.2%), Diésel=3560gal (89.0%)
#     Distancia: 76.54 km
#     Tiempo: 121.0 min
#     Costo: $523.08
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 12 (24.0, 58.0): 40.0 min (04:40) | Ventana: [04:40 - 05:20]
#       - Cliente 11 (27.0, 69.0): 61.4 min (05:01) | Ventana: [04:30 - 07:00]
#       - Cliente 8 (41.0, 49.0): 95.8 min (05:36) | Ventana: [04:10 - 07:30]
#     Entregas por cliente:
#       - Cliente 12: G, D
#       - Cliente 11: G, D
#       - Cliente 8: G, D
#
#   Ruta #4:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 4 → 2 → 3 → Depot
#     Carga: Gasohol=3600gal (90.0%), Diésel=3590gal (89.8%)
#     Distancia: 67.73 km
#     Tiempo: 141.4 min
#     Costo: $505.46
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 4 (55.0, 45.0): 50.0 min (04:50) | Ventana: [04:50 - 07:10]
#       - Cliente 2 (65.0, 35.0): 74.1 min (05:14) | Ventana: [04:50 - 07:10]
#       - Cliente 3 (56.0, 39.0): 110.0 min (05:50) | Ventana: [05:50 - 07:00]
#     Entregas por cliente:
#       - Cliente 4: G, D
#       - Cliente 2: G, D
#       - Cliente 3: G, D
#
#   Ruta #5:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 24 → 23 → 21 → Depot
#     Carga: Gasohol=3460gal (86.5%), Diésel=3680gal (92.0%)
#     Distancia: 45.78 km
#     Tiempo: 189.1 min
#     Costo: $461.57
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 24 (45.0, 20.0): 18.0 min (04:18) | Ventana: [04:10 - 07:20]
#       - Cliente 23 (37.0, 31.0): 80.0 min (05:20) | Ventana: [05:20 - 06:00]
#       - Cliente 21 (36.0, 26.0): 170.0 min (06:50) | Ventana: [06:50 - 07:30]
#     Entregas por cliente:
#       - Cliente 24: G, D
#       - Cliente 23: G, D
#       - Cliente 21: G, D
#
#   Ruta #6:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 14 → 13 → 10 → Depot
#     Carga: Gasohol=3400gal (85.0%), Diésel=3490gal (87.2%)
#     Distancia: 73.58 km
#     Tiempo: 104.5 min
#     Costo: $517.16
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 14 (15.0, 60.0): 32.0 min (04:32) | Ventana: [04:30 - 06:30]
#       - Cliente 13 (20.0, 65.0): 50.0 min (04:50) | Ventana: [04:50 - 05:30]
#       - Cliente 10 (31.0, 52.0): 77.0 min (05:17) | Ventana: [04:10 - 07:20]
#     Entregas por cliente:
#       - Cliente 14: G, D
#       - Cliente 13: G, D
#       - Cliente 10: G, D
#
#   Ruta #7:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 20 → 19 → 18 → Depot
#     Carga: Gasohol=3460gal (86.5%), Diésel=3660gal (91.5%)
#     Distancia: 66.54 km
#     Tiempo: 116.1 min
#     Costo: $503.08
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 20 (30.0, 5.0): 50.0 min (04:50) | Ventana: [04:50 - 05:30]
#       - Cliente 19 (24.0, 12.0): 69.2 min (05:09) | Ventana: [04:20 - 05:40]
#       - Cliente 18 (25.0, 24.0): 91.3 min (05:31) | Ventana: [04:10 - 07:30]
#     Entregas por cliente:
#       - Cliente 20: G, D
#       - Cliente 19: G, D
#       - Cliente 18: G, D
#
#   Ruta #8:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 6 → 7 → 9 → Depot
#     Carga: Gasohol=3580gal (89.5%), Diésel=3650gal (91.2%)
#     Distancia: 103.25 km
#     Tiempo: 133.3 min
#     Costo: $576.51
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 6 (57.0, 68.0): 39.7 min (04:40) | Ventana: [04:30 - 06:30]
#       - Cliente 7 (62.0, 77.0): 60.0 min (04:60) | Ventana: [04:40 - 06:00]
#       - Cliente 9 (40.0, 60.0): 97.8 min (05:38) | Ventana: [04:40 - 05:50]
#     Entregas por cliente:
#       - Cliente 6: G, D
#       - Cliente 7: G, D
#       - Cliente 9: G, D
#
# ================================================================================
# Solución final con costo total: $4,274.50
#
# --- Clockwise: True | Split Demands: True ---
#
# >>> Vehículos utilizados en Forward Sweep:
#   * Tipo 1: 3/20
#   * Tipo 2: 5/20
#
# ================================================================================
# SOLUCIÓN
# ================================================================================
#
# >>> RESUMEN GENERAL:
#   * Número de rutas: 8
#   * Costo total: $4,630.26
#   * Distancia total: 715.13 km
#   * Cisternas Tipo 1: 3/20
#   * Cisternas Tipo 2: 5/20
#
# ================================================================================
#
# ================================================================================
# INICIANDO MEJORA ITERATIVA (CLOCKWISE Y COUNTERCLOCKWISE)
# ================================================================================
#
# >>> Iteración global 1
#
#   >>> Intentando mejora en sentido ANTIHORARIO...
#
# >>> Proceso de mejora (antihorario) completado en 1 iteraciones.
# >>> Vehículos utilizados:
#   * Tipo 1: 3/20
#   * Tipo 2: 5/20
#   >>> Sin mejoras
#
#   >>> Intentando mejora en sentido HORARIO...
#
# >>> Proceso de mejora (horario) completado en 1 iteraciones.
# >>> Vehículos utilizados:
#   * Tipo 1: 3/20
#   * Tipo 2: 5/20
#   >>> Sin mejoras
#
# >>> No se encontraron más mejoras en ninguna dirección.
#
# ================================================================================
# MEJORA ITERATIVA COMPLETADA EN 1 ITERACIONES GLOBALES
# ================================================================================
#
# ================================================================================
# SOLUCIÓN
# ================================================================================
#
# >>> RESUMEN GENERAL:
#   * Número de rutas: 8
#   * Costo total: $4,630.26
#   * Distancia total: 715.13 km
#   * Cisternas Tipo 1: 3/20
#   * Cisternas Tipo 2: 5/20
#
# ================================================================================
#   [Iteración 3] Nueva mejor solución: $4,604.05
#
# ================================================================================
# SOLUCIÓN
# ================================================================================
#
# >>> RESUMEN GENERAL:
#   * Número de rutas: 8
#   * Costo total: $4,604.05
#   * Distancia total: 742.02 km
#   * Cisternas Tipo 1: 2/20
#   * Cisternas Tipo 2: 6/20
#
# >>> DETALLE DE RUTAS:
#
#   Ruta #1:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 3 → 4 → 5 → 6 → 7 → 8 → Depot
#     Carga: Gasohol=3450gal (86.2%), Diésel=3500gal (87.5%)
#     Distancia: 104.72 km
#     Tiempo: 154.7 min
#     Costo: $579.44
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 3 (65.0, 35.0): 50.0 min (04:50) | Ventana: [04:50 - 07:10]
#       - Cliente 4 (65.0, 35.0): 55.0 min (04:55) | Ventana: [04:50 - 07:10]
#       - Cliente 5 (67.0, 5.0): 90.1 min (05:30) | Ventana: [05:10 - 05:50]
#       - Cliente 6 (67.0, 5.0): 95.1 min (05:35) | Ventana: [05:10 - 05:50]
#       - Cliente 7 (45.0, 20.0): 126.7 min (06:07) | Ventana: [04:10 - 07:20]
#       - Cliente 8 (45.0, 20.0): 131.7 min (06:12) | Ventana: [04:10 - 07:20]
#     Entregas por cliente:
#       - Cliente 3: G
#       - Cliente 4: D
#       - Cliente 5: G
#       - Cliente 6: D
#       - Cliente 7: G
#       - Cliente 8: D
#
#   Ruta #2:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 9 → 10 → 11 → 12 → 13 → 14 → Depot
#     Carga: Gasohol=3610gal (90.2%), Diésel=3730gal (93.2%)
#     Distancia: 54.36 km
#     Tiempo: 189.1 min
#     Costo: $478.71
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 9 (37.0, 31.0): 80.0 min (05:20) | Ventana: [05:20 - 06:00]
#       - Cliente 10 (37.0, 31.0): 85.0 min (05:25) | Ventana: [05:20 - 06:00]
#       - Cliente 11 (45.0, 10.0): 112.5 min (05:52) | Ventana: [05:10 - 06:10]
#       - Cliente 12 (45.0, 10.0): 117.5 min (05:57) | Ventana: [05:10 - 06:10]
#       - Cliente 13 (36.0, 26.0): 170.0 min (06:50) | Ventana: [06:50 - 07:30]
#       - Cliente 14 (36.0, 26.0): 175.0 min (06:55) | Ventana: [06:50 - 07:30]
#     Entregas por cliente:
#       - Cliente 9: G
#       - Cliente 10: D
#       - Cliente 11: G
#       - Cliente 12: D
#       - Cliente 13: G
#       - Cliente 14: D
#
#   Ruta #3:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 21 → 22 → 48 → 49 → Depot
#     Carga: Gasohol=2370gal (59.2%), Diésel=2410gal (60.2%)
#     Distancia: 133.92 km
#     Tiempo: 181.5 min
#     Costo: $637.84
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 21 (5.0, 5.0): 70.0 min (05:10) | Ventana: [05:10 - 05:50]
#       - Cliente 22 (5.0, 5.0): 75.0 min (05:15) | Ventana: [05:10 - 05:50]
#       - Cliente 48 (55.0, 45.0): 144.0 min (06:24) | Ventana: [04:50 - 07:10]
#       - Cliente 49 (56.0, 39.0): 155.1 min (06:35) | Ventana: [05:50 - 07:00]
#     Entregas por cliente:
#       - Cliente 21: G
#       - Cliente 22: D
#       - Cliente 48: D
#       - Cliente 49: G
#
#   Ruta #4:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 23 → 24 → 25 → 26 → 27 → 28 → Depot
#     Carga: Gasohol=3510gal (87.8%), Diésel=3500gal (87.5%)
#     Distancia: 90.05 km
#     Tiempo: 173.8 min
#     Costo: $550.11
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 23 (10.0, 43.0): 80.0 min (05:20) | Ventana: [05:20 - 06:00]
#       - Cliente 24 (10.0, 43.0): 85.0 min (05:25) | Ventana: [05:20 - 06:00]
#       - Cliente 25 (2.0, 60.0): 108.8 min (05:49) | Ventana: [04:40 - 06:00]
#       - Cliente 26 (2.0, 60.0): 113.8 min (05:54) | Ventana: [04:40 - 06:00]
#       - Cliente 27 (15.0, 60.0): 131.8 min (06:12) | Ventana: [04:30 - 06:30]
#       - Cliente 28 (15.0, 60.0): 136.8 min (06:17) | Ventana: [04:30 - 06:30]
#     Entregas por cliente:
#       - Cliente 23: G
#       - Cliente 24: D
#       - Cliente 25: G
#       - Cliente 26: D
#       - Cliente 27: G
#       - Cliente 28: D
#
#   Ruta #5:
#     Cisterna: Tipo 1
#     Secuencia: Depot → 29 → 30 → 31 → 32 → 33 → 34 → 35 → 36 → Depot
#     Carga: Gasohol=4640gal (80.0%), Diésel=4740gal (91.2%)
#     Distancia: 103.22 km
#     Tiempo: 159.7 min
#     Costo: $656.43
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 29 (20.0, 65.0): 50.0 min (04:50) | Ventana: [04:50 - 05:30]
#       - Cliente 30 (20.0, 65.0): 55.0 min (04:55) | Ventana: [04:50 - 05:30]
#       - Cliente 31 (24.0, 58.0): 68.1 min (05:08) | Ventana: [04:40 - 05:20]
#       - Cliente 32 (24.0, 58.0): 73.1 min (05:13) | Ventana: [04:40 - 05:20]
#       - Cliente 33 (31.0, 52.0): 87.3 min (05:27) | Ventana: [04:10 - 07:20]
#       - Cliente 34 (31.0, 52.0): 92.3 min (05:32) | Ventana: [04:10 - 07:20]
#       - Cliente 35 (27.0, 69.0): 114.7 min (05:55) | Ventana: [04:30 - 07:00]
#       - Cliente 36 (27.0, 69.0): 119.7 min (05:60) | Ventana: [04:30 - 07:00]
#     Entregas por cliente:
#       - Cliente 29: G
#       - Cliente 30: D
#       - Cliente 31: G
#       - Cliente 32: D
#       - Cliente 33: G
#       - Cliente 34: D
#       - Cliente 35: G
#       - Cliente 36: D
#
#   Ruta #6:
#     Cisterna: Tipo 1
#     Secuencia: Depot → 37 → 38 → 39 → 40 → 41 → 42 → 43 → 44 → Depot
#     Carga: Gasohol=4740gal (81.7%), Diésel=4840gal (93.1%)
#     Distancia: 121.50 km
#     Tiempo: 176.0 min
#     Costo: $692.99
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 37 (40.0, 60.0): 40.0 min (04:40) | Ventana: [04:40 - 05:50]
#       - Cliente 38 (40.0, 60.0): 45.0 min (04:45) | Ventana: [04:40 - 05:50]
#       - Cliente 39 (41.0, 49.0): 61.0 min (05:01) | Ventana: [04:10 - 07:30]
#       - Cliente 40 (41.0, 49.0): 66.0 min (05:06) | Ventana: [04:10 - 07:30]
#       - Cliente 41 (62.0, 77.0): 106.0 min (05:46) | Ventana: [04:40 - 06:00]
#       - Cliente 42 (62.0, 77.0): 111.0 min (05:51) | Ventana: [04:40 - 06:00]
#       - Cliente 43 (57.0, 68.0): 126.3 min (06:06) | Ventana: [04:30 - 06:30]
#       - Cliente 44 (57.0, 68.0): 131.3 min (06:11) | Ventana: [04:30 - 06:30]
#     Entregas por cliente:
#       - Cliente 37: G
#       - Cliente 38: D
#       - Cliente 39: G
#       - Cliente 40: D
#       - Cliente 41: G
#       - Cliente 42: D
#       - Cliente 43: G
#       - Cliente 44: D
#
#   Ruta #7:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 47 → 45 → 46 → 50 → 1 → 2 → Depot
#     Carga: Gasohol=3670gal (91.8%), Diésel=3600gal (90.0%)
#     Distancia: 67.72 km
#     Tiempo: 147.2 min
#     Costo: $505.44
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 47 (55.0, 45.0): 50.0 min (04:50) | Ventana: [04:50 - 07:10]
#       - Cliente 45 (61.0, 52.0): 70.0 min (05:10) | Ventana: [05:10 - 06:10]
#       - Cliente 46 (61.0, 52.0): 75.0 min (05:15) | Ventana: [05:10 - 06:10]
#       - Cliente 50 (56.0, 39.0): 110.0 min (05:50) | Ventana: [05:50 - 07:00]
#       - Cliente 1 (50.0, 35.0): 122.2 min (06:02) | Ventana: [04:10 - 07:20]
#       - Cliente 2 (50.0, 35.0): 127.2 min (06:07) | Ventana: [04:10 - 07:20]
#     Entregas por cliente:
#       - Cliente 47: G
#       - Cliente 45: G
#       - Cliente 46: D
#       - Cliente 50: D
#       - Cliente 1: G
#       - Cliente 2: D
#
#   Ruta #8:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 20 → 19 → 18 → 17 → 15 → 16 → Depot
#     Carga: Gasohol=3460gal (86.5%), Diésel=3660gal (91.5%)
#     Distancia: 66.54 km
#     Tiempo: 96.5 min
#     Costo: $503.08
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 20 (25.0, 24.0): 14.9 min (04:15) | Ventana: [04:10 - 07:30]
#       - Cliente 19 (25.0, 24.0): 19.9 min (04:20) | Ventana: [04:10 - 07:30]
#       - Cliente 18 (24.0, 12.0): 36.9 min (04:37) | Ventana: [04:20 - 05:40]
#       - Cliente 17 (24.0, 12.0): 41.9 min (04:42) | Ventana: [04:20 - 05:40]
#       - Cliente 15 (30.0, 5.0): 56.1 min (04:56) | Ventana: [04:50 - 05:30]
#       - Cliente 16 (30.0, 5.0): 61.1 min (05:01) | Ventana: [04:50 - 05:30]
#     Entregas por cliente:
#       - Cliente 20: D
#       - Cliente 19: G
#       - Cliente 18: D
#       - Cliente 17: G
#       - Cliente 15: G
#       - Cliente 16: D
#
# ================================================================================
# Solución final con costo total: $4,604.05
#
# === Mejor configuración encontrada: Clockwise=True, Split Demands=False con costo total: $4,274.50 ===
