# %% [markdown]
# Connected to Python 3.10.12

# %%
"""
Problema de ruteo de vehiculos con multiples compartimento, flota heterogenea y ventanas de tiempo.

0. Contexto:
    PetroAndes Logistics S.A.C. es una empresa dedicada a la distribución de combustibles líquidos, principalmente gasohol 90 y diésel B5, hacia estaciones de servicio y clientes industriales en el sur del país. 
    
    Cada día la empresa alquila cisternas a transportistas con los que mantiene contratos que establecen tarifas diferenciadas según el tamaño del vehículo y el costo por kilómetro recorrido. 
    
    Al inicio de cada jornada se reciben los pedidos de los clientes, se consolida la demanda total y se debe decidir qué cisternas alquilar, cuánto producto cargará cada una y en qué orden se realizarán las entregas.

    Las cisternas utilizadas son vehículos con dos compartimentos, diseñados para transportar simultáneamente gasohol y diésel sin riesgo de mezcla entre productos. 
    
    La flota está compuesta por dos tipos de unidades, y cada tipo cuenta con un volumen específico asignado a cada producto. 

    Cada unidad realiza una única ruta por jornada, la cual comienza y termina en la almacen de despacho. 
    
    Una vez que un vehículo completa su recorrido y retorna al almacen, no puede volver a salir durante el mismo día.

    Un aspecto operativo crítico son los horarios de atención de los clientes. 
    Las estaciones no pueden recibir combustible en cualquier momento del día, estas ventanas de tiempo son propias de cada cliente y responden a regulaciones de seguridad o políticas internas de cada negocio. 
    Si una cisterna arriba antes del inicio de la ventana a un cliente, puede esperar hasta el horario permitido para iniciar la descarga, sin embargo, si llega después del límite establecido, no puede iniciar ese proceso.

    Cada cliente demanda cantidades específicas de gasohol y diésel, que deben entregarse en una sola visita por producto. 
    
    Un cliente puede ser atendido una única vez si una cisterna entrega ambos combustibles en la misma parada, o con dos cisternas distintas si cada producto se despacha por separado. No está permitido que más de una cisterna atienda el mismo tipo de producto en un mismo cliente. 
    
    Cada entrega tiene un tiempo de descarga definido, y cuando ambos productos se entregan en la misma visita, el tiempo total corresponde a la suma de los tiempos de descarga de cada combustible. 
    
    Los compartimentos de las cisternas son exclusivos para un solo tipo de producto.

    El crecimiento del número de clientes y la variabilidad diaria de la demanda han hecho que la planificación manual resulte insuficiente. Cada error en la asignación de cisternas puede traducirse en retrasos, sobrecostos o incluso en la pérdida de clientes por falta de abastecimiento oportuno. Contar con un programa que asista al gerente de operaciones en la toma de decisiones diarias se ha vuelto crucial para evitar pérdidas y garantizar la continuidad del servicio. 

    INSTANCIAS:

        La flota disponible es fija en todas las instancias y está compuesta por dos tipos de cisternas, con 20 unidades de cada tipo. 
        Los parámetros asociados a cada tipo se detallan a continuación:

        Tipo | Cap. Gasohol | Cap. Diésel | Costo fijo | Costo por km
        -----|--------------|------------|-----------|-------------
        1    | 5800         | 5200       | 450       | 2
        2    | 4000         | 4000       | 370       | 2

        Se asume una velocidad promedio constante de 60 km/h para todos los desplazamientos, sin variaciones horarias. 
        Las capacidades de los compartimentos están expresadas en galones y todos los costos se encuentran en dólares estadounidenses (US$). 
        Además, se considera que el tiempo de servicio en cada cliente es fijo e igual a 5 minutos, independientemente de la cantidad entregada. Si ambos combustibles se entregan en la misma visita, el tiempo total será de 10 minutos.

    EJEMPLO DE FORMATO DE ARCHIVO DE INSTANCIA (.csv):

            id, x,    y,    Gasohol,  Diésel,   Inicio,  Fin
            0,  35.0, 35.0, 0,        0,        04:00,   09:00
            36, 2.0,  60.0, 810,      790,      04:40,   06:00
            68, 56.0, 39.0, 760,      780,      05:50,   07:00
            22, 45.0, 10.0, 810,      850,      05:10,   06:10
            3,  55.0, 45.0, 800,      810,      04:50,   07:10
            31, 31.0, 52.0, 710,      840,      04:10,   07:20
            42, 24.0, 12.0, 810,      800,      04:20,   05:40
            8,  10.0, 10.0, 770,      790,      05:20,   06:00
            24, 65.0, 35.0, 840,      800,      04:50,   07:10
            53, 37.0, 31.0, 810,      850,      05:20,   06:00
            63, 27.0, 69.0, 860,      810,      04:30,   07:00

        Las distancias entre el almacén y los clientes, así como entre clientes, se calculan utilizando la distancia euclidiana a partir de sus coordenadas (x, y) expresadas en kilómetros. 
        Además, se establece que las cisternas pueden iniciar sus rutas a partir de las 04:00 horas y deben retornar al almacén antes de las 09:00 horas del mismo día.

Funcion Objetivo: Minimizar el costo diario de operacion, considerando el alquiler de cisternas y la distancia recorrida por los vehiculos, garantizando la atención completa de todos los clientes dentro de sus ventanas de tiempo.
"""

import os, sys
os.chdir(os.path.dirname(os.path.abspath(__file__)))

import pandas as pd
import numpy as np
from IPython.display import display
from typing import List, Dict
import random

from models import ProblemInstance, Ruta, SolutionVisualizer
from solvers import SweepAlgorithm, SolverTabuSearchMCVRPTW

pd.set_option('display.float_format', lambda x: '%.2f' % x)
np.set_printoptions(precision=2, suppress=True)

SEED = 42
np.random.seed(SEED)
random.seed(SEED)


# -----------------------------------------------------------------------------
# Utility Functions for Data Preprocessing
# -----------------------------------------------------------------------------

def time_to_minutes(time_str):
    """Convertir ventanas de tiempo a minutos desde 04:00"""
    h, m = map(int, time_str.split(':'))
    return (h - 4) * 60 + m


def polar_coordinate_angle(x, y, depot_x, depot_y):
    """Calculate the angle of a point (x, y) with respect to a depot in polar coordinates."""
    delta_x = x - depot_x
    delta_y = y - depot_y
    angle = np.arctan2(delta_y, delta_x)
    return angle if angle >= 0 else angle + 2 * np.pi


def clockwise_angle(angle_ccw):
    """Convierte un ángulo CCW a su equivalente horario en [0, 2π)."""
    return (-angle_ccw) % (2 * np.pi)


def radius(x, y, depot_x, depot_y):
    """
    Calculate the radius of a point (x, y) with respect to a depot (depot_x, depot_y)
    in polar coordinates.
    """
    return np.sqrt((x - depot_x) ** 2 + (y - depot_y) ** 2)


def split_client_demands(df: pd.DataFrame) -> pd.DataFrame:
    """Split demands into two rows: one for gasohol and another for diesel."""
    gasohol_df = df.copy()
    gasohol_df["tipo_combustible"] = "gasohol"
    gasohol_df["demanda_diesel"] = 0

    diesel_df = df.copy()
    diesel_df["tipo_combustible"] = "diesel"
    diesel_df["demanda_gasohol"] = 0

    df_split_demands = (
        pd.concat([gasohol_df, diesel_df], ignore_index=True)
        .sort_values(by=['AN', 'R'])
        .drop_duplicates(subset=['index', 'demanda_gasohol', 'demanda_diesel'], keep='first')
        .assign(old_index=lambda x: x.index)
        .drop(columns=['index'])
        .reset_index(drop=True).reset_index(drop=False)
    )
    
    return df_split_demands


# -----------------------------------------------------------------------------
# Load and Preprocess Data
# -----------------------------------------------------------------------------

df = (
    pd.read_csv('./instancias/25_clientes_1.csv')
    .reset_index(drop=False)
)

df['E'] = df['ventana_inicio'].apply(time_to_minutes)
df['L'] = df['ventana_fin'].apply(time_to_minutes)

df['AN'] = df.apply(
    lambda row: polar_coordinate_angle(row['x'], row['y'], df.loc[0, 'x'], df.loc[0, 'y']), axis=1
)

df['R'] = df.apply(
    lambda row: radius(row['x'], row['y'], df.loc[0, 'x'], df.loc[0, 'y']), axis=1
)

# Reorder according to polar-coordinate angle and distance
df = (
    df.sort_values(by=['AN', 'R'])
    .rename(columns={'index': 'old_index'})
    .reset_index(drop=True).reset_index(drop=False)
)
# display(df)


# -----------------------------------------------------------------------------
# Problem Parameters
# -----------------------------------------------------------------------------

tipos_cisternas = {
    1: {'cap_gasohol': 5800, 'cap_diesel': 5200, 'costo_fijo': 450, 'costo_km': 2},
    2: {'cap_gasohol': 4000, 'cap_diesel': 4000, 'costo_fijo': 370, 'costo_km': 2}
}

# -----------------------------------------------------------------------------
# Main Algorithm
# -----------------------------------------------------------------------------

def tabu_search_mcvrptw(data: pd.DataFrame, tipos_cisternas: Dict, 
                       clockwise: bool = False, I: int = 1000, 
                       split_demands: bool = False,
                       num_vehiculos_por_tipo: int = 20,
                       velocidad: float = 60, 
                       tiempo_descarga: float = 5):
    """
    Iterated Tabu Search para MCVRPTW.
    
    Basado en Silvestrin (2017) - 'An Iterated Tabu Search for Multi-Compartment Vehicle Routing Problem'
    
    Pseudo-código:
        function ITS()
            s <- SweepConstruction()
            s <- TabuSearch(s)
            for i = 1, ..., I iterations do
                s' <- Perturb(s)
                s <- TabuSearch(s')
                with probability (i / I)^2: s <- s'
            end for
            return the best solution s' found during search
        end function
    """
    df_input = data.copy()
    if clockwise:
        df_input['AN'] = df_input['AN'].apply(clockwise_angle)
    if split_demands:
        df_input = split_client_demands(df_input)

    instance = ProblemInstance(
        df_input, tipos_cisternas, num_vehiculos_por_tipo, 
        velocidad, tiempo_descarga
    )
    visualizer = SolutionVisualizer(instance)
    
    sweep_solver = SweepAlgorithm(instance)
    
    # Construcción inicial con Angular Sweep
    rutas = sweep_solver.forward_sweep()
    visualizer.imprimir_solucion(rutas, 1)
    # visualizer.visualizar_rutas(rutas, "Forward Sweep")

    # Mejora con "2-opt" bidireccional
    rutas = sweep_solver.iterative_improving_sweep(rutas)
    visualizer.imprimir_solucion(rutas, 1)
    visualizer.visualizar_rutas(rutas, "Forward Sweep + 2-opt bidirectional")

    # Iterated Tabu Search
    tabu_solver = SolverTabuSearchMCVRPTW(sweep_solver)
    best_solution = rutas
    best_cost = sum(r.costo_total for r in best_solution)

    for iteration in range(1, I + 1):
        rutas_perturbadas = tabu_solver.perturbation(rutas)
        rutas = tabu_solver.tabu_search(rutas_perturbadas, iteration)

        prob = (iteration / I) ** 2
        if random.random() < prob:
            rutas = rutas_perturbadas
        
        current_cost = sum(r.costo_total for r in rutas)
        if current_cost < best_cost:
            best_solution = rutas
            best_cost = current_cost
            print(f"  [Iteración {iteration}] Nueva mejor solución: ${best_cost:,.2f}")
    
    visualizer.imprimir_solucion(best_solution, 2)
    visualizer.visualizar_rutas(best_solution, "Iterated Tabu Search - Final Solution")
    return best_solution, best_cost


# -----------------------------------------------------------------------------
# Execute
# -----------------------------------------------------------------------------

best_cost_solution = float('inf')
best_config = {}
for cc in [False, True]:
    for sd in [False, True]:
        try:
            print(f"\n--- Clockwise: {cc} | Split Demands: {sd} ---")
            rutas_solucion, costo = tabu_search_mcvrptw(df, tipos_cisternas, clockwise=cc, split_demands=sd, I=50)
            print(f"Solución final con costo total: ${costo:,.2f}")
            if costo < best_cost_solution:
                best_cost_solution = costo
                best_config = {'clockwise': cc, 'split_demands': sd}
        except Exception as e:
            print(f"Error con configuración Clockwise={cc}, Split Demands={sd}: {e}")
            import traceback
            traceback.print_exc()
            raise e
    #     break
    # break

print(f"\n=== Mejor configuración encontrada: Clockwise={best_config['clockwise']}, Split Demands={best_config['split_demands']} con costo total: ${best_cost_solution:,.2f} ===")
# Out:
# --- Clockwise: False | Split Demands: False ---
#
# >>> Vehículos utilizados en Forward Sweep:
#   * Tipo 1: 0/20
#   * Tipo 2: 9/20
#
# ================================================================================
# SOLUCIÓN
# ================================================================================
#
# >>> RESUMEN GENERAL:
#   * Número de rutas: 9
#   * Costo total: $4,796.15
#   * Distancia total: 733.08 km
#   * Cisternas Tipo 1: 0/20
#   * Cisternas Tipo 2: 9/20
#
# ================================================================================
#
# ================================================================================
# INICIANDO MEJORA ITERATIVA (CLOCKWISE Y COUNTERCLOCKWISE)
# ================================================================================
#
# >>> Iteración global 1
#
#   >>> Intentando mejora en sentido ANTIHORARIO...
#   [Iteración 1 - antihorario] Mejora rutas 2-3: $1109.92 → $1103.54 (ahorro: $6.37)
#   [Iteración 1 - antihorario] Mejora rutas 2-3: $1103.54 → $1062.86 (ahorro: $40.68)
#   [Iteración 1 - antihorario] Mejora rutas 4-5: $1014.75 → $1013.47 (ahorro: $1.28)
#   [Iteración 1 - antihorario] Mejora rutas 5-6: $1085.23 → $1057.42 (ahorro: $27.80)
#   [Iteración 1 - antihorario] Mejora rutas 6-7: $1007.05 → $954.94 (ahorro: $52.11)
#   [Iteración 2 - antihorario] Mejora rutas 4-5: $1011.89 → $980.56 (ahorro: $31.34)
#
# >>> Proceso de mejora (antihorario) completado en 3 iteraciones.
# >>> Vehículos utilizados:
#   * Tipo 1: 0/20
#   * Tipo 2: 9/20
#   >>> Mejora encontrada. Costo actual: $4,636.56
#
#   >>> Intentando mejora en sentido HORARIO...
#
# >>> Proceso de mejora (horario) completado en 1 iteraciones.
# >>> Vehículos utilizados:
#   * Tipo 1: 0/20
#   * Tipo 2: 9/20
#   >>> Sin mejoras
#
# >>> Iteración global 2
#
#   >>> Intentando mejora en sentido ANTIHORARIO...
#
# >>> Proceso de mejora (antihorario) completado en 1 iteraciones.
# >>> Vehículos utilizados:
#   * Tipo 1: 0/20
#   * Tipo 2: 9/20
#   >>> Sin mejoras
#
#   >>> Intentando mejora en sentido HORARIO...
#
# >>> Proceso de mejora (horario) completado en 1 iteraciones.
# >>> Vehículos utilizados:
#   * Tipo 1: 0/20
#   * Tipo 2: 9/20
#   >>> Sin mejoras
#
# >>> No se encontraron más mejoras en ninguna dirección.
#
# ================================================================================
# MEJORA ITERATIVA COMPLETADA EN 2 ITERACIONES GLOBALES
# ================================================================================
#
# ================================================================================
# SOLUCIÓN
# ================================================================================
#
# >>> RESUMEN GENERAL:
#   * Número de rutas: 9
#   * Costo total: $4,636.56
#   * Distancia total: 653.28 km
#   * Cisternas Tipo 1: 0/20
#   * Cisternas Tipo 2: 9/20
#
# ================================================================================
#   [Iteración 1] Nueva mejor solución: $4,233.41
#   [Iteración 2] Nueva mejor solución: $3,793.53
#   [Iteración 3] Nueva mejor solución: $3,396.25
#   [Iteración 4] Nueva mejor solución: $3,395.31
#
# ================================================================================
# SOLUCIÓN
# ================================================================================
#
# >>> RESUMEN GENERAL:
#   * Número de rutas: 6
#   * Costo total: $3,395.31
#   * Distancia total: 587.65 km
#   * Cisternas Tipo 1: 0/20
#   * Cisternas Tipo 2: 6/20
#
# >>> DETALLE DE RUTAS:
#
#   Ruta #1:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 8 → 5 → 4 → 3 → 1 → Depot
#     Carga: Gasohol=3970gal (99.2%), Diésel=4000gal (100.0%)
#     Distancia: 72.97 km
#     Tiempo: 152.2 min
#     Costo: $515.94
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 8 (41.0, 49.0): 15.2 min (04:15) | Ventana: [04:10 - 07:30]
#       - Cliente 5 (61.0, 52.0): 70.0 min (05:10) | Ventana: [05:10 - 06:10]
#       - Cliente 4 (55.0, 45.0): 89.2 min (05:29) | Ventana: [04:50 - 07:10]
#       - Cliente 3 (56.0, 39.0): 110.0 min (05:50) | Ventana: [05:50 - 07:00]
#       - Cliente 1 (50.0, 35.0): 127.2 min (06:07) | Ventana: [04:10 - 07:20]
#     Entregas por cliente:
#       - Cliente 8: G, D
#       - Cliente 5: G, D
#       - Cliente 4: G, D
#       - Cliente 3: G, D
#       - Cliente 1: G, D
#
#   Ruta #2:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 12 → 11 → 13 → 14 → 15 → Depot
#     Carga: Gasohol=3740gal (93.5%), Diésel=3810gal (95.2%)
#     Distancia: 106.43 km
#     Tiempo: 170.9 min
#     Costo: $582.86
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 12 (24.0, 58.0): 40.0 min (04:40) | Ventana: [04:40 - 05:20]
#       - Cliente 11 (27.0, 69.0): 61.4 min (05:01) | Ventana: [04:30 - 07:00]
#       - Cliente 13 (20.0, 65.0): 79.5 min (05:19) | Ventana: [04:50 - 05:30]
#       - Cliente 14 (15.0, 60.0): 96.5 min (05:37) | Ventana: [04:30 - 06:30]
#       - Cliente 15 (2.0, 60.0): 119.5 min (05:60) | Ventana: [04:40 - 06:00]
#     Entregas por cliente:
#       - Cliente 12: G, D
#       - Cliente 11: G, D
#       - Cliente 13: G, D
#       - Cliente 14: G, D
#       - Cliente 15: G, D
#
#   Ruta #3:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 10 → 9 → 7 → 6 → Depot
#     Carga: Gasohol=2990gal (74.8%), Diésel=3290gal (82.2%)
#     Distancia: 107.27 km
#     Tiempo: 147.8 min
#     Costo: $584.53
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 10 (31.0, 52.0): 17.5 min (04:17) | Ventana: [04:10 - 07:20]
#       - Cliente 9 (40.0, 60.0): 40.0 min (04:40) | Ventana: [04:40 - 05:50]
#       - Cliente 7 (62.0, 77.0): 77.8 min (05:18) | Ventana: [04:40 - 06:00]
#       - Cliente 6 (57.0, 68.0): 98.1 min (05:38) | Ventana: [04:30 - 06:30]
#     Entregas por cliente:
#       - Cliente 10: G, D
#       - Cliente 9: G, D
#       - Cliente 7: G, D
#       - Cliente 6: G, D
#
#   Ruta #4:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 2 → 25 → 22 → Depot
#     Carga: Gasohol=2390gal (59.8%), Diésel=2350gal (58.8%)
#     Distancia: 109.55 km
#     Tiempo: 159.6 min
#     Costo: $589.11
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 2 (65.0, 35.0): 50.0 min (04:50) | Ventana: [04:50 - 07:10]
#       - Cliente 25 (67.0, 5.0): 90.1 min (05:30) | Ventana: [05:10 - 05:50]
#       - Cliente 22 (45.0, 10.0): 122.6 min (06:03) | Ventana: [05:10 - 06:10]
#     Entregas por cliente:
#       - Cliente 2: G, D
#       - Cliente 25: G, D
#       - Cliente 22: G, D
#
#   Ruta #5:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 19 → 20 → 17 → 18 → Depot
#     Carga: Gasohol=2940gal (73.5%), Diésel=3260gal (81.5%)
#     Distancia: 102.17 km
#     Tiempo: 147.5 min
#     Costo: $574.33
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 19 (24.0, 12.0): 25.5 min (04:25) | Ventana: [04:20 - 05:40]
#       - Cliente 20 (30.0, 5.0): 50.0 min (04:50) | Ventana: [04:50 - 05:30]
#       - Cliente 17 (5.0, 5.0): 85.0 min (05:25) | Ventana: [05:10 - 05:50]
#       - Cliente 18 (25.0, 24.0): 122.6 min (06:03) | Ventana: [04:10 - 07:30]
#     Entregas por cliente:
#       - Cliente 19: G, D
#       - Cliente 20: G, D
#       - Cliente 17: G, D
#       - Cliente 18: G, D
#
#   Ruta #6:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 16 → 23 → 24 → 21 → Depot
#     Carga: Gasohol=2850gal (71.2%), Diésel=3270gal (81.8%)
#     Distancia: 89.27 km
#     Tiempo: 189.1 min
#     Costo: $548.54
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 16 (10.0, 43.0): 80.0 min (05:20) | Ventana: [05:20 - 06:00]
#       - Cliente 23 (37.0, 31.0): 119.5 min (05:60) | Ventana: [05:20 - 06:00]
#       - Cliente 24 (45.0, 20.0): 143.1 min (06:23) | Ventana: [04:10 - 07:20]
#       - Cliente 21 (36.0, 26.0): 170.0 min (06:50) | Ventana: [06:50 - 07:30]
#     Entregas por cliente:
#       - Cliente 16: G, D
#       - Cliente 23: G, D
#       - Cliente 24: G, D
#       - Cliente 21: G, D
#
# ================================================================================
# Solución final con costo total: $3,395.31
#
# --- Clockwise: False | Split Demands: True ---
#
# >>> Vehículos utilizados en Forward Sweep:
#   * Tipo 1: 0/20
#   * Tipo 2: 10/20
#
# ================================================================================
# SOLUCIÓN
# ================================================================================
#
# >>> RESUMEN GENERAL:
#   * Número de rutas: 10
#   * Costo total: $5,365.87
#   * Distancia total: 832.94 km
#   * Cisternas Tipo 1: 0/20
#   * Cisternas Tipo 2: 10/20
#
# ================================================================================
#
# ================================================================================
# INICIANDO MEJORA ITERATIVA (CLOCKWISE Y COUNTERCLOCKWISE)
# ================================================================================
#
# >>> Iteración global 1
#
#   >>> Intentando mejora en sentido ANTIHORARIO...
#   [Iteración 1 - antihorario] Mejora rutas 1-2: $1155.89 → $1088.60 (ahorro: $67.28)
#   [Iteración 1 - antihorario] Mejora rutas 1-2: $1088.60 → $1085.12 (ahorro: $3.48)
#   [Iteración 1 - antihorario] Mejora rutas 1-2: $1085.12 → $1077.16 (ahorro: $7.96)
#   [Iteración 1 - antihorario] Mejora rutas 2-3: $1044.12 → $1016.73 (ahorro: $27.39)
#   [Iteración 1 - antihorario] Mejora rutas 7-8: $1033.28 → $1005.19 (ahorro: $28.09)
#   [Iteración 1 - antihorario] Mejora rutas 8-9: $1029.05 → $964.50 (ahorro: $64.54)
#   [Iteración 2 - antihorario] Mejora rutas 6-7: $1061.35 → $1055.55 (ahorro: $5.80)
#
# >>> Proceso de mejora (antihorario) completado en 3 iteraciones.
# >>> Vehículos utilizados:
#   * Tipo 1: 0/20
#   * Tipo 2: 10/20
#   >>> Mejora encontrada. Costo actual: $5,161.32
#
#   >>> Intentando mejora en sentido HORARIO...
#
# >>> Proceso de mejora (horario) completado en 1 iteraciones.
# >>> Vehículos utilizados:
#   * Tipo 1: 0/20
#   * Tipo 2: 10/20
#   >>> Sin mejoras
#
# >>> Iteración global 2
#
#   >>> Intentando mejora en sentido ANTIHORARIO...
#
# >>> Proceso de mejora (antihorario) completado en 1 iteraciones.
# >>> Vehículos utilizados:
#   * Tipo 1: 0/20
#   * Tipo 2: 10/20
#   >>> Sin mejoras
#
#   >>> Intentando mejora en sentido HORARIO...
#
# >>> Proceso de mejora (horario) completado en 1 iteraciones.
# >>> Vehículos utilizados:
#   * Tipo 1: 0/20
#   * Tipo 2: 10/20
#   >>> Sin mejoras
#
# >>> No se encontraron más mejoras en ninguna dirección.
#
# ================================================================================
# MEJORA ITERATIVA COMPLETADA EN 2 ITERACIONES GLOBALES
# ================================================================================
#
# ================================================================================
# SOLUCIÓN
# ================================================================================
#
# >>> RESUMEN GENERAL:
#   * Número de rutas: 10
#   * Costo total: $5,161.32
#   * Distancia total: 730.66 km
#   * Cisternas Tipo 1: 0/20
#   * Cisternas Tipo 2: 10/20
#
# ================================================================================
#   [Iteración 1] Nueva mejor solución: $4,349.47
#   [Iteración 2] Nueva mejor solución: $4,333.93
#
# ================================================================================
# SOLUCIÓN
# ================================================================================
#
# >>> RESUMEN GENERAL:
#   * Número de rutas: 8
#   * Costo total: $4,333.93
#   * Distancia total: 686.96 km
#   * Cisternas Tipo 1: 0/20
#   * Cisternas Tipo 2: 8/20
#
# >>> DETALLE DE RUTAS:
#
#   Ruta #1:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 8 → 7 → 5 → 6 → 4 → 3 → 1 → 2 → Depot
#     Carga: Gasohol=3270gal (81.8%), Diésel=3260gal (81.5%)
#     Distancia: 68.29 km
#     Tiempo: 179.8 min
#     Costo: $506.58
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 8 (55.0, 45.0): 50.0 min (04:50) | Ventana: [04:50 - 07:10]
#       - Cliente 7 (55.0, 45.0): 55.0 min (04:55) | Ventana: [04:50 - 07:10]
#       - Cliente 5 (56.0, 39.0): 110.0 min (05:50) | Ventana: [05:50 - 07:00]
#       - Cliente 6 (56.0, 39.0): 115.0 min (05:55) | Ventana: [05:50 - 07:00]
#       - Cliente 4 (65.0, 35.0): 129.8 min (06:10) | Ventana: [04:50 - 07:10]
#       - Cliente 3 (65.0, 35.0): 134.8 min (06:15) | Ventana: [04:50 - 07:10]
#       - Cliente 1 (50.0, 35.0): 154.8 min (06:35) | Ventana: [04:10 - 07:20]
#       - Cliente 2 (50.0, 35.0): 159.8 min (06:40) | Ventana: [04:10 - 07:20]
#     Entregas por cliente:
#       - Cliente 8: D
#       - Cliente 7: G
#       - Cliente 5: G
#       - Cliente 6: D
#       - Cliente 4: D
#       - Cliente 3: G
#       - Cliente 1: G
#       - Cliente 2: D
#
#   Ruta #2:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 16 → 15 → 11 → 12 → 14 → 13 → 10 → Depot
#     Carga: Gasohol=2390gal (59.8%), Diésel=3190gal (79.8%)
#     Distancia: 106.45 km
#     Tiempo: 141.5 min
#     Costo: $582.90
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 16 (41.0, 49.0): 15.2 min (04:15) | Ventana: [04:10 - 07:30]
#       - Cliente 15 (41.0, 49.0): 20.2 min (04:20) | Ventana: [04:10 - 07:30]
#       - Cliente 11 (57.0, 68.0): 50.1 min (04:50) | Ventana: [04:30 - 06:30]
#       - Cliente 12 (57.0, 68.0): 55.1 min (04:55) | Ventana: [04:30 - 06:30]
#       - Cliente 14 (62.0, 77.0): 70.4 min (05:10) | Ventana: [04:40 - 06:00]
#       - Cliente 13 (62.0, 77.0): 75.4 min (05:15) | Ventana: [04:40 - 06:00]
#       - Cliente 10 (61.0, 52.0): 105.4 min (05:45) | Ventana: [05:10 - 06:10]
#     Entregas por cliente:
#       - Cliente 16: D
#       - Cliente 15: G
#       - Cliente 11: G
#       - Cliente 12: D
#       - Cliente 14: D
#       - Cliente 13: G
#       - Cliente 10: D
#
#   Ruta #3:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 20 → 19 → 22 → 21 → 18 → 17 → 9 → Depot
#     Carga: Gasohol=3100gal (77.5%), Diésel=2450gal (61.3%)
#     Distancia: 104.28 km
#     Tiempo: 139.3 min
#     Costo: $578.55
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 20 (31.0, 52.0): 17.5 min (04:17) | Ventana: [04:10 - 07:20]
#       - Cliente 19 (31.0, 52.0): 22.5 min (04:22) | Ventana: [04:10 - 07:20]
#       - Cliente 22 (27.0, 69.0): 44.9 min (04:45) | Ventana: [04:30 - 07:00]
#       - Cliente 21 (27.0, 69.0): 49.9 min (04:50) | Ventana: [04:30 - 07:00]
#       - Cliente 18 (40.0, 60.0): 70.7 min (05:11) | Ventana: [04:40 - 05:50]
#       - Cliente 17 (40.0, 60.0): 75.7 min (05:16) | Ventana: [04:40 - 05:50]
#       - Cliente 9 (61.0, 52.0): 103.2 min (05:43) | Ventana: [05:10 - 06:10]
#     Entregas por cliente:
#       - Cliente 20: D
#       - Cliente 19: G
#       - Cliente 22: D
#       - Cliente 21: G
#       - Cliente 18: D
#       - Cliente 17: G
#       - Cliente 9: G
#
#   Ruta #4:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 23 → 24 → 25 → 26 → 27 → 28 → 29 → 30 → Depot
#     Carga: Gasohol=2820gal (70.5%), Diésel=3000gal (75.0%)
#     Distancia: 95.03 km
#     Tiempo: 149.5 min
#     Costo: $560.06
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 23 (24.0, 58.0): 40.0 min (04:40) | Ventana: [04:40 - 05:20]
#       - Cliente 24 (24.0, 58.0): 45.0 min (04:45) | Ventana: [04:40 - 05:20]
#       - Cliente 25 (20.0, 65.0): 58.1 min (04:58) | Ventana: [04:50 - 05:30]
#       - Cliente 26 (20.0, 65.0): 63.1 min (05:03) | Ventana: [04:50 - 05:30]
#       - Cliente 27 (15.0, 60.0): 75.1 min (05:15) | Ventana: [04:30 - 06:30]
#       - Cliente 28 (15.0, 60.0): 80.1 min (05:20) | Ventana: [04:30 - 06:30]
#       - Cliente 29 (2.0, 60.0): 98.1 min (05:38) | Ventana: [04:40 - 06:00]
#       - Cliente 30 (2.0, 60.0): 103.1 min (05:43) | Ventana: [04:40 - 06:00]
#     Entregas por cliente:
#       - Cliente 23: G
#       - Cliente 24: D
#       - Cliente 25: G
#       - Cliente 26: D
#       - Cliente 27: G
#       - Cliente 28: D
#       - Cliente 29: G
#       - Cliente 30: D
#
#   Ruta #5:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 31 → 32 → 41 → 42 → Depot
#     Carga: Gasohol=1510gal (37.8%), Diésel=1620gal (40.5%)
#     Distancia: 66.37 km
#     Tiempo: 189.1 min
#     Costo: $502.74
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 31 (10.0, 43.0): 80.0 min (05:20) | Ventana: [05:20 - 06:00]
#       - Cliente 32 (10.0, 43.0): 85.0 min (05:25) | Ventana: [05:20 - 06:00]
#       - Cliente 41 (36.0, 26.0): 170.0 min (06:50) | Ventana: [06:50 - 07:30]
#       - Cliente 42 (36.0, 26.0): 175.0 min (06:55) | Ventana: [06:50 - 07:30]
#     Entregas por cliente:
#       - Cliente 31: G
#       - Cliente 32: D
#       - Cliente 41: G
#       - Cliente 42: D
#
#   Ruta #6:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 33 → 34 → 36 → Depot
#     Carga: Gasohol=830gal (20.8%), Diésel=1620gal (40.5%)
#     Distancia: 84.88 km
#     Tiempo: 127.5 min
#     Costo: $539.76
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 33 (5.0, 5.0): 70.0 min (05:10) | Ventana: [05:10 - 05:50]
#       - Cliente 34 (5.0, 5.0): 75.0 min (05:15) | Ventana: [05:10 - 05:50]
#       - Cliente 36 (25.0, 24.0): 107.6 min (05:48) | Ventana: [04:10 - 07:30]
#     Entregas por cliente:
#       - Cliente 33: G
#       - Cliente 34: D
#       - Cliente 36: D
#
#   Ruta #7:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 35 → 37 → 38 → 39 → 40 → 46 → 45 → Depot
#     Carga: Gasohol=2930gal (73.2%), Diésel=2490gal (62.3%)
#     Distancia: 67.53 km
#     Tiempo: 102.5 min
#     Costo: $505.05
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 35 (25.0, 24.0): 14.9 min (04:15) | Ventana: [04:10 - 07:30]
#       - Cliente 37 (24.0, 12.0): 31.9 min (04:32) | Ventana: [04:20 - 05:40]
#       - Cliente 38 (24.0, 12.0): 36.9 min (04:37) | Ventana: [04:20 - 05:40]
#       - Cliente 39 (30.0, 5.0): 51.1 min (04:51) | Ventana: [04:50 - 05:30]
#       - Cliente 40 (30.0, 5.0): 56.1 min (04:56) | Ventana: [04:50 - 05:30]
#       - Cliente 46 (37.0, 31.0): 88.1 min (05:28) | Ventana: [05:20 - 06:00]
#       - Cliente 45 (37.0, 31.0): 93.1 min (05:33) | Ventana: [05:20 - 06:00]
#     Entregas por cliente:
#       - Cliente 35: G
#       - Cliente 37: G
#       - Cliente 38: D
#       - Cliente 39: G
#       - Cliente 40: D
#       - Cliente 46: D
#       - Cliente 45: G
#
#   Ruta #8:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 43 → 44 → 50 → 49 → 47 → 48 → Depot
#     Carga: Gasohol=2030gal (50.7%), Diésel=2350gal (58.8%)
#     Distancia: 94.14 km
#     Tiempo: 167.2 min
#     Costo: $558.28
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 43 (45.0, 10.0): 70.0 min (05:10) | Ventana: [05:10 - 06:10]
#       - Cliente 44 (45.0, 10.0): 75.0 min (05:15) | Ventana: [05:10 - 06:10]
#       - Cliente 50 (67.0, 5.0): 102.6 min (05:43) | Ventana: [05:10 - 05:50]
#       - Cliente 49 (67.0, 5.0): 107.6 min (05:48) | Ventana: [05:10 - 05:50]
#       - Cliente 47 (45.0, 20.0): 139.2 min (06:19) | Ventana: [04:10 - 07:20]
#       - Cliente 48 (45.0, 20.0): 144.2 min (06:24) | Ventana: [04:10 - 07:20]
#     Entregas por cliente:
#       - Cliente 43: G
#       - Cliente 44: D
#       - Cliente 50: D
#       - Cliente 49: G
#       - Cliente 47: G
#       - Cliente 48: D
#
# ================================================================================
# Solución final con costo total: $4,333.93
#
# --- Clockwise: True | Split Demands: False ---
#
# >>> Vehículos utilizados en Forward Sweep:
#   * Tipo 1: 0/20
#   * Tipo 2: 8/20
#
# ================================================================================
# SOLUCIÓN
# ================================================================================
#
# >>> RESUMEN GENERAL:
#   * Número de rutas: 8
#   * Costo total: $4,367.97
#   * Distancia total: 703.98 km
#   * Cisternas Tipo 1: 0/20
#   * Cisternas Tipo 2: 8/20
#
# ================================================================================
#
# ================================================================================
# INICIANDO MEJORA ITERATIVA (CLOCKWISE Y COUNTERCLOCKWISE)
# ================================================================================
#
# >>> Iteración global 1
#
#   >>> Intentando mejora en sentido ANTIHORARIO...
#   [Iteración 1 - antihorario] Mejora rutas 0-1: $1058.16 → $1043.74 (ahorro: $14.42)
#   [Iteración 1 - antihorario] Mejora rutas 3-4: $1144.03 → $1107.00 (ahorro: $37.03)
#   [Iteración 1 - antihorario] Mejora rutas 4-5: $1083.92 → $1053.36 (ahorro: $30.56)
#   [Iteración 1 - antihorario] Mejora rutas 5-6: $1152.70 → $1117.03 (ahorro: $35.67)
#   [Iteración 1 - antihorario] Mejora rutas 6-7: $1045.19 → $1043.48 (ahorro: $1.72)
#
# >>> Proceso de mejora (antihorario) completado en 2 iteraciones.
# >>> Vehículos utilizados:
#   * Tipo 1: 0/20
#   * Tipo 2: 8/20
#   >>> Mejora encontrada. Costo actual: $4,248.58
#
#   >>> Intentando mejora en sentido HORARIO...
#   [Iteración 1 - horario] Mejora rutas 3-4: $1080.95 → $1079.88 (ahorro: $1.07)
#
# >>> Proceso de mejora (horario) completado en 2 iteraciones.
# >>> Vehículos utilizados:
#   * Tipo 1: 0/20
#   * Tipo 2: 8/20
#   >>> Mejora encontrada. Costo actual: $4,247.50
#
# >>> Iteración global 2
#
#   >>> Intentando mejora en sentido ANTIHORARIO...
#
# >>> Proceso de mejora (antihorario) completado en 1 iteraciones.
# >>> Vehículos utilizados:
#   * Tipo 1: 0/20
#   * Tipo 2: 8/20
#   >>> Sin mejoras
#
#   >>> Intentando mejora en sentido HORARIO...
#
# >>> Proceso de mejora (horario) completado en 1 iteraciones.
# >>> Vehículos utilizados:
#   * Tipo 1: 0/20
#   * Tipo 2: 8/20
#   >>> Sin mejoras
#
# >>> No se encontraron más mejoras en ninguna dirección.
#
# ================================================================================
# MEJORA ITERATIVA COMPLETADA EN 2 ITERACIONES GLOBALES
# ================================================================================
#
# ================================================================================
# SOLUCIÓN
# ================================================================================
#
# >>> RESUMEN GENERAL:
#   * Número de rutas: 8
#   * Costo total: $4,247.50
#   * Distancia total: 643.75 km
#   * Cisternas Tipo 1: 0/20
#   * Cisternas Tipo 2: 8/20
#
# ================================================================================
#   [Iteración 1] Nueva mejor solución: $3,823.18
#   [Iteración 2] Nueva mejor solución: $3,815.30
#   [Iteración 3] Nueva mejor solución: $3,808.63
#
# ================================================================================
# SOLUCIÓN
# ================================================================================
#
# >>> RESUMEN GENERAL:
#   * Número de rutas: 7
#   * Costo total: $3,808.63
#   * Distancia total: 609.31 km
#   * Cisternas Tipo 1: 0/20
#   * Cisternas Tipo 2: 7/20
#
# >>> DETALLE DE RUTAS:
#
#   Ruta #1:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 2 → 25 → 22 → 24 → Depot
#     Carga: Gasohol=2910gal (72.8%), Diésel=3150gal (78.8%)
#     Distancia: 110.66 km
#     Tiempo: 170.7 min
#     Costo: $591.31
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 2 (65.0, 35.0): 50.0 min (04:50) | Ventana: [04:50 - 07:10]
#       - Cliente 25 (67.0, 5.0): 90.1 min (05:30) | Ventana: [05:10 - 05:50]
#       - Cliente 22 (45.0, 10.0): 122.6 min (06:03) | Ventana: [05:10 - 06:10]
#       - Cliente 24 (45.0, 20.0): 142.6 min (06:23) | Ventana: [04:10 - 07:20]
#     Entregas por cliente:
#       - Cliente 2: G, D
#       - Cliente 25: G, D
#       - Cliente 22: G, D
#       - Cliente 24: G, D
#
#   Ruta #2:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 19 → 20 → 23 → 21 → Depot
#     Carga: Gasohol=3110gal (77.8%), Diésel=3320gal (83.0%)
#     Distancia: 75.79 km
#     Tiempo: 189.1 min
#     Costo: $521.59
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 19 (24.0, 12.0): 25.5 min (04:25) | Ventana: [04:20 - 05:40]
#       - Cliente 20 (30.0, 5.0): 50.0 min (04:50) | Ventana: [04:50 - 05:30]
#       - Cliente 23 (37.0, 31.0): 86.9 min (05:27) | Ventana: [05:20 - 06:00]
#       - Cliente 21 (36.0, 26.0): 170.0 min (06:50) | Ventana: [06:50 - 07:30]
#     Entregas por cliente:
#       - Cliente 19: G, D
#       - Cliente 20: G, D
#       - Cliente 23: G, D
#       - Cliente 21: G, D
#
#   Ruta #3:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 14 → 15 → 16 → Depot
#     Carga: Gasohol=2210gal (55.2%), Diésel=2300gal (57.5%)
#     Distancia: 90.05 km
#     Tiempo: 120.1 min
#     Costo: $550.11
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 14 (15.0, 60.0): 32.0 min (04:32) | Ventana: [04:30 - 06:30]
#       - Cliente 15 (2.0, 60.0): 55.0 min (04:55) | Ventana: [04:40 - 06:00]
#       - Cliente 16 (10.0, 43.0): 83.8 min (05:24) | Ventana: [05:20 - 06:00]
#     Entregas por cliente:
#       - Cliente 14: G, D
#       - Cliente 15: G, D
#       - Cliente 16: G, D
#
#   Ruta #4:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 12 → 13 → 11 → 10 → Depot
#     Carga: Gasohol=2880gal (72.0%), Diésel=3140gal (78.5%)
#     Distancia: 76.55 km
#     Tiempo: 131.1 min
#     Costo: $523.10
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 12 (24.0, 58.0): 40.0 min (04:40) | Ventana: [04:40 - 05:20]
#       - Cliente 13 (20.0, 65.0): 58.1 min (04:58) | Ventana: [04:50 - 05:30]
#       - Cliente 11 (27.0, 69.0): 76.1 min (05:16) | Ventana: [04:30 - 07:00]
#       - Cliente 10 (31.0, 52.0): 103.6 min (05:44) | Ventana: [04:10 - 07:20]
#     Entregas por cliente:
#       - Cliente 12: G, D
#       - Cliente 13: G, D
#       - Cliente 11: G, D
#       - Cliente 10: G, D
#
#   Ruta #5:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 9 → 7 → 6 → 8 → Depot
#     Carga: Gasohol=3090gal (77.2%), Diésel=3240gal (81.0%)
#     Distancia: 103.66 km
#     Tiempo: 158.2 min
#     Costo: $577.33
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 9 (40.0, 60.0): 40.0 min (04:40) | Ventana: [04:40 - 05:50]
#       - Cliente 7 (62.0, 77.0): 77.8 min (05:18) | Ventana: [04:40 - 06:00]
#       - Cliente 6 (57.0, 68.0): 98.1 min (05:38) | Ventana: [04:30 - 06:30]
#       - Cliente 8 (41.0, 49.0): 132.9 min (06:13) | Ventana: [04:10 - 07:30]
#     Entregas por cliente:
#       - Cliente 9: G, D
#       - Cliente 7: G, D
#       - Cliente 6: G, D
#       - Cliente 8: G, D
#
#   Ruta #6:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 4 → 5 → 3 → 1 → Depot
#     Carga: Gasohol=3250gal (81.2%), Diésel=3210gal (80.2%)
#     Distancia: 67.72 km
#     Tiempo: 152.2 min
#     Costo: $505.44
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 4 (55.0, 45.0): 50.0 min (04:50) | Ventana: [04:50 - 07:10]
#       - Cliente 5 (61.0, 52.0): 70.0 min (05:10) | Ventana: [05:10 - 06:10]
#       - Cliente 3 (56.0, 39.0): 110.0 min (05:50) | Ventana: [05:50 - 07:00]
#       - Cliente 1 (50.0, 35.0): 127.2 min (06:07) | Ventana: [04:10 - 07:20]
#     Entregas por cliente:
#       - Cliente 4: G, D
#       - Cliente 5: G, D
#       - Cliente 3: G, D
#       - Cliente 1: G, D
#
#   Ruta #7:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 18 → 17 → Depot
#     Carga: Gasohol=1430gal (35.8%), Diésel=1620gal (40.5%)
#     Distancia: 84.88 km
#     Tiempo: 122.4 min
#     Costo: $539.76
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 18 (25.0, 24.0): 14.9 min (04:15) | Ventana: [04:10 - 07:30]
#       - Cliente 17 (5.0, 5.0): 70.0 min (05:10) | Ventana: [05:10 - 05:50]
#     Entregas por cliente:
#       - Cliente 18: G, D
#       - Cliente 17: G, D
#
# ================================================================================
# Solución final con costo total: $3,808.63
#
# --- Clockwise: True | Split Demands: True ---
#
# >>> Vehículos utilizados en Forward Sweep:
#   * Tipo 1: 0/20
#   * Tipo 2: 8/20
#
# ================================================================================
# SOLUCIÓN
# ================================================================================
#
# >>> RESUMEN GENERAL:
#   * Número de rutas: 8
#   * Costo total: $4,390.26
#   * Distancia total: 715.13 km
#   * Cisternas Tipo 1: 0/20
#   * Cisternas Tipo 2: 8/20
#
# ================================================================================
#
# ================================================================================
# INICIANDO MEJORA ITERATIVA (CLOCKWISE Y COUNTERCLOCKWISE)
# ================================================================================
#
# >>> Iteración global 1
#
#   >>> Intentando mejora en sentido ANTIHORARIO...
#   [Iteración 1 - antihorario] Mejora rutas 5-6: $1189.43 → $1184.25 (ahorro: $5.18)
#   [Iteración 1 - antihorario] Mejora rutas 5-6: $1184.25 → $1173.98 (ahorro: $10.27)
#
# >>> Proceso de mejora (antihorario) completado en 2 iteraciones.
# >>> Vehículos utilizados:
#   * Tipo 1: 0/20
#   * Tipo 2: 8/20
#   >>> Mejora encontrada. Costo actual: $4,374.81
#
#   >>> Intentando mejora en sentido HORARIO...
#
# >>> Proceso de mejora (horario) completado en 1 iteraciones.
# >>> Vehículos utilizados:
#   * Tipo 1: 0/20
#   * Tipo 2: 8/20
#   >>> Sin mejoras
#
# >>> Iteración global 2
#
#   >>> Intentando mejora en sentido ANTIHORARIO...
#
# >>> Proceso de mejora (antihorario) completado en 1 iteraciones.
# >>> Vehículos utilizados:
#   * Tipo 1: 0/20
#   * Tipo 2: 8/20
#   >>> Sin mejoras
#
#   >>> Intentando mejora en sentido HORARIO...
#
# >>> Proceso de mejora (horario) completado en 1 iteraciones.
# >>> Vehículos utilizados:
#   * Tipo 1: 0/20
#   * Tipo 2: 8/20
#   >>> Sin mejoras
#
# >>> No se encontraron más mejoras en ninguna dirección.
#
# ================================================================================
# MEJORA ITERATIVA COMPLETADA EN 2 ITERACIONES GLOBALES
# ================================================================================
#
# ================================================================================
# SOLUCIÓN
# ================================================================================
#
# >>> RESUMEN GENERAL:
#   * Número de rutas: 8
#   * Costo total: $4,374.81
#   * Distancia total: 707.41 km
#   * Cisternas Tipo 1: 0/20
#   * Cisternas Tipo 2: 8/20
#
# ================================================================================
#   [Iteración 1] Nueva mejor solución: $4,330.51
#   [Iteración 3] Nueva mejor solución: $4,323.40
#   [Iteración 4] Nueva mejor solución: $3,934.44
#   [Iteración 17] Nueva mejor solución: $3,843.10
#
# ================================================================================
# SOLUCIÓN
# ================================================================================
#
# >>> RESUMEN GENERAL:
#   * Número de rutas: 7
#   * Costo total: $3,843.10
#   * Distancia total: 626.55 km
#   * Cisternas Tipo 1: 0/20
#   * Cisternas Tipo 2: 7/20
#
# >>> DETALLE DE RUTAS:
#
#   Ruta #1:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 2 → 1 → 4 → 3 → 6 → 5 → 8 → 7 → Depot
#     Carga: Gasohol=2980gal (74.5%), Diésel=3170gal (79.2%)
#     Distancia: 104.72 km
#     Tiempo: 154.7 min
#     Costo: $579.44
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 2 (50.0, 35.0): 15.0 min (04:15) | Ventana: [04:10 - 07:20]
#       - Cliente 1 (50.0, 35.0): 20.0 min (04:20) | Ventana: [04:10 - 07:20]
#       - Cliente 4 (65.0, 35.0): 50.0 min (04:50) | Ventana: [04:50 - 07:10]
#       - Cliente 3 (65.0, 35.0): 55.0 min (04:55) | Ventana: [04:50 - 07:10]
#       - Cliente 6 (67.0, 5.0): 90.1 min (05:30) | Ventana: [05:10 - 05:50]
#       - Cliente 5 (67.0, 5.0): 95.1 min (05:35) | Ventana: [05:10 - 05:50]
#       - Cliente 8 (45.0, 20.0): 126.7 min (06:07) | Ventana: [04:10 - 07:20]
#       - Cliente 7 (45.0, 20.0): 131.7 min (06:12) | Ventana: [04:10 - 07:20]
#     Entregas por cliente:
#       - Cliente 2: D
#       - Cliente 1: G
#       - Cliente 4: D
#       - Cliente 3: G
#       - Cliente 6: D
#       - Cliente 5: G
#       - Cliente 8: D
#       - Cliente 7: G
#
#   Ruta #2:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 10 → 9 → 11 → 12 → 13 → 14 → 20 → 19 → Depot
#     Carga: Gasohol=3010gal (75.2%), Diésel=3350gal (83.8%)
#     Distancia: 71.35 km
#     Tiempo: 216.0 min
#     Costo: $512.70
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 10 (37.0, 31.0): 80.0 min (05:20) | Ventana: [05:20 - 06:00]
#       - Cliente 9 (37.0, 31.0): 85.0 min (05:25) | Ventana: [05:20 - 06:00]
#       - Cliente 11 (45.0, 10.0): 112.5 min (05:52) | Ventana: [05:10 - 06:10]
#       - Cliente 12 (45.0, 10.0): 117.5 min (05:57) | Ventana: [05:10 - 06:10]
#       - Cliente 13 (36.0, 26.0): 170.0 min (06:50) | Ventana: [06:50 - 07:30]
#       - Cliente 14 (36.0, 26.0): 175.0 min (06:55) | Ventana: [06:50 - 07:30]
#       - Cliente 20 (25.0, 24.0): 191.2 min (07:11) | Ventana: [04:10 - 07:30]
#       - Cliente 19 (25.0, 24.0): 196.2 min (07:16) | Ventana: [04:10 - 07:30]
#     Entregas por cliente:
#       - Cliente 10: D
#       - Cliente 9: G
#       - Cliente 11: G
#       - Cliente 12: D
#       - Cliente 13: G
#       - Cliente 14: D
#       - Cliente 20: D
#       - Cliente 19: G
#
#   Ruta #3:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 18 → 17 → 15 → 16 → 21 → 22 → Depot
#     Carga: Gasohol=2340gal (58.5%), Diésel=2440gal (61.0%)
#     Distancia: 102.14 km
#     Tiempo: 137.4 min
#     Costo: $574.28
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 18 (24.0, 12.0): 25.5 min (04:25) | Ventana: [04:20 - 05:40]
#       - Cliente 17 (24.0, 12.0): 30.5 min (04:30) | Ventana: [04:20 - 05:40]
#       - Cliente 15 (30.0, 5.0): 50.0 min (04:50) | Ventana: [04:50 - 05:30]
#       - Cliente 16 (30.0, 5.0): 55.0 min (04:55) | Ventana: [04:50 - 05:30]
#       - Cliente 21 (5.0, 5.0): 85.0 min (05:25) | Ventana: [05:10 - 05:50]
#       - Cliente 22 (5.0, 5.0): 90.0 min (05:30) | Ventana: [05:10 - 05:50]
#     Entregas por cliente:
#       - Cliente 18: D
#       - Cliente 17: G
#       - Cliente 15: G
#       - Cliente 16: D
#       - Cliente 21: G
#       - Cliente 22: D
#
#   Ruta #4:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 23 → 24 → 25 → 26 → 28 → 27 → 34 → 33 → Depot
#     Carga: Gasohol=2830gal (70.8%), Diésel=3140gal (78.5%)
#     Distancia: 93.39 km
#     Tiempo: 187.1 min
#     Costo: $556.78
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 23 (10.0, 43.0): 80.0 min (05:20) | Ventana: [05:20 - 06:00]
#       - Cliente 24 (10.0, 43.0): 85.0 min (05:25) | Ventana: [05:20 - 06:00]
#       - Cliente 25 (2.0, 60.0): 108.8 min (05:49) | Ventana: [04:40 - 06:00]
#       - Cliente 26 (2.0, 60.0): 113.8 min (05:54) | Ventana: [04:40 - 06:00]
#       - Cliente 28 (15.0, 60.0): 131.8 min (06:12) | Ventana: [04:30 - 06:30]
#       - Cliente 27 (15.0, 60.0): 136.8 min (06:17) | Ventana: [04:30 - 06:30]
#       - Cliente 34 (31.0, 52.0): 159.7 min (06:40) | Ventana: [04:10 - 07:20]
#       - Cliente 33 (31.0, 52.0): 164.7 min (06:45) | Ventana: [04:10 - 07:20]
#     Entregas por cliente:
#       - Cliente 23: G
#       - Cliente 24: D
#       - Cliente 25: G
#       - Cliente 26: D
#       - Cliente 28: D
#       - Cliente 27: G
#       - Cliente 34: D
#       - Cliente 33: G
#
#   Ruta #5:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 31 → 32 → 29 → 30 → 36 → 35 → 38 → 37 → Depot
#     Carga: Gasohol=2960gal (74.0%), Diésel=3100gal (77.5%)
#     Distancia: 82.93 km
#     Tiempo: 137.4 min
#     Costo: $535.85
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 31 (24.0, 58.0): 40.0 min (04:40) | Ventana: [04:40 - 05:20]
#       - Cliente 32 (24.0, 58.0): 45.0 min (04:45) | Ventana: [04:40 - 05:20]
#       - Cliente 29 (20.0, 65.0): 58.1 min (04:58) | Ventana: [04:50 - 05:30]
#       - Cliente 30 (20.0, 65.0): 63.1 min (05:03) | Ventana: [04:50 - 05:30]
#       - Cliente 36 (27.0, 69.0): 76.1 min (05:16) | Ventana: [04:30 - 07:00]
#       - Cliente 35 (27.0, 69.0): 81.1 min (05:21) | Ventana: [04:30 - 07:00]
#       - Cliente 38 (40.0, 60.0): 101.9 min (05:42) | Ventana: [04:40 - 05:50]
#       - Cliente 37 (40.0, 60.0): 106.9 min (05:47) | Ventana: [04:40 - 05:50]
#     Entregas por cliente:
#       - Cliente 31: G
#       - Cliente 32: D
#       - Cliente 29: G
#       - Cliente 30: D
#       - Cliente 36: D
#       - Cliente 35: G
#       - Cliente 38: D
#       - Cliente 37: G
#
#   Ruta #6:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 44 → 43 → 41 → 42 → Depot
#     Carga: Gasohol=1670gal (41.8%), Diésel=1650gal (41.2%)
#     Distancia: 99.89 km
#     Tiempo: 119.9 min
#     Costo: $569.77
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 44 (57.0, 68.0): 39.7 min (04:40) | Ventana: [04:30 - 06:30]
#       - Cliente 43 (57.0, 68.0): 44.7 min (04:45) | Ventana: [04:30 - 06:30]
#       - Cliente 41 (62.0, 77.0): 60.0 min (04:60) | Ventana: [04:40 - 06:00]
#       - Cliente 42 (62.0, 77.0): 65.0 min (05:05) | Ventana: [04:40 - 06:00]
#     Entregas por cliente:
#       - Cliente 44: D
#       - Cliente 43: G
#       - Cliente 41: G
#       - Cliente 42: D
#
#   Ruta #7:
#     Cisterna: Tipo 2
#     Secuencia: Depot → 40 → 39 → 45 → 46 → 48 → 47 → 50 → 49 → Depot
#     Carga: Gasohol=3090gal (77.2%), Diésel=3130gal (78.2%)
#     Distancia: 72.14 km
#     Tiempo: 141.4 min
#     Costo: $514.27
#     Tiempos de llegada (min desde 04:00):
#       - Cliente 40 (41.0, 49.0): 15.2 min (04:15) | Ventana: [04:10 - 07:30]
#       - Cliente 39 (41.0, 49.0): 20.2 min (04:20) | Ventana: [04:10 - 07:30]
#       - Cliente 45 (61.0, 52.0): 70.0 min (05:10) | Ventana: [05:10 - 06:10]
#       - Cliente 46 (61.0, 52.0): 75.0 min (05:15) | Ventana: [05:10 - 06:10]
#       - Cliente 48 (55.0, 45.0): 89.2 min (05:29) | Ventana: [04:50 - 07:10]
#       - Cliente 47 (55.0, 45.0): 94.2 min (05:34) | Ventana: [04:50 - 07:10]
#       - Cliente 50 (56.0, 39.0): 110.0 min (05:50) | Ventana: [05:50 - 07:00]
#       - Cliente 49 (56.0, 39.0): 115.0 min (05:55) | Ventana: [05:50 - 07:00]
#     Entregas por cliente:
#       - Cliente 40: D
#       - Cliente 39: G
#       - Cliente 45: G
#       - Cliente 46: D
#       - Cliente 48: D
#       - Cliente 47: G
#       - Cliente 50: D
#       - Cliente 49: G
#
# ================================================================================
# Solución final con costo total: $3,843.10
#
# === Mejor configuración encontrada: Clockwise=False, Split Demands=False con costo total: $3,395.31 ===
